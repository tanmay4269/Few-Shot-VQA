# %%
import os
os.chdir('/workspace')
from trainer import * 

cfg = {
    "name": "DANN",
    #
    ### DataLoader ###
    # "n_classes": 12,
    # "n_types": 4,

    "n_classes": 6,
    "n_types": 3,

    'label_type_to_labels' : {
        'yes_no': ['yes', 'no'],
        'colors': ['red', 'blue'],
        'numbers': ['0', '1'],
    },

    #
    "v2_samples_per_answer": 300,
    "abs_samples_per_answer": 300,
    #
    "v2_samples_per_answer_train": 200,
    "abs_samples_per_answer_train": 200,
    #
    "v2_samples_per_answer_val": 50,
    "abs_samples_per_answer_val": 50,
    "source_domain": "v2",
    
    ### VLModel ###
    "image_encoder": "facebook/dinov2-base",
    "text_encoder": "bert-base-uncased",
    #
    ## Embedder
    "num_attn_heads": 8,
    "fusion_mode": "cat",
    "num_stacked_attn": 1,
    "criss_cross__drop_p": 0.0,
    "post_concat__drop_p": 0.0,
    "embed_attn__add_residual": False,
    "embed_attn__drop_p": 0.0,
    #
    ## Label Classifier
    "label_classifier__use_bn": False,
    "label_classifier__drop_p": 0.0,
    "label_classifier__repeat_layers": [2, 2],
    #
    ## Domain Classifier
    "domain_classifier__use_bn": True,
    "domain_classifier__drop_p": 0.5,
    "domain_classifier__repeat_layers": [2, 2],
    #
    ### Objective ###
    "domain_adaptation_method": "domain_adversarial",  # 'naive', 'importance_sampling', 'domain_adversarial'
    #
    ### Trainer ###
    "relaxation_period": 3,
    "epochs": 30,
    "batch_size": 150,
    "base_lr": 1e-5,
    "weight_decay": 1e-5,
    #
    ### Logging ###
    # "print_logs": False,
    "print_logs": True,
    "show_plot": True,
    "weights_save_root": "./weights/raw",
}

if True:
    # v2
    cfg["source_domain"] = "v2"
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    v2_ckpt_path = cfg["weights_save_path"]

    trainer.train(show_plot=True)

    # abs
    cfg["source_domain"] = "abs"
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    abs_ckpt_path = cfg["weights_save_path"]

    trainer.train(show_plot=False)
# Out:
# weights_save_path: ./weights/raw/CFUJFS2E.pth
# Labels: ['yes', 'no', 'red', 'blue', '0', '1']
# Number of Common Labels = 6 | n_classes = 6
# V2: 	Train size = 1200             | Val size = 300 | Total = 1500
# Abs: 	Train size = 1200             | Val size = 300 | Total = 1500
# --------------------
# Epoch [1/30]	                         Avg Train Loss: 1.110937	                         Avg Eval Loss: 1.106476	                         Avg Domain Accuracy: 0.49	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [2/30]	                         Avg Train Loss: 1.107965	                         Avg Eval Loss: 1.114219	                         Avg Domain Accuracy: 0.50	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [3/30]	                         Avg Train Loss: 1.114268	                         Avg Eval Loss: 1.116889	                         Avg Domain Accuracy: 0.50	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [4/30]	                         Avg Train Loss: 1.108305	                         Avg Eval Loss: 1.114114	                         Avg Domain Accuracy: 0.49	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [5/30]	                         Avg Train Loss: 1.107820	                         Avg Eval Loss: 1.105422	                         Avg Domain Accuracy: 0.50	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [6/30]	                         Avg Train Loss: 1.107508	                         Avg Eval Loss: 1.103712	                         Avg Domain Accuracy: 0.51	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [7/30]	                         Avg Train Loss: 1.109322	                         Avg Eval Loss: 1.102769	                         Avg Domain Accuracy: 0.52	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [8/30]	                         Avg Train Loss: 1.109483	                         Avg Eval Loss: 1.115737	                         Avg Domain Accuracy: 0.49	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [9/30]	                         Avg Train Loss: 1.105570	                         Avg Eval Loss: 1.114269	                         Avg Domain Accuracy: 0.48	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [10/30]	                         Avg Train Loss: 1.114050	                         Avg Eval Loss: 1.106707	                         Avg Domain Accuracy: 0.50	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [11/30]	                         Avg Train Loss: 1.099867	                         Avg Eval Loss: 1.099820	                         Avg Domain Accuracy: 0.51	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [12/30]	                         Avg Train Loss: 1.103852	                         Avg Eval Loss: 1.097883	                         Avg Domain Accuracy: 0.52	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [13/30]	                         Avg Train Loss: 1.105062	                         Avg Eval Loss: 1.104271	                         Avg Domain Accuracy: 0.51	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [14/30]	                         Avg Train Loss: 1.102561	                         Avg Eval Loss: 1.104742	                         Avg Domain Accuracy: 0.50	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [15/30]	                         Avg Train Loss: 1.110562	                         Avg Eval Loss: 1.104644	                         Avg Domain Accuracy: 0.47	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [16/30]	                         Avg Train Loss: 1.112250	                         Avg Eval Loss: 1.107681	                         Avg Domain Accuracy: 0.49	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [17/30]	                         Avg Train Loss: 1.110529	                         Avg Eval Loss: 1.098087	                         Avg Domain Accuracy: 0.55	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [18/30]	                         Avg Train Loss: 1.101109	                         Avg Eval Loss: 1.094217	                         Avg Domain Accuracy: 0.55	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [19/30]	                         Avg Train Loss: 1.101585	                         Avg Eval Loss: 1.109797	                         Avg Domain Accuracy: 0.48	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [20/30]	                         Avg Train Loss: 1.107121	                         Avg Eval Loss: 1.109318	                         Avg Domain Accuracy: 0.51	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [21/30]	                         Avg Train Loss: 1.100766	                         Avg Eval Loss: 1.101705	                         Avg Domain Accuracy: 0.52	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [22/30]	                         Avg Train Loss: 1.102924	                         Avg Eval Loss: 1.106278	                         Avg Domain Accuracy: 0.52	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [23/30]	                         Avg Train Loss: 1.105400	                         Avg Eval Loss: 1.102718	                         Avg Domain Accuracy: 0.51	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [24/30]	                         Avg Train Loss: 1.109080	                         Avg Eval Loss: 1.100877	                         Avg Domain Accuracy: 0.51	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [25/30]	                         Avg Train Loss: 1.106787	                         Avg Eval Loss: 1.097720	                         Avg Domain Accuracy: 0.50	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [26/30]	                         Avg Train Loss: 1.100779	                         Avg Eval Loss: 1.097555	                         Avg Domain Accuracy: 0.53	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [27/30]	                         Avg Train Loss: 1.110531	                         Avg Eval Loss: 1.091903	                         Avg Domain Accuracy: 0.54	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [28/30]	                         Avg Train Loss: 1.102752	                         Avg Eval Loss: 1.106397	                         Avg Domain Accuracy: 0.50	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [29/30]	                         Avg Train Loss: 1.104211	                         Avg Eval Loss: 1.114472	                         Avg Domain Accuracy: 0.50	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# Epoch [30/30]	                         Avg Train Loss: 1.104702	                         Avg Eval Loss: 1.114686	                         Avg Domain Accuracy: 0.48	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
# weights_save_path: ./weights/raw/ecmJzEwY.pth
# Labels: ['yes', 'no', 'red', 'blue', '0', '1']
# Number of Common Labels = 6 | n_classes = 6
# V2: 	Train size = 1200             | Val size = 300 | Total = 1500
# Abs: 	Train size = 1200             | Val size = 300 | Total = 1500
# --------------------
# Epoch [1/30]	                         Avg Train Loss: 1.099559	                         Avg Eval Loss: 1.093988	                         Avg Domain Accuracy: 0.49	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.25
