# %%
import os
os.chdir('/workspace')
from trainer import * 

cfg = {
    "name": "DANN",
    #
    ### DataLoader ###
    # "n_classes": 12,
    # "n_types": 4,

    "n_classes": 6,
    "n_types": 3,

    'label_type_to_labels' : {
        'yes_no': ['yes', 'no'],
        'colors': ['red', 'blue'],
        'numbers': ['0', '1'],
    },

    #
    "v2_samples_per_answer": 300,
    "abs_samples_per_answer": 300,
    #
    "v2_samples_per_answer_train": 200,
    "abs_samples_per_answer_train": 200,
    #
    "v2_samples_per_answer_val": 50,
    "abs_samples_per_answer_val": 50,
    "source_domain": "v2",
    
    ### VLModel ###
    "image_encoder": "facebook/dinov2-base",
    "text_encoder": "bert-base-uncased",
    #
    ## Embedder
    "num_attn_heads": 8,
    "fusion_mode": "cat",
    "num_stacked_attn": 1,
    "criss_cross__drop_p": 0.5,
    "post_concat__drop_p": 0.0,
    "embed_attn__add_residual": False,
    "embed_attn__drop_p": 0.0,
    #
    ## Label Classifier
    "label_classifier__use_bn": False,
    "label_classifier__drop_p": 0.0,
    "label_classifier__repeat_layers": [2, 2],
    #
    ## Domain Classifier
    "domain_classifier__use_bn": True,
    "domain_classifier__drop_p": 0.5,
    "domain_classifier__repeat_layers": [2, 2],
    #
    ### Objective ###
    "domain_adaptation_method": "domain_adversarial",  # 'naive', 'importance_sampling', 'domain_adversarial'
    #
    ### Trainer ###
    "relaxation_period": 3,
    "epochs": 50,
    "batch_size": 150,
    "base_lr": 5e-5,
    "weight_decay": 1e-5,
    #
    ### Logging ###
    # "print_logs": False,
    "print_logs": True,
    "show_plot": True,
    "weights_save_root": "./weights/raw",
}

if True:
    # v2
    cfg["source_domain"] = "v2"
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    v2_ckpt_path = cfg["weights_save_path"]

    trainer.train(show_plot=True)

    # abs
    cfg["source_domain"] = "abs"
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    abs_ckpt_path = cfg["weights_save_path"]

    trainer.train(show_plot=False)
# Out:
# weights_save_path: ./weights/raw/ImjYuoMG.pth
# Labels: ['yes', 'no', 'red', 'blue', '0', '1']
# Number of Common Labels = 6 | n_classes = 6
# V2: 	Train size = 1200             | Val size = 300 | Total = 1500
# Abs: 	Train size = 1200             | Val size = 300 | Total = 1500
# --------------------
# Epoch [1/50]	                         Avg Train Loss: 1.100721	                         Avg Eval Loss: 1.112795	                         Avg Domain Accuracy: 0.49	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.08
# Epoch [2/50]	                         Avg Train Loss: 1.108851	                         Avg Eval Loss: 1.098277	                         Avg Domain Accuracy: 0.51	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.08
# Epoch [3/50]	                         Avg Train Loss: 1.099247	                         Avg Eval Loss: 1.108036	                         Avg Domain Accuracy: 0.46	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.08
# Epoch [4/50]	                         Avg Train Loss: 1.103249	                         Avg Eval Loss: 1.109460	                         Avg Domain Accuracy: 0.47	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.08
# Epoch [5/50]	                         Avg Train Loss: 1.103079	                         Avg Eval Loss: 1.092120	                         Avg Domain Accuracy: 0.53	                         Avg Label Type Accuracy: 0.25	                         Avg Total Eval Accuracy: 0.08
# Epoch [6/50]	                         Avg Train Loss: 1.097672	                         Avg Eval Loss: 1.093358	                         Avg Domain Accuracy: 0.52	                         Avg Label Type Accuracy: 0.27	                         Avg Total Eval Accuracy: 0.10
# Epoch [7/50]	                         Avg Train Loss: 1.094670	                         Avg Eval Loss: 1.099468	                         Avg Domain Accuracy: 0.49	                         Avg Label Type Accuracy: 0.35	                         Avg Total Eval Accuracy: 0.13
# Epoch [8/50]	                         Avg Train Loss: 1.097111	                         Avg Eval Loss: 1.090762	                         Avg Domain Accuracy: 0.53	                         Avg Label Type Accuracy: 0.36	                         Avg Total Eval Accuracy: 0.14
# Epoch [9/50]	                         Avg Train Loss: 1.095872	                         Avg Eval Loss: 1.089952	                         Avg Domain Accuracy: 0.49	                         Avg Label Type Accuracy: 0.36	                         Avg Total Eval Accuracy: 0.16
# Epoch [10/50]	                         Avg Train Loss: 1.065447	                         Avg Eval Loss: 1.039258	                         Avg Domain Accuracy: 0.49	                         Avg Label Type Accuracy: 0.36	                         Avg Total Eval Accuracy: 0.19
# Epoch [11/50]	                         Avg Train Loss: 0.999959	                         Avg Eval Loss: 0.926320	                         Avg Domain Accuracy: 0.51	                         Avg Label Type Accuracy: 0.32	                         Avg Total Eval Accuracy: 0.32
# Epoch [12/50]	                         Avg Train Loss: 0.876731	                         Avg Eval Loss: 0.829113	                         Avg Domain Accuracy: 0.48	                         Avg Label Type Accuracy: 0.33	                         Avg Total Eval Accuracy: 0.30
# Epoch [13/50]	                         Avg Train Loss: 0.801419	                         Avg Eval Loss: 0.788910	                         Avg Domain Accuracy: 0.49	                         Avg Label Type Accuracy: 0.42	                         Avg Total Eval Accuracy: 0.33
# Epoch [14/50]	                         Avg Train Loss: 0.793754	                         Avg Eval Loss: 0.773875	                         Avg Domain Accuracy: 0.54	                         Avg Label Type Accuracy: 0.38	                         Avg Total Eval Accuracy: 0.17
# Epoch [15/50]	                         Avg Train Loss: 0.792141	                         Avg Eval Loss: 0.787687	                         Avg Domain Accuracy: 0.52	                         Avg Label Type Accuracy: 0.42	                         Avg Total Eval Accuracy: 0.24
# Epoch [16/50]	                         Avg Train Loss: 0.782475	                         Avg Eval Loss: 0.797027	                         Avg Domain Accuracy: 0.49	                         Avg Label Type Accuracy: 0.41	                         Avg Total Eval Accuracy: 0.22
# Epoch [17/50]	                         Avg Train Loss: 0.761113	                         Avg Eval Loss: 0.738462	                         Avg Domain Accuracy: 0.48	                         Avg Label Type Accuracy: 0.44	                         Avg Total Eval Accuracy: 0.21
# Epoch [18/50]	                         Avg Train Loss: 0.696923	                         Avg Eval Loss: 0.661756	                         Avg Domain Accuracy: 0.49	                         Avg Label Type Accuracy: 0.55	                         Avg Total Eval Accuracy: 0.40
# Epoch [19/50]	                         Avg Train Loss: 0.624485	                         Avg Eval Loss: 0.626004	                         Avg Domain Accuracy: 0.48	                         Avg Label Type Accuracy: 0.56	                         Avg Total Eval Accuracy: 0.41
# Epoch [20/50]	                         Avg Train Loss: 0.592985	                         Avg Eval Loss: 0.589905	                         Avg Domain Accuracy: 0.51	                         Avg Label Type Accuracy: 0.56	                         Avg Total Eval Accuracy: 0.39
# Epoch [21/50]	                         Avg Train Loss: 0.582368	                         Avg Eval Loss: 0.583659	                         Avg Domain Accuracy: 0.52	                         Avg Label Type Accuracy: 0.56	                         Avg Total Eval Accuracy: 0.38
# Epoch [22/50]	                         Avg Train Loss: 0.579133	                         Avg Eval Loss: 0.570338	                         Avg Domain Accuracy: 0.51	                         Avg Label Type Accuracy: 0.57	                         Avg Total Eval Accuracy: 0.26
# Epoch [23/50]	                         Avg Train Loss: 0.573102	                         Avg Eval Loss: 0.570227	                         Avg Domain Accuracy: 0.52	                         Avg Label Type Accuracy: 0.57	                         Avg Total Eval Accuracy: 0.38
# Epoch [24/50]	                         Avg Train Loss: 0.567410	                         Avg Eval Loss: 0.577177	                         Avg Domain Accuracy: 0.52	                         Avg Label Type Accuracy: 0.56	                         Avg Total Eval Accuracy: 0.39
# Epoch [25/50]	                         Avg Train Loss: 0.572341	                         Avg Eval Loss: 0.583655	                         Avg Domain Accuracy: 0.49	                         Avg Label Type Accuracy: 0.56	                         Avg Total Eval Accuracy: 0.27
# Epoch [26/50]	                         Avg Train Loss: 0.565597	                         Avg Eval Loss: 0.570488	                         Avg Domain Accuracy: 0.48	                         Avg Label Type Accuracy: 0.57	                         Avg Total Eval Accuracy: 0.40
# Epoch [27/50]	                         Avg Train Loss: 0.564281	                         Avg Eval Loss: 0.573998	                         Avg Domain Accuracy: 0.48	                         Avg Label Type Accuracy: 0.57	                         Avg Total Eval Accuracy: 0.38
# Epoch [28/50]	                         Avg Train Loss: 0.569400	                         Avg Eval Loss: 0.550627	                         Avg Domain Accuracy: 0.53	                         Avg Label Type Accuracy: 0.58	                         Avg Total Eval Accuracy: 0.36
# Epoch [29/50]	                         Avg Train Loss: 0.563800	                         Avg Eval Loss: 0.570884	                         Avg Domain Accuracy: 0.51	                         Avg Label Type Accuracy: 0.57	                         Avg Total Eval Accuracy: 0.31
# Epoch [30/50]	                         Avg Train Loss: 0.572166	                         Avg Eval Loss: 0.573161	                         Avg Domain Accuracy: 0.51	                         Avg Label Type Accuracy: 0.57	                         Avg Total Eval Accuracy: 0.32
# Epoch [31/50]	                         Avg Train Loss: 0.564414	                         Avg Eval Loss: 0.581025	                         Avg Domain Accuracy: 0.49	                         Avg Label Type Accuracy: 0.56	                         Avg Total Eval Accuracy: 0.41
# Epoch [32/50]	                         Avg Train Loss: 0.558937	                         Avg Eval Loss: 0.562762	                         Avg Domain Accuracy: 0.52	                         Avg Label Type Accuracy: 0.57	                         Avg Total Eval Accuracy: 0.32
# Epoch [33/50]	                         Avg Train Loss: 0.561197	                         Avg Eval Loss: 0.572406	                         Avg Domain Accuracy: 0.52	                         Avg Label Type Accuracy: 0.57	                         Avg Total Eval Accuracy: 0.41
# Epoch [34/50]	                         Avg Train Loss: 0.560252	                         Avg Eval Loss: 0.575874	                         Avg Domain Accuracy: 0.49	                         Avg Label Type Accuracy: 0.56	                         Avg Total Eval Accuracy: 0.39
# Epoch [35/50]	                         Avg Train Loss: 0.554542	                         Avg Eval Loss: 0.566502	                         Avg Domain Accuracy: 0.50	                         Avg Label Type Accuracy: 0.57	                         Avg Total Eval Accuracy: 0.39
# Epoch [36/50]	                         Avg Train Loss: 0.560435	                         Avg Eval Loss: 0.579202	                         Avg Domain Accuracy: 0.52	                         Avg Label Type Accuracy: 0.57	                         Avg Total Eval Accuracy: 0.24
# Epoch [37/50]	                         Avg Train Loss: 0.558190	                         Avg Eval Loss: 0.572360	                         Avg Domain Accuracy: 0.51	                         Avg Label Type Accuracy: 0.57	                         Avg Total Eval Accuracy: 0.39
# Epoch [38/50]	                         Avg Train Loss: 0.558032	                         Avg Eval Loss: 0.563594	                         Avg Domain Accuracy: 0.48	                         Avg Label Type Accuracy: 0.57	                         Avg Total Eval Accuracy: 0.40
# Epoch [39/50]	                         Avg Train Loss: 0.556465	                         Avg Eval Loss: 0.572590	                         Avg Domain Accuracy: 0.48	                         Avg Label Type Accuracy: 0.57	                         Avg Total Eval Accuracy: 0.35
# Epoch [40/50]	                         Avg Train Loss: 0.559197	                         Avg Eval Loss: 0.570404	                         Avg Domain Accuracy: 0.51	                         Avg Label Type Accuracy: 0.57	                         Avg Total Eval Accuracy: 0.30
# Epoch [41/50]	                         Avg Train Loss: 0.554034	                         Avg Eval Loss: 0.568669	                         Avg Domain Accuracy: 0.47	                         Avg Label Type Accuracy: 0.56	                         Avg Total Eval Accuracy: 0.41
# Epoch [42/50]	                         Avg Train Loss: 0.552235	                         Avg Eval Loss: 0.564863	                         Avg Domain Accuracy: 0.50	                         Avg Label Type Accuracy: 0.58	                         Avg Total Eval Accuracy: 0.35
# Epoch [43/50]	                         Avg Train Loss: 0.556844	                         Avg Eval Loss: 0.572483	                         Avg Domain Accuracy: 0.48	                         Avg Label Type Accuracy: 0.57	                         Avg Total Eval Accuracy: 0.36
# Epoch [44/50]	                         Avg Train Loss: 0.552954	                         Avg Eval Loss: 0.571803	                         Avg Domain Accuracy: 0.52	                         Avg Label Type Accuracy: 0.57	                         Avg Total Eval Accuracy: 0.34
# Epoch [45/50]	                         Avg Train Loss: 0.548597	                         Avg Eval Loss: 0.570022	                         Avg Domain Accuracy: 0.48	                         Avg Label Type Accuracy: 0.57	                         Avg Total Eval Accuracy: 0.35
# Epoch [46/50]	                         Avg Train Loss: 0.546306	                         Avg Eval Loss: 0.556086	                         Avg Domain Accuracy: 0.48	                         Avg Label Type Accuracy: 0.57	                         Avg Total Eval Accuracy: 0.39
# Epoch [47/50]	                         Avg Train Loss: 0.553563	                         Avg Eval Loss: 0.564819	                         Avg Domain Accuracy: 0.48	                         Avg Label Type Accuracy: 0.57	                         Avg Total Eval Accuracy: 0.36
# Epoch [48/50]	                         Avg Train Loss: 0.551663	                         Avg Eval Loss: 0.559415	                         Avg Domain Accuracy: 0.53	                         Avg Label Type Accuracy: 0.57	                         Avg Total Eval Accuracy: 0.33
# Epoch [49/50]	                         Avg Train Loss: 0.553555	                         Avg Eval Loss: 0.571954	                         Avg Domain Accuracy: 0.48	                         Avg Label Type Accuracy: 0.57	                         Avg Total Eval Accuracy: 0.34
# Epoch [50/50]	                         Avg Train Loss: 0.553383	                         Avg Eval Loss: 0.570101	                         Avg Domain Accuracy: 0.48	                         Avg Label Type Accuracy: 0.57	                         Avg Total Eval Accuracy: 0.37
# weights_save_path: ./weights/raw/zOF8ZCmL.pth
# Labels: ['yes', 'no', 'red', 'blue', '0', '1']
# Number of Common Labels = 6 | n_classes = 6
# V2: 	Train size = 1200             | Val size = 300 | Total = 1500
# Abs: 	Train size = 1200             | Val size = 300 | Total = 1500
# --------------------
