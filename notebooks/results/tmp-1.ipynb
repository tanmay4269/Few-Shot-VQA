# %%
import os
os.chdir('/workspace')
from trainer import * 

cfg = {
    "name": "DANN",
    #
    ### DataLoader ###
    "n_classes": 12,
    "n_types": 4,
    #
    "v2_samples_per_answer": 300,
    "abs_samples_per_answer": 300,
    #
    "v2_samples_per_answer_train": 150,
    "abs_samples_per_answer_train": 150,
    #
    "v2_samples_per_answer_val": 50,
    "abs_samples_per_answer_val": 50,
    "source_domain": "v2",
    
    ### VLModel ###
    "image_encoder": "facebook/dinov2-base",
    "text_encoder": "bert-base-uncased",
    #
    ## Embedder
    "num_attn_heads": 8,
    "fusion_mode": "cat",
    "num_stacked_attn": 1,
    "criss_cross__drop_p": 0.0,
    "post_concat__drop_p": 0.0,
    "embed_attn__add_residual": False,
    "embed_attn__drop_p": 0.0,
    #
    ## Label Classifier
    # 'use_label_type_classifier': False,
    # 'use_label_type_classifier': True,
    "label_classifier__use_bn": True,
    "label_classifier__drop_p": 0.0,
    "label_classifier__repeat_layers": [0, 0],
    #
    ## Domain Classifier
    "domain_classifier__use_bn": True,
    "domain_classifier__drop_p": 0.5,
    "domain_classifier__repeat_layers": [2, 2],
    #
    ### Objective ###
    "domain_adaptation_method": "domain_adversarial",  # 'naive', 'importance_sampling', 'domain_adversarial'
    #
    ### Trainer ###
    "relaxation_period": -1,
    "epochs": 30,
    "batch_size": 150,
    "base_lr": 0.0005,
    "weight_decay": 1e-5,
    #
    ### Logging ###
    # "print_logs": False,
    "print_logs": True,
    "show_plot": True,
    "weights_save_root": "./weights/raw",
}

if True:
    # v2
    cfg["source_domain"] = "v2"
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    v2_ckpt_path = cfg["weights_save_path"]

    trainer.train(show_plot=True)

    # abs
    cfg["source_domain"] = "abs"
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    abs_ckpt_path = cfg["weights_save_path"]

    trainer.train(show_plot=False)
# Out:
# weights_save_path: ./weights/raw/cKILVQir.pth
# Labels: ['yes', 'no', '0', '1', '2', '3', 'red', 'yellow', 'blue', 'green', 'dog', 'cat']
# Number of Common Labels = 12 | n_classes = 12
# V2: 	Train size = 1800             | Val size = 600 | Total = 2400
# Abs: 	Train size = 1800             | Val size = 600 | Total = 2400
# --------------------
# 	 Iter [0/12]	 Loss: 1.408328
# 	 Iter [3/12]	 Loss: 1.184395
# 	 Iter [6/12]	 Loss: 0.992379
# 	 Iter [9/12]	 Loss: 0.838520
# Epoch [1/30]	                         Avg Train Loss: 1.040844	                         Avg Eval Loss: 1.274646	                         Avg Domain Accuracy: 0.50	                         Avg Label Type Accuracy: 0.49	                         Avg Eval Accuracy: 0.15
# 	 Iter [0/12]	 Loss: 0.757982
# 	 Iter [3/12]	 Loss: 0.708226
# 	 Iter [6/12]	 Loss: 1.133922
# 	 Iter [9/12]	 Loss: 0.820460
# Epoch [2/30]	                         Avg Train Loss: 0.896263	                         Avg Eval Loss: 1.224087	                         Avg Domain Accuracy: 0.50	                         Avg Label Type Accuracy: 0.50	                         Avg Eval Accuracy: 0.14
# 	 Iter [0/12]	 Loss: 0.705454
# 	 Iter [3/12]	 Loss: 0.734471
# 	 Iter [6/12]	 Loss: 0.705063
# 	 Iter [9/12]	 Loss: 0.694542
# 	 Iter [3/12]	 Loss: 0.632661
# 	 Iter [6/12]	 Loss: 0.612403
# 	 Iter [9/12]	 Loss: 0.627326
# Epoch [5/30]	                         Avg Train Loss: 0.611402	                         Avg Eval Loss: 1.308795	                         Avg Domain Accuracy: 0.51	                         Avg Label Type Accuracy: 0.53	                         Avg Eval Accuracy: 0.16
# 	 Iter [0/12]	 Loss: 0.594271
# 	 Iter [3/12]	 Loss: 0.609430
# 	 Iter [6/12]	 Loss: 0.574908
# 	 Iter [9/12]	 Loss: 0.592909
# Epoch [6/30]	                         Avg Train Loss: 0.585048	                         Avg Eval Loss: 1.274090	                         Avg Domain Accuracy: 0.50	                         Avg Label Type Accuracy: 0.53	                         Avg Eval Accuracy: 0.17
# 	 Iter [0/12]	 Loss: 0.574793
# 	 Iter [3/12]	 Loss: 0.579560
# 	 Iter [6/12]	 Loss: 0.550879
# 	 Iter [9/12]	 Loss: 0.557820
# Epoch [7/30]	                         Avg Train Loss: 0.566716	                         Avg Eval Loss: 1.285587	                         Avg Domain Accuracy: 0.51	                         Avg Label Type Accuracy: 0.54	                         Avg Eval Accuracy: 0.16
# 	 Iter [0/12]	 Loss: 0.534653
# 	 Iter [3/12]	 Loss: 0.521697
# 	 Iter [6/12]	 Loss: 0.539339
# 	 Iter [9/12]	 Loss: 0.540193
# Epoch [8/30]	                         Avg Train Loss: 0.543139	                         Avg Eval Loss: 1.296817	                         Avg Domain Accuracy: 0.49	                         Avg Label Type Accuracy: 0.54	                         Avg Eval Accuracy: 0.16
# 	 Iter [0/12]	 Loss: 0.528610
# 	 Iter [3/12]	 Loss: 0.500733
# 	 Iter [6/12]	 Loss: 0.500403
# 	 Iter [9/12]	 Loss: 0.509895
# Epoch [9/30]	                         Avg Train Loss: 0.512994	                         Avg Eval Loss: 1.324899	                         Avg Domain Accuracy: 0.51	                         Avg Label Type Accuracy: 0.54	                         Avg Eval Accuracy: 0.17
# 	 Iter [0/12]	 Loss: 0.498895
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 77
#      74 trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
#      75 abs_ckpt_path = cfg["weights_save_path"]
# ---> 77 trainer.train(show_plot=False)
#
# File /workspace/trainer.py:691, in DA_Trainer.train(self, show_plot, optuna_trial, comet_expt)
#     686 self.train_dataloader = zip(
#     687     self.v2_train_dataloader, self.abs_train_dataloader
#     688 )
#     689 self.val_dataloader = zip(self.v2_val_dataloader, self.abs_val_dataloader)
# --> 691 label_loss, domain_loss, label_type_loss, total_loss = self.train_epoch()
#     692 with torch.no_grad():
#     693     (
#     694         eval_loss,
#     695         v2_accuracy,
#    (...)
#     699         domain_accuracy,
#     700     ) = self.eval_epoch()
#
# File /workspace/trainer.py:569, in DA_Trainer.train_epoch(self)
#     561 for i, (
#     562     (v2_i_tokens, v2_q_tokens, v2_label, v2_label_type),
#     563     (abs_i_tokens, abs_q_tokens, abs_label, abs_label_type),
#     564 ) in enumerate(self.train_dataloader):
#     566     self.alpha = self.get_alpha(i, self.num_train_batches)
#     568     (label_loss, domain_loss, label_type_loss, total_loss), _ = (
# --> 569         self.process_input(
#     570             v2_i_tokens,
#     571             v2_q_tokens,
#     572             v2_label,
#     573             v2_label_type,
#     574             abs_i_tokens,
#     575             abs_q_tokens,
#     576             abs_label,
#     577             abs_label_type,
#     578             self.alpha,
#     579         )
#     580     )
#     582     label_loss_meter.update(label_loss.item())
#     583     domain_loss_meter.update(domain_loss.item())
#
# File /workspace/trainer.py:522, in DA_Trainer.process_input(self, v2_i_tokens, v2_q_tokens, v2_label, v2_label_type, abs_i_tokens, abs_q_tokens, abs_label, abs_label_type, alpha)
#     519 abs_q_tokens = {key: value.cuda() for key, value in abs_q_tokens.items()}
#     521 v2_logits = self.model(v2_i_tokens, v2_q_tokens, alpha)
# --> 522 abs_logits = self.model(abs_i_tokens, abs_q_tokens, alpha)
#     524 v2_label, abs_label = v2_label.cuda(), abs_label.cuda()
#     525 v2_label_type, abs_label_type = v2_label_type.cuda(), abs_label_type.cuda()
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /workspace/models/models.py:245, in VLModel_IS.forward(self, i_tokens, q_tokens, alpha)
#     244 def forward(self, i_tokens, q_tokens, alpha=None):
# --> 245     embedding = self.get_embedding(i_tokens, q_tokens)
#     246     embedding = embedding.squeeze(1)
#     248     domain_features = embedding if not alpha or not self.grad_reversal else ReverseLayerF.apply(embedding, alpha)
#
# File /workspace/models/models.py:152, in VLModel.get_embedding(self, i_tokens, q_tokens)
#     150 with torch.no_grad():
#     151     i_embeddings = self.i_encoder(**i_tokens).last_hidden_state
# --> 152     q_embeddings = self.q_encoder(**q_tokens).last_hidden_state
#     154 for stack in range(self.num_stacked_attn):
#     155     # Cross Attention
#     156     i_attended, q_attended = self.cross_attn(
#     157         i_embeddings, q_embeddings, self.attn_q2i[stack], self.attn_i2q[stack]
#     158     )
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /opt/conda/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:1107, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1100         extended_attention_mask = _prepare_4d_causal_attention_mask_for_sdpa(
#    1101             attention_mask,
#    1102             input_shape,
#    1103             embedding_output,
#    1104             past_key_values_length,
#    1105         )
#    1106     else:
# -> 1107         extended_attention_mask = _prepare_4d_attention_mask_for_sdpa(
#    1108             attention_mask, embedding_output.dtype, tgt_len=seq_length
#    1109         )
#    1110 else:
#    1111     # We can provide a self-attention mask of dimensions [batch_size, from_seq_length, to_seq_length]
#    1112     # ourselves in which case we just need to make it broadcastable to all heads.
#    1113     extended_attention_mask = self.get_extended_attention_mask(attention_mask, input_shape)
#
# File /opt/conda/lib/python3.11/site-packages/transformers/modeling_attn_mask_utils.py:452, in _prepare_4d_attention_mask_for_sdpa(mask, dtype, tgt_len)
#     450     return None
#     451 else:
# --> 452     return AttentionMaskConverter._expand_mask(mask=mask, dtype=dtype, tgt_len=tgt_len)
#
# File /opt/conda/lib/python3.11/site-packages/transformers/modeling_attn_mask_utils.py:174, in AttentionMaskConverter._expand_mask(mask, dtype, tgt_len)
#     170         mask.masked_fill_(context_mask, torch.finfo(dtype).min)
#     172     return mask[None, None, :, :].expand(bsz, 1, tgt_len, tgt_len + past_key_values_length)
# --> 174 @staticmethod
#     175 def _expand_mask(mask: torch.Tensor, dtype: torch.dtype, tgt_len: Optional[int] = None):
#     176     """
#     177     Expands attention_mask from `[bsz, seq_len]` to `[bsz, 1, tgt_seq_len, src_seq_len]`.
#     178     """
#     179     bsz, src_len = mask.size()
#
# KeyboardInterrupt:
