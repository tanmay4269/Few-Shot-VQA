# %%
import os
os.chdir('/workspace')
from trainer import * 

cfg = {
    "name": "DANN",
    #
    ### DataLoader ###
    # "n_classes": 12,
    # "n_types": 4,

    "n_classes": 4,
    "n_types": 2,

    'label_type_to_labels' : {
        'yes_no': ['yes', 'no'],
        'colors': ['red', 'blue'],
    },

    #
    "v2_samples_per_answer": 300,
    "abs_samples_per_answer": 300,
    #
    "v2_samples_per_answer_train": 200,
    "abs_samples_per_answer_train": 200,
    #
    "v2_samples_per_answer_val": 50,
    "abs_samples_per_answer_val": 50,
    "source_domain": "v2",
    
    ### VLModel ###
    "image_encoder": "facebook/dinov2-base",
    "text_encoder": "bert-base-uncased",
    #
    ## Embedder
    "num_attn_heads": 8,
    "fusion_mode": "cat",
    "num_stacked_attn": 1,
    "criss_cross__drop_p": 0.0,
    "post_concat__drop_p": 0.0,
    "embed_attn__add_residual": False,
    "embed_attn__drop_p": 0.0,
    #
    ## Label Classifier
    "label_classifier__use_bn": False,
    "label_classifier__drop_p": 0.0,
    "label_classifier__repeat_layers": [2, 2],
    #
    ## Domain Classifier
    "domain_classifier__use_bn": True,
    "domain_classifier__drop_p": 0.5,
    "domain_classifier__repeat_layers": [2, 2],
    #
    ### Objective ###
    "domain_adaptation_method": "domain_adversarial",  # 'naive', 'importance_sampling', 'domain_adversarial'
    #
    ### Trainer ###
    "relaxation_period": 3,
    "epochs": 30,
    "batch_size": 150,
    "base_lr": 1e-4,
    "weight_decay": 1e-5,
    #
    ### Logging ###
    # "print_logs": False,
    "print_logs": True,
    "show_plot": True,
    "weights_save_root": "./weights/raw",
}

if True:
    # v2
    cfg["source_domain"] = "v2"
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    v2_ckpt_path = cfg["weights_save_path"]

    trainer.train(show_plot=True)

    # abs
    cfg["source_domain"] = "abs"
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    abs_ckpt_path = cfg["weights_save_path"]

    trainer.train(show_plot=False)
# Out:
# weights_save_path: ./weights/raw/kk87a687.pth
# Labels: ['yes', 'no', 'red', 'blue']
# Number of Common Labels = 4 | n_classes = 4
# V2: 	Train size = 800             | Val size = 200 | Total = 1000
# Abs: 	Train size = 800             | Val size = 200 | Total = 1000
# --------------------
# Epoch [1/30]	                         Avg Train Loss: 0.903761	                         Avg Eval Loss: 0.908229	                         Avg Domain Accuracy: 0.47	                         Avg Label Type Accuracy: 0.38	                         Avg Total Eval Accuracy: 0.12
# Epoch [2/30]	                         Avg Train Loss: 0.903780	                         Avg Eval Loss: 0.892482	                         Avg Domain Accuracy: 0.55	                         Avg Label Type Accuracy: 0.38	                         Avg Total Eval Accuracy: 0.12
# Epoch [3/30]	                         Avg Train Loss: 0.898581	                         Avg Eval Loss: 0.912921	                         Avg Domain Accuracy: 0.49	                         Avg Label Type Accuracy: 0.38	                         Avg Total Eval Accuracy: 0.38
# Epoch [4/30]	                         Avg Train Loss: 0.899996	                         Avg Eval Loss: 0.897033	                         Avg Domain Accuracy: 0.48	                         Avg Label Type Accuracy: 0.41	                         Avg Total Eval Accuracy: 0.38
# Epoch [5/30]	                         Avg Train Loss: 0.898604	                         Avg Eval Loss: 0.878887	                         Avg Domain Accuracy: 0.53	                         Avg Label Type Accuracy: 0.54	                         Avg Total Eval Accuracy: 0.38
# Epoch [6/30]	                         Avg Train Loss: 0.890262	                         Avg Eval Loss: 0.890328	                         Avg Domain Accuracy: 0.52	                         Avg Label Type Accuracy: 0.51	                         Avg Total Eval Accuracy: 0.21
# Epoch [7/30]	                         Avg Train Loss: 0.882840	                         Avg Eval Loss: 0.876276	                         Avg Domain Accuracy: 0.50	                         Avg Label Type Accuracy: 0.56	                         Avg Total Eval Accuracy: 0.29
# Epoch [8/30]	                         Avg Train Loss: 0.855240	                         Avg Eval Loss: 0.822718	                         Avg Domain Accuracy: 0.50	                         Avg Label Type Accuracy: 0.57	                         Avg Total Eval Accuracy: 0.23
# Epoch [9/30]	                         Avg Train Loss: 0.764085	                         Avg Eval Loss: 0.701886	                         Avg Domain Accuracy: 0.49	                         Avg Label Type Accuracy: 0.61	                         Avg Total Eval Accuracy: 0.26
# Epoch [10/30]	                         Avg Train Loss: 0.607798	                         Avg Eval Loss: 0.571620	                         Avg Domain Accuracy: 0.48	                         Avg Label Type Accuracy: 0.62	                         Avg Total Eval Accuracy: 0.26
# Epoch [11/30]	                         Avg Train Loss: 0.554866	                         Avg Eval Loss: 0.555238	                         Avg Domain Accuracy: 0.51	                         Avg Label Type Accuracy: 0.62	                         Avg Total Eval Accuracy: 0.25
# Epoch [12/30]	                         Avg Train Loss: 0.559847	                         Avg Eval Loss: 0.528040	                         Avg Domain Accuracy: 0.52	                         Avg Label Type Accuracy: 0.62	                         Avg Total Eval Accuracy: 0.25
# Epoch [13/30]	                         Avg Train Loss: 0.563144	                         Avg Eval Loss: 0.585366	                         Avg Domain Accuracy: 0.49	                         Avg Label Type Accuracy: 0.62	                         Avg Total Eval Accuracy: 0.50
# Epoch [14/30]	                         Avg Train Loss: 0.548944	                         Avg Eval Loss: 0.543427	                         Avg Domain Accuracy: 0.51	                         Avg Label Type Accuracy: 0.62	                         Avg Total Eval Accuracy: 0.50
# Epoch [15/30]	                         Avg Train Loss: 0.558091	                         Avg Eval Loss: 0.588768	                         Avg Domain Accuracy: 0.50	                         Avg Label Type Accuracy: 0.62	                         Avg Total Eval Accuracy: 0.25
# Epoch [16/30]	                         Avg Train Loss: 0.560536	                         Avg Eval Loss: 0.544932	                         Avg Domain Accuracy: 0.51	                         Avg Label Type Accuracy: 0.62	                         Avg Total Eval Accuracy: 0.49
# Epoch [17/30]	                         Avg Train Loss: 0.550955	                         Avg Eval Loss: 0.602567	                         Avg Domain Accuracy: 0.54	                         Avg Label Type Accuracy: 0.62	                         Avg Total Eval Accuracy: 0.26
# Epoch [18/30]	                         Avg Train Loss: 0.550742	                         Avg Eval Loss: 0.546180	                         Avg Domain Accuracy: 0.53	                         Avg Label Type Accuracy: 0.62	                         Avg Total Eval Accuracy: 0.25
# Epoch [19/30]	                         Avg Train Loss: 0.544142	                         Avg Eval Loss: 0.546340	                         Avg Domain Accuracy: 0.48	                         Avg Label Type Accuracy: 0.62	                         Avg Total Eval Accuracy: 0.25
# Epoch [20/30]	                         Avg Train Loss: 0.547942	                         Avg Eval Loss: 0.546129	                         Avg Domain Accuracy: 0.52	                         Avg Label Type Accuracy: 0.62	                         Avg Total Eval Accuracy: 0.41
# Epoch [21/30]	                         Avg Train Loss: 0.546700	                         Avg Eval Loss: 0.563887	                         Avg Domain Accuracy: 0.49	                         Avg Label Type Accuracy: 0.62	                         Avg Total Eval Accuracy: 0.50
# Epoch [22/30]	                         Avg Train Loss: 0.548938	                         Avg Eval Loss: 0.545773	                         Avg Domain Accuracy: 0.52	                         Avg Label Type Accuracy: 0.62	                         Avg Total Eval Accuracy: 0.50
# Epoch [23/30]	                         Avg Train Loss: 0.548884	                         Avg Eval Loss: 0.538067	                         Avg Domain Accuracy: 0.53	                         Avg Label Type Accuracy: 0.62	                         Avg Total Eval Accuracy: 0.25
# Epoch [24/30]	                         Avg Train Loss: 0.544371	                         Avg Eval Loss: 0.549945	                         Avg Domain Accuracy: 0.50	                         Avg Label Type Accuracy: 0.62	                         Avg Total Eval Accuracy: 0.28
# Epoch [25/30]	                         Avg Train Loss: 0.544958	                         Avg Eval Loss: 0.532774	                         Avg Domain Accuracy: 0.51	                         Avg Label Type Accuracy: 0.62	                         Avg Total Eval Accuracy: 0.48
# Epoch [26/30]	                         Avg Train Loss: 0.547789	                         Avg Eval Loss: 0.553173	                         Avg Domain Accuracy: 0.48	                         Avg Label Type Accuracy: 0.62	                         Avg Total Eval Accuracy: 0.50
# Epoch [27/30]	                         Avg Train Loss: 0.542254	                         Avg Eval Loss: 0.550550	                         Avg Domain Accuracy: 0.48	                         Avg Label Type Accuracy: 0.62	                         Avg Total Eval Accuracy: 0.50
# Epoch [28/30]	                         Avg Train Loss: 0.541610	                         Avg Eval Loss: 0.533995	                         Avg Domain Accuracy: 0.51	                         Avg Label Type Accuracy: 0.62	                         Avg Total Eval Accuracy: 0.50
# Epoch [29/30]	                         Avg Train Loss: 0.544851	                         Avg Eval Loss: 0.539113	                         Avg Domain Accuracy: 0.51	                         Avg Label Type Accuracy: 0.62	                         Avg Total Eval Accuracy: 0.27
# Epoch [30/30]	                         Avg Train Loss: 0.554911	                         Avg Eval Loss: 0.549566	                         Avg Domain Accuracy: 0.48	                         Avg Label Type Accuracy: 0.62	                         Avg Total Eval Accuracy: 0.26
# weights_save_path: ./weights/raw/bNsNvF0N.pth
