# %% [markdown]
# ## Domain Adversarial

# %%
import os
os.chdir('/workspace')

from trainer import *

cfg = {
    ### META ###
    'name': 'DANN',

    ### DataLoader ###
    'n_classes': 10,
    'labels': [
        'yes', 'no',
        '0', '1', '2', '3',  
        'red', 'yellow', 'blue', 'green', 
    ],
    'v2_samples_per_answer': 300,
    'abs_samples_per_answer': 300,

    'v2_samples_per_answer_train': 200,
    'v2_samples_per_answer_val': 50,

    'abs_samples_per_answer_train': 200,
    'abs_samples_per_answer_val': 50,

    'source_domain': 'abs',
    
    ### VLModel ###
    'image_encoder': 'facebook/dinov2-base',
    'text_encoder': 'bert-base-uncased',
    
    ## Embedder
    'num_attn_heads': 8,
    'fusion_mode': 'cat',
    'num_stacked_attn': 1, 
    
    'criss_cross__drop_p': 0.0,
    'post_concat__drop_p': 0.0, 
    'embed_attn__add_residual': False,
    'embed_attn__drop_p': 0.0,

    ## Label Classifier
    'label_classifier__use_bn': False,
    'label_classifier__drop_p': 0.0,
    'label_classifier__repeat_layers': [0, 0],

    ## Domain Classifier
    'domain_classifier__use_bn': True,
    'domain_classifier__drop_p': 0.5,
    'domain_classifier__repeat_layers': [2, 2], 

    ### Objective ###
    # loss fn
    'domain_adaptation_method': 'domain_adversarial',  # 'naive', 'importance_sampling', 'domain_adversarial'

    ### Trainer ###
    'relaxation_period': 3,  # epochs to wait where accuracy is dropping 
                            # below moving average before ending the run
                            # (-1 to disable it)
    
    'batch_size': 150,
    'epochs': 30,
    'base_lr': 5e-4,
    'weight_decay': 5e-4,

    ### Logging ###
    'print_logs': True,
    # 'print_logs': False,

    'weights_save_root': './weights/raw'
}

if True:
    # v2
    cfg['source_domain'] = 'v2'
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    v2_ckpt_path = cfg['weights_save_path']

    trainer.train(show_plot=True)

    # abs
    cfg['source_domain'] = 'abs'
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    abs_ckpt_path = cfg['weights_save_path']

    trainer.train(show_plot=True)
# Out:
# weights_save_path: ./weights/raw/SO3x84UY.pth
# Number of Common Labels = 10 | n_classes = 10
# Labels: ['yes', 'no', '0', '1', '2', '3', 'red', 'yellow', 'blue', 'green']
# V2: 	Train size = 2000	             | Val size = 500 | Total = 2500
# Abs: 	Train size = 2000	             | Val size = 500 | Total = 2500
# --------------------
# Epoch [1/30]	                         Avg Train Loss: 1.523337	                         Avg Eval Loss: 1.443615	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.20
# Epoch [2/30]	                         Avg Train Loss: 1.282406	                         Avg Eval Loss: 1.184273	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.22
# Epoch [3/30]	                         Avg Train Loss: 1.124191	                         Avg Eval Loss: 1.126298	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.30
# Epoch [4/30]	                         Avg Train Loss: 1.019402	                         Avg Eval Loss: 1.006474	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.30
# Epoch [5/30]	                         Avg Train Loss: 1.003246	                         Avg Eval Loss: 1.039602	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.31
# Epoch [6/30]	                         Avg Train Loss: 1.002207	                         Avg Eval Loss: 1.007996	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.31
# Epoch [7/30]	                         Avg Train Loss: 0.996833	                         Avg Eval Loss: 0.995740	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.31
# Epoch [8/30]	                         Avg Train Loss: 0.984142	                         Avg Eval Loss: 0.983901	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.33
# Epoch [9/30]	                         Avg Train Loss: 0.972065	                         Avg Eval Loss: 0.961935	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.36
# Epoch [10/30]	                         Avg Train Loss: 0.961743	                         Avg Eval Loss: 0.997204	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.38
# Epoch [11/30]	                         Avg Train Loss: 0.939687	                         Avg Eval Loss: 0.984361	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.35
# Epoch [12/30]	                         Avg Train Loss: 0.912877	                         Avg Eval Loss: 0.931441	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.37
# Epoch [13/30]	                         Avg Train Loss: 0.896981	                         Avg Eval Loss: 0.923131	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.40
# Epoch [14/30]	                         Avg Train Loss: 0.880595	                         Avg Eval Loss: 1.085255	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.37
# Epoch [15/30]	                         Avg Train Loss: 0.873956	                         Avg Eval Loss: 0.935602	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.40
# Epoch [16/30]	                         Avg Train Loss: 0.844756	                         Avg Eval Loss: 0.931547	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.43
# Epoch [17/30]	                         Avg Train Loss: 0.831518	                         Avg Eval Loss: 0.949093	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.41
# Epoch [18/30]	                         Avg Train Loss: 0.807962	                         Avg Eval Loss: 0.971038	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.40
# Epoch [19/30]	                         Avg Train Loss: 0.769997	                         Avg Eval Loss: 1.120271	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.42
# Epoch [20/30]	                         Avg Train Loss: 0.770282	                         Avg Eval Loss: 0.991942	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.45
# Epoch [21/30]	                         Avg Train Loss: 0.729917	                         Avg Eval Loss: 1.144316	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.44
# Epoch [22/30]	                         Avg Train Loss: 0.715118	                         Avg Eval Loss: 1.040166	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.44
# Epoch [23/30]	                         Avg Train Loss: 0.692231	                         Avg Eval Loss: 1.055200	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.44
# Epoch [24/30]	                         Avg Train Loss: 0.665305	                         Avg Eval Loss: 1.134543	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.45
# Epoch [25/30]	                         Avg Train Loss: 0.645491	                         Avg Eval Loss: 1.262644	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.43
# Epoch [26/30]	                         Avg Train Loss: 0.635872	                         Avg Eval Loss: 1.297112	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.43
# Epoch [27/30]	                         Avg Train Loss: 0.609697	                         Avg Eval Loss: 1.286180	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.42
# Epoch [28/30]	                         Avg Train Loss: 0.596219	                         Avg Eval Loss: 1.289788	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.42
# Epoch [29/30]	                         Avg Train Loss: 0.579463	                         Avg Eval Loss: 1.391068	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.41
# Epoch [30/30]	                         Avg Train Loss: 0.573188	                         Avg Eval Loss: 1.396591	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.42
# weights_save_path: ./weights/raw/Z2iYh6DQ.pth
# Number of Common Labels = 10 | n_classes = 10
# Labels: ['yes', 'no', '0', '1', '2', '3', 'red', 'yellow', 'blue', 'green']
# V2: 	Train size = 2000	             | Val size = 500 | Total = 2500
# Abs: 	Train size = 2000	             | Val size = 500 | Total = 2500
# --------------------
# Epoch [1/30]	                         Avg Train Loss: 1.526237	                         Avg Eval Loss: 1.492582	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.15
# Epoch [2/30]	                         Avg Train Loss: 1.357875	                         Avg Eval Loss: 1.324461	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.28
# Epoch [3/30]	                         Avg Train Loss: 1.058814	                         Avg Eval Loss: 1.015476	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.32
# Epoch [4/30]	                         Avg Train Loss: 1.014025	                         Avg Eval Loss: 1.021397	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.30
# Epoch [5/30]	                         Avg Train Loss: 0.994078	                         Avg Eval Loss: 1.022237	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.33
# Epoch [6/30]	                         Avg Train Loss: 0.990558	                         Avg Eval Loss: 0.990165	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.34
# Epoch [7/30]	                         Avg Train Loss: 0.964801	                         Avg Eval Loss: 0.974968	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.39
# Epoch [8/30]	                         Avg Train Loss: 0.946024	                         Avg Eval Loss: 0.983916	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.39
# Epoch [9/30]	                         Avg Train Loss: 0.927713	                         Avg Eval Loss: 0.932914	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.39
# Epoch [10/30]	                         Avg Train Loss: 0.909747	                         Avg Eval Loss: 0.979463	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.38
# Epoch [11/30]	                         Avg Train Loss: 0.895977	                         Avg Eval Loss: 0.908156	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.41
# Epoch [12/30]	                         Avg Train Loss: 0.866606	                         Avg Eval Loss: 0.921011	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.41
# Epoch [13/30]	                         Avg Train Loss: 0.843276	                         Avg Eval Loss: 0.917446	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.45
# Epoch [14/30]	                         Avg Train Loss: 0.812351	                         Avg Eval Loss: 0.937288	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.42
# Epoch [15/30]	                         Avg Train Loss: 0.793098	                         Avg Eval Loss: 0.949402	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.41
# Epoch [16/30]	                         Avg Train Loss: 0.780830	                         Avg Eval Loss: 1.026832	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.43
# Epoch [17/30]	                         Avg Train Loss: 0.764376	                         Avg Eval Loss: 1.025979	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.42
# Epoch [18/30]	                         Avg Train Loss: 0.752469	                         Avg Eval Loss: 1.239382	                         Avg Domain Accuracy: 0.54	                         Avg Eval Accuracy: 0.41
# Epoch [19/30]	                         Avg Train Loss: 0.740100	                         Avg Eval Loss: 1.066242	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.44
# Epoch [20/30]	                         Avg Train Loss: 0.701894	                         Avg Eval Loss: 1.107411	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.44
# Epoch [21/30]	                         Avg Train Loss: 0.697887	                         Avg Eval Loss: 1.237607	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.45
# Epoch [22/30]	                         Avg Train Loss: 0.685635	                         Avg Eval Loss: 1.101814	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.45
# Epoch [23/30]	                         Avg Train Loss: 0.663855	                         Avg Eval Loss: 1.287528	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.41
# Epoch [24/30]	                         Avg Train Loss: 0.643169	                         Avg Eval Loss: 1.323153	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.45
# Epoch [25/30]	                         Avg Train Loss: 0.629620	                         Avg Eval Loss: 1.395429	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.41
# Epoch [26/30]	                         Avg Train Loss: 0.624131	                         Avg Eval Loss: 1.387796	                         Avg Domain Accuracy: 0.46	                         Avg Eval Accuracy: 0.44
# Epoch [27/30]	                         Avg Train Loss: 0.604076	                         Avg Eval Loss: 1.417481	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.41
# Epoch [28/30]	                         Avg Train Loss: 0.586772	                         Avg Eval Loss: 1.402936	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.44
# Epoch [29/30]	                         Avg Train Loss: 0.571980	                         Avg Eval Loss: 1.474146	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.43
# Epoch [30/30]	                         Avg Train Loss: 0.561850	                         Avg Eval Loss: 1.475453	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.43

# %%
# v2_ckpt_path = './weights/raw/name=DANN__n_classes=10__v2_samples_per_answer=300__abs_samples_per_answer=150__source_domain=v2__base_lr=0.001__domain_adaptation_method=domain_adversarial__.pth'

# abs_ckpt_path = './weights/raw/name=DANN__n_classes=10__v2_samples_per_answer=300__abs_samples_per_answer=150__source_domain=abs__base_lr=0.001__domain_adaptation_method=domain_adversarial__.pth'

# %%
cfg['v2_ckpt'] = v2_ckpt_path
cfg['abs_ckpt'] = abs_ckpt_path

# %% [markdown]
# ## Evaluating

# %%
(v2_train_data, v2_val_data), (abs_train_data, abs_val_data), labels = data_processing_v2(cfg, vqa_v2, vqa_abs)
model = VLModel(cfg, return_embeddings=True).cuda()

def eval_domain_adaptation(eval_dataset, model_ckpt, evaluate_train=False):
    if eval_dataset == 'v2':
        train_data, val_data = v2_train_data, v2_val_data
    elif eval_dataset == 'abs':
        train_data, val_data = abs_train_data, abs_val_data

    train_dataset = VQADataset(cfg, train_data)
    val_dataset = VQADataset(cfg, val_data)

    train_dataloader = DataLoader(train_dataset, batch_size=cfg['batch_size'], shuffle=True)
    val_dataloader = DataLoader(val_dataset, batch_size=cfg['batch_size'], shuffle=True)

    if model_ckpt == 'v2':
        ckpt = cfg['v2_ckpt']
    elif model_ckpt == 'abs':
        ckpt = cfg['abs_ckpt']

    state_dict = torch.load(ckpt, weights_only=True)
    model.load_state_dict(state_dict, strict=False)

    dataloader = val_dataloader if not evaluate_train else train_dataloader

    model.eval()
    correct, total = 0, 0
    embeddings = None

    with torch.no_grad():
        for i_tokens, q_tokens, label in dataloader:
            i_tokens = {key: value.cuda() for key, value in i_tokens.items()}
            q_tokens = {key: value.cuda() for key, value in q_tokens.items()}
            label = label.cuda()
            
            logits, embedding = model(i_tokens, q_tokens)
            embeddings = np.concatenate((embeddings, embedding), axis=0) if embeddings is not None else embedding

            # Compute accuracy
            _, predicted_indices = torch.max(logits, dim=1)
            label_indices = torch.argmax(label, dim=1)
            is_correct = (predicted_indices == label_indices)

            total += label.shape[0]
            correct += is_correct.sum().item()

    accuracy = (correct / total)

    source = 'v2 ' if model_ckpt == 'v2' else 'abs'
    target = 'v2 ' if eval_dataset == 'v2' else 'abs'
    split = 'train set' if evaluate_train else 'val set  '
    print(f'{source} -> {target} | {split} \t accuracy = {accuracy*100:.2f}%')
    
    return embeddings
# Out:
# Number of Common Labels = 10 | n_classes = 10
# Labels: ['yes', 'no', '0', '1', '2', '3', 'red', 'yellow', 'blue', 'green']
# V2: 	Train size = 2000	             | Val size = 500 | Total = 2500
# Abs: 	Train size = 2000	             | Val size = 500 | Total = 2500
# --------------------

# %%
# v2 -> v2
v2_val_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='v2', evaluate_train=False)
v2_train_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='v2', evaluate_train=True)

# abs -> abs
abs_val_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='abs', evaluate_train=False)
abs_train_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='abs', evaluate_train=True)
# Out:
# v2  -> v2  | val set   	 accuracy = 34.40%
# v2  -> v2  | train set 	 accuracy = 44.70%
# abs -> abs | val set   	 accuracy = 50.60%
# abs -> abs | train set 	 accuracy = 53.55%

# %%
# v2 -> abs
v2_abs_val_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='abs', evaluate_train=False)
v2_abs_train_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='abs', evaluate_train=True)

# abs -> v2
abs_v2_val_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='v2', evaluate_train=False)
abs_v2_train_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='v2', evaluate_train=True)
# Out:
# v2  -> abs | val set   	 accuracy = 44.80%
# v2  -> abs | train set 	 accuracy = 50.55%
# abs -> v2  | val set   	 accuracy = 33.80%
# abs -> v2  | train set 	 accuracy = 46.75%

# %% [markdown]
# ## Visualizing embeddings

# %%
from sklearn.manifold import TSNE
import matplotlib.patches as mpatches

def plot_tsne(embeddings, plot_labels, perplexities, title=''):
    n_plots = len(perplexities)
    fig, axes = plt.subplots(1, n_plots, figsize=(6 * n_plots, 6))
    
    for idx, perplexity in enumerate(perplexities):
        tsne = TSNE(n_components=2, perplexity=perplexity, random_state=42)
        tsne_embeddings = tsne.fit_transform(embeddings)
        
        colors = {'vv': 'blue', 'aa': 'red', 'va': 'orange', 'av': 'violet'}
        ax = axes[idx]
        for i, plot_label in enumerate(plot_labels):
                
            ax.scatter(tsne_embeddings[i, 0], tsne_embeddings[i, 1], color=colors[plot_label])
            ax.text(tsne_embeddings[i, 0] + 0.1, tsne_embeddings[i, 1], '', fontsize=9)
        
        ax.set_title(f'Perplexity = {perplexity}')
    
    custom_legend = [mpatches.Patch(color=colors[label], label=label) for label in set(plot_labels)]
    fig.legend(handles=custom_legend)
    fig.suptitle(title, fontsize=16)

    plt.tight_layout()
    plt.show()

# %%
n_v2 = len(v2_val_embeddings)
n_abs = len(abs_val_embeddings)

# v2 -> v2
plot_tsne(v2_val_embeddings, ['vv'] * n_v2, perplexities=[2,4,8,16,32], title='v2->v2 (val set)')
plot_tsne(v2_train_embeddings, ['vv'] * n_v2, perplexities=[2,4,8,16,32], title='v2->v2 (train set)')

# abs -> abs
plot_tsne(abs_val_embeddings, ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='abs->abs (val set)')
plot_tsne(abs_train_embeddings, ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='abs->abs (train set)')

# combined plot
val_embeddings = np.concatenate((v2_val_embeddings, abs_val_embeddings), axis=0)
plot_tsne(val_embeddings, ['vv'] * n_v2 + ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='Same Domain (val set)')

train_embeddings = np.concatenate((v2_train_embeddings, abs_train_embeddings), axis=0)
plot_tsne(train_embeddings, ['vv'] * n_v2 + ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='Same Domain (train set)')

# %%
# v2 -> abs
plot_tsne(v2_abs_val_embeddings, ['va'] * n_abs, perplexities=[2,4,8,16,32], title='v2->abs (val set)')
plot_tsne(v2_abs_train_embeddings, ['va'] * n_abs, perplexities=[2,4,8,16,32], title='v2->abs (train set)')

# abs -> v2
plot_tsne(abs_v2_val_embeddings, ['av'] * n_v2, perplexities=[2,4,8,16,32], title='abs->v2 (val set)')
plot_tsne(abs_v2_train_embeddings, ['av'] * n_v2, perplexities=[2,4,8,16,32], title='abs->v2 (train set)')

# combined plot
val_embeddings = np.concatenate((v2_abs_val_embeddings, abs_v2_val_embeddings), axis=0)
plot_tsne(val_embeddings, ['va'] * n_abs + ['av'] * n_v2, perplexities=[2,4,8,16,32], title='Cross Domain (val set)')

train_embeddings = np.concatenate((v2_abs_train_embeddings, abs_v2_train_embeddings), axis=0)
plot_tsne(train_embeddings, ['va'] * n_abs + ['av'] * n_v2, perplexities=[2,4,8,16,32], title='Cross Domain (train set)')
