# %% [markdown]
# ## Domain Adversarial

# %%
import os
os.chdir('/workspace')

from trainer import *

cfg = {
    ### META ###
    'name': 'DANN',

    ### DataLoader ###
    'n_classes': 10,
    'labels': [
        'yes', 'no',
        '0', '1', '2', '3',  
        'red', 'yellow', 'blue', 'green', 
    ],
    'v2_samples_per_answer': 300,
    'abs_samples_per_answer': 300,

    'v2_samples_per_answer_train': 200,
    'v2_samples_per_answer_val': 50,

    'abs_samples_per_answer_train': 200,
    'abs_samples_per_answer_val': 50,

    'source_domain': 'abs',
    
    ### VLModel ###
    'image_encoder': 'facebook/dinov2-base',
    'text_encoder': 'bert-base-uncased',
    
    ## Embedder
    'num_attn_heads': 8,
    'fusion_mode': 'cat',
    'num_stacked_attn': 1, 
    
    'criss_cross__drop_p': 0.5,
    'post_concat__drop_p': 0.0, 
    'embed_attn__add_residual': False,
    'embed_attn__drop_p': 0.0,

    ## Label Classifier
    'label_classifier__use_bn': False,
    'label_classifier__drop_p': 0.0,
    'label_classifier__repeat_layers': [0, 0],

    ## Domain Classifier
    'domain_classifier__use_bn': True,
    'domain_classifier__drop_p': 0.5,
    'domain_classifier__repeat_layers': [2, 2], 

    ### Objective ###
    # loss fn
    'domain_adaptation_method': 'domain_adversarial',  # 'naive', 'importance_sampling', 'domain_adversarial'

    ### Trainer ###
    'relaxation_period': 3,  # epochs to wait where accuracy is dropping 
                            # below moving average before ending the run
                            # (-1 to disable it)
    
    'batch_size': 150,
    'epochs': 30,
    'base_lr': 5e-4,
    'weight_decay': 5e-4,

    ### Logging ###
    'print_logs': True,
    # 'print_logs': False,

    'weights_save_root': './weights/raw'
}

if True:
    # v2
    cfg['source_domain'] = 'v2'
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    v2_ckpt_path = cfg['weights_save_path']

    trainer.train(show_plot=True)

    # abs
    cfg['source_domain'] = 'abs'
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    abs_ckpt_path = cfg['weights_save_path']

    trainer.train(show_plot=True)
# Out:
# weights_save_path: ./weights/raw/zYc0jPxX.pth
# Number of Common Labels = 10 | n_classes = 10
# Labels: ['yes', 'no', '0', '1', '2', '3', 'red', 'yellow', 'blue', 'green']
# V2: 	Train size = 2000	             | Val size = 500 | Total = 2500
# Abs: 	Train size = 2000	             | Val size = 500 | Total = 2500
# --------------------
# Epoch [1/30]	                         Avg Train Loss: 1.527228	                         Avg Eval Loss: 1.455293	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.20
# Epoch [2/30]	                         Avg Train Loss: 1.226684	                         Avg Eval Loss: 1.138364	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.28
# Epoch [3/30]	                         Avg Train Loss: 1.028077	                         Avg Eval Loss: 0.999953	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.31
# Epoch [4/30]	                         Avg Train Loss: 1.001168	                         Avg Eval Loss: 1.003746	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.31
# Epoch [5/30]	                         Avg Train Loss: 0.994244	                         Avg Eval Loss: 0.977274	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.31
# Epoch [6/30]	                         Avg Train Loss: 0.984101	                         Avg Eval Loss: 0.992569	                         Avg Domain Accuracy: 0.46	                         Avg Eval Accuracy: 0.32
# Epoch [7/30]	                         Avg Train Loss: 0.980414	                         Avg Eval Loss: 0.986279	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.35
# Epoch [8/30]	                         Avg Train Loss: 0.966082	                         Avg Eval Loss: 0.960900	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.38
# Epoch [9/30]	                         Avg Train Loss: 0.942915	                         Avg Eval Loss: 0.955009	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.39
# Epoch [10/30]	                         Avg Train Loss: 0.924603	                         Avg Eval Loss: 0.969762	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.41
# Epoch [11/30]	                         Avg Train Loss: 0.904626	                         Avg Eval Loss: 0.944504	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.41
# Epoch [12/30]	                         Avg Train Loss: 0.876586	                         Avg Eval Loss: 0.939715	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.44
# Epoch [13/30]	                         Avg Train Loss: 0.849339	                         Avg Eval Loss: 0.956129	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.44
# Epoch [14/30]	                         Avg Train Loss: 0.829784	                         Avg Eval Loss: 0.954209	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.42
# Epoch [15/30]	                         Avg Train Loss: 0.799710	                         Avg Eval Loss: 0.975825	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.42
# Epoch [16/30]	                         Avg Train Loss: 0.776462	                         Avg Eval Loss: 0.979119	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.44
# Epoch [17/30]	                         Avg Train Loss: 0.751923	                         Avg Eval Loss: 1.091049	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.41
# Epoch [18/30]	                         Avg Train Loss: 0.729231	                         Avg Eval Loss: 1.103690	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.46
# Epoch [19/30]	                         Avg Train Loss: 0.721804	                         Avg Eval Loss: 1.057031	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.41
# Epoch [20/30]	                         Avg Train Loss: 0.719725	                         Avg Eval Loss: 1.123085	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.45
# Epoch [21/30]	                         Avg Train Loss: 0.676527	                         Avg Eval Loss: 1.123515	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.43
# Epoch [22/30]	                         Avg Train Loss: 0.653252	                         Avg Eval Loss: 1.175587	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.44
# Epoch [23/30]	                         Avg Train Loss: 0.633929	                         Avg Eval Loss: 1.214561	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.42
# Epoch [24/30]	                         Avg Train Loss: 0.626983	                         Avg Eval Loss: 1.329599	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.42
# Epoch [25/30]	                         Avg Train Loss: 0.606011	                         Avg Eval Loss: 1.281620	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.42
# Epoch [26/30]	                         Avg Train Loss: 0.587883	                         Avg Eval Loss: 1.328460	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.42
# Epoch [27/30]	                         Avg Train Loss: 0.573074	                         Avg Eval Loss: 1.371049	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.41
# Epoch [28/30]	                         Avg Train Loss: 0.562340	                         Avg Eval Loss: 1.420698	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.42
# Epoch [29/30]	                         Avg Train Loss: 0.550050	                         Avg Eval Loss: 1.444256	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.41
# Epoch [30/30]	                         Avg Train Loss: 0.545336	                         Avg Eval Loss: 1.461467	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.41
# weights_save_path: ./weights/raw/S97oRLyO.pth
# Number of Common Labels = 10 | n_classes = 10
# Labels: ['yes', 'no', '0', '1', '2', '3', 'red', 'yellow', 'blue', 'green']
# V2: 	Train size = 2000	             | Val size = 500 | Total = 2500
# Abs: 	Train size = 2000	             | Val size = 500 | Total = 2500
# --------------------
# Epoch [1/30]	                         Avg Train Loss: 1.528180	                         Avg Eval Loss: 1.521196	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.10
# Epoch [2/30]	                         Avg Train Loss: 1.334593	                         Avg Eval Loss: 1.189726	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.26
# Epoch [3/30]	                         Avg Train Loss: 1.083102	                         Avg Eval Loss: 1.017146	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.30
# Epoch [4/30]	                         Avg Train Loss: 1.012909	                         Avg Eval Loss: 1.032030	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.30
# Epoch [5/30]	                         Avg Train Loss: 1.003241	                         Avg Eval Loss: 1.020640	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.32
# Epoch [6/30]	                         Avg Train Loss: 0.989499	                         Avg Eval Loss: 1.001163	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.33
# Epoch [7/30]	                         Avg Train Loss: 0.985027	                         Avg Eval Loss: 1.000135	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.36
# Epoch [8/30]	                         Avg Train Loss: 0.973172	                         Avg Eval Loss: 0.971881	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.37
# Epoch [9/30]	                         Avg Train Loss: 0.951205	                         Avg Eval Loss: 0.955718	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.40
# Epoch [10/30]	                         Avg Train Loss: 0.925042	                         Avg Eval Loss: 0.932423	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.40
# Epoch [11/30]	                         Avg Train Loss: 0.895262	                         Avg Eval Loss: 0.931706	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.42
# Epoch [12/30]	                         Avg Train Loss: 0.876447	                         Avg Eval Loss: 0.932680	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.39
# Epoch [13/30]	                         Avg Train Loss: 0.852769	                         Avg Eval Loss: 0.968291	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.43
# Epoch [14/30]	                         Avg Train Loss: 0.833916	                         Avg Eval Loss: 0.986101	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.41
# Epoch [15/30]	                         Avg Train Loss: 0.800726	                         Avg Eval Loss: 0.953395	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.41
# Epoch [16/30]	                         Avg Train Loss: 0.779794	                         Avg Eval Loss: 0.992933	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.42
# Epoch [17/30]	                         Avg Train Loss: 0.760110	                         Avg Eval Loss: 0.989768	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.44
# Epoch [18/30]	                         Avg Train Loss: 0.733187	                         Avg Eval Loss: 1.079661	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.45
# Epoch [19/30]	                         Avg Train Loss: 0.714966	                         Avg Eval Loss: 1.038516	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.45
# Epoch [20/30]	                         Avg Train Loss: 0.691894	                         Avg Eval Loss: 1.057548	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.44
# Epoch [21/30]	                         Avg Train Loss: 0.670152	                         Avg Eval Loss: 1.189135	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.44
# Epoch [22/30]	                         Avg Train Loss: 0.640826	                         Avg Eval Loss: 1.179859	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.43
# Epoch [23/30]	                         Avg Train Loss: 0.617326	                         Avg Eval Loss: 1.280943	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.43
# Epoch [24/30]	                         Avg Train Loss: 0.630669	                         Avg Eval Loss: 1.260106	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.41
# Epoch [25/30]	                         Avg Train Loss: 0.606234	                         Avg Eval Loss: 1.301380	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.42
# Epoch [26/30]	                         Avg Train Loss: 0.594215	                         Avg Eval Loss: 1.257299	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.42
# Epoch [27/30]	                         Avg Train Loss: 0.569988	                         Avg Eval Loss: 1.345923	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.44
# Epoch [28/30]	                         Avg Train Loss: 0.557604	                         Avg Eval Loss: 1.374287	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.45
# Epoch [29/30]	                         Avg Train Loss: 0.542623	                         Avg Eval Loss: 1.378314	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.44
# Epoch [30/30]	                         Avg Train Loss: 0.534632	                         Avg Eval Loss: 1.400398	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.44

# %%
# v2_ckpt_path = './weights/raw/name=DANN__n_classes=10__v2_samples_per_answer=300__abs_samples_per_answer=150__source_domain=v2__base_lr=0.001__domain_adaptation_method=domain_adversarial__.pth'

# abs_ckpt_path = './weights/raw/name=DANN__n_classes=10__v2_samples_per_answer=300__abs_samples_per_answer=150__source_domain=abs__base_lr=0.001__domain_adaptation_method=domain_adversarial__.pth'

# %%
cfg['v2_ckpt'] = v2_ckpt_path
cfg['abs_ckpt'] = abs_ckpt_path

# %% [markdown]
# ## Evaluating

# %%
(v2_train_data, v2_val_data), (abs_train_data, abs_val_data), labels = data_processing_v2(cfg, vqa_v2, vqa_abs)
model = VLModel(cfg, return_embeddings=True).cuda()

def eval_domain_adaptation(eval_dataset, model_ckpt, evaluate_train=False):
    if eval_dataset == 'v2':
        train_data, val_data = v2_train_data, v2_val_data
    elif eval_dataset == 'abs':
        train_data, val_data = abs_train_data, abs_val_data

    train_dataset = VQADataset(cfg, train_data)
    val_dataset = VQADataset(cfg, val_data)

    train_dataloader = DataLoader(train_dataset, batch_size=cfg['batch_size'], shuffle=True)
    val_dataloader = DataLoader(val_dataset, batch_size=cfg['batch_size'], shuffle=True)

    if model_ckpt == 'v2':
        ckpt = cfg['v2_ckpt']
    elif model_ckpt == 'abs':
        ckpt = cfg['abs_ckpt']

    state_dict = torch.load(ckpt, weights_only=True)
    model.load_state_dict(state_dict, strict=False)

    dataloader = val_dataloader if not evaluate_train else train_dataloader

    model.eval()
    correct, total = 0, 0
    embeddings = None

    with torch.no_grad():
        for i_tokens, q_tokens, label in dataloader:
            i_tokens = {key: value.cuda() for key, value in i_tokens.items()}
            q_tokens = {key: value.cuda() for key, value in q_tokens.items()}
            label = label.cuda()
            
            logits, embedding = model(i_tokens, q_tokens)
            embeddings = np.concatenate((embeddings, embedding), axis=0) if embeddings is not None else embedding

            # Compute accuracy
            _, predicted_indices = torch.max(logits, dim=1)
            label_indices = torch.argmax(label, dim=1)
            is_correct = (predicted_indices == label_indices)

            total += label.shape[0]
            correct += is_correct.sum().item()

    accuracy = (correct / total)

    source = 'v2 ' if model_ckpt == 'v2' else 'abs'
    target = 'v2 ' if eval_dataset == 'v2' else 'abs'
    split = 'train set' if evaluate_train else 'val set  '
    print(f'{source} -> {target} | {split} \t accuracy = {accuracy*100:.2f}%')
    
    return embeddings
# Out:
# Number of Common Labels = 10 | n_classes = 10
# Labels: ['yes', 'no', '0', '1', '2', '3', 'red', 'yellow', 'blue', 'green']
# V2: 	Train size = 2000	             | Val size = 500 | Total = 2500
# Abs: 	Train size = 2000	             | Val size = 500 | Total = 2500
# --------------------

# %%
# v2 -> v2
v2_val_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='v2', evaluate_train=False)
v2_train_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='v2', evaluate_train=True)

# abs -> abs
abs_val_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='abs', evaluate_train=False)
abs_train_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='abs', evaluate_train=True)
# Out:
# v2  -> v2  | val set   	 accuracy = 36.40%
# v2  -> v2  | train set 	 accuracy = 54.15%
# abs -> abs | val set   	 accuracy = 48.60%
# abs -> abs | train set 	 accuracy = 52.60%

# %%
# v2 -> abs
v2_abs_val_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='abs', evaluate_train=False)
v2_abs_train_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='abs', evaluate_train=True)

# abs -> v2
abs_v2_val_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='v2', evaluate_train=False)
abs_v2_train_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='v2', evaluate_train=True)
# Out:
# v2  -> abs | val set   	 accuracy = 52.40%
# v2  -> abs | train set 	 accuracy = 60.75%
# abs -> v2  | val set   	 accuracy = 36.80%
# abs -> v2  | train set 	 accuracy = 48.90%

# %% [markdown]
# ## Visualizing embeddings

# %%
from sklearn.manifold import TSNE
import matplotlib.patches as mpatches

def plot_tsne(embeddings, plot_labels, perplexities, title=''):
    n_plots = len(perplexities)
    fig, axes = plt.subplots(1, n_plots, figsize=(6 * n_plots, 6))
    
    for idx, perplexity in enumerate(perplexities):
        tsne = TSNE(n_components=2, perplexity=perplexity, random_state=42)
        tsne_embeddings = tsne.fit_transform(embeddings)
        
        colors = {'vv': 'blue', 'aa': 'red', 'va': 'orange', 'av': 'violet'}
        ax = axes[idx]
        for i, plot_label in enumerate(plot_labels):
                
            ax.scatter(tsne_embeddings[i, 0], tsne_embeddings[i, 1], color=colors[plot_label])
            ax.text(tsne_embeddings[i, 0] + 0.1, tsne_embeddings[i, 1], '', fontsize=9)
        
        ax.set_title(f'Perplexity = {perplexity}')
    
    custom_legend = [mpatches.Patch(color=colors[label], label=label) for label in set(plot_labels)]
    fig.legend(handles=custom_legend)
    fig.suptitle(title, fontsize=16)

    plt.tight_layout()
    plt.show()

# %%
n_v2 = len(v2_val_embeddings)
n_abs = len(abs_val_embeddings)

# v2 -> v2
plot_tsne(v2_val_embeddings, ['vv'] * n_v2, perplexities=[2,4,8,16,32], title='v2->v2 (val set)')
plot_tsne(v2_train_embeddings, ['vv'] * n_v2, perplexities=[2,4,8,16,32], title='v2->v2 (train set)')

# abs -> abs
plot_tsne(abs_val_embeddings, ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='abs->abs (val set)')
plot_tsne(abs_train_embeddings, ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='abs->abs (train set)')

# combined plot
val_embeddings = np.concatenate((v2_val_embeddings, abs_val_embeddings), axis=0)
plot_tsne(val_embeddings, ['vv'] * n_v2 + ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='Same Domain (val set)')

train_embeddings = np.concatenate((v2_train_embeddings, abs_train_embeddings), axis=0)
plot_tsne(train_embeddings, ['vv'] * n_v2 + ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='Same Domain (train set)')

# %%
# v2 -> abs
plot_tsne(v2_abs_val_embeddings, ['va'] * n_abs, perplexities=[2,4,8,16,32], title='v2->abs (val set)')
plot_tsne(v2_abs_train_embeddings, ['va'] * n_abs, perplexities=[2,4,8,16,32], title='v2->abs (train set)')

# abs -> v2
plot_tsne(abs_v2_val_embeddings, ['av'] * n_v2, perplexities=[2,4,8,16,32], title='abs->v2 (val set)')
plot_tsne(abs_v2_train_embeddings, ['av'] * n_v2, perplexities=[2,4,8,16,32], title='abs->v2 (train set)')

# combined plot
val_embeddings = np.concatenate((v2_abs_val_embeddings, abs_v2_val_embeddings), axis=0)
plot_tsne(val_embeddings, ['va'] * n_abs + ['av'] * n_v2, perplexities=[2,4,8,16,32], title='Cross Domain (val set)')

train_embeddings = np.concatenate((v2_abs_train_embeddings, abs_v2_train_embeddings), axis=0)
plot_tsne(train_embeddings, ['va'] * n_abs + ['av'] * n_v2, perplexities=[2,4,8,16,32], title='Cross Domain (train set)')
