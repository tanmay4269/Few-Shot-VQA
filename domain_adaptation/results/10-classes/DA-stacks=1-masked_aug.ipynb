# %% [markdown]
# ## Domain Adversarial

# %%
import os
os.chdir('/workspace')

from trainer import *

cfg = {
    ### META ###
    'name': 'DANN',

    ### DataLoader ###
    'n_classes': 10,
    'labels': [
        'yes', 'no',
        '0', '1', '2', '3',  
        'red', 'yellow', 'blue', 'green', 
    ],
    
    'mask_patches': True,
    
    'v2_samples_per_answer': 300,
    'abs_samples_per_answer': 300,

    'v2_samples_per_answer_train': 200,
    'v2_samples_per_answer_val': 50,

    'abs_samples_per_answer_train': 200,
    'abs_samples_per_answer_val': 50,

    'source_domain': 'abs',
    
    ### VLModel ###
    'image_encoder': 'facebook/dinov2-base',
    'text_encoder': 'bert-base-uncased',
    
    ## Embedder
    'num_attn_heads': 8,
    'fusion_mode': 'cat',
    'num_stacked_attn': 1, 
    
    'criss_cross__drop_p': 0.5,
    'post_concat__drop_p': 0.0, 
    'embed_attn__add_residual': False,
    'embed_attn__drop_p': 0.0,

    ## Label Classifier
    'label_classifier__use_bn': False,
    'label_classifier__drop_p': 0.0,
    'label_classifier__repeat_layers': [0, 0],

    ## Domain Classifier
    'domain_classifier__use_bn': True,
    'domain_classifier__drop_p': 0.5,
    'domain_classifier__repeat_layers': [2, 2], 

    ### Objective ###
    # loss fn
    'domain_adaptation_method': 'domain_adversarial',  # 'naive', 'importance_sampling', 'domain_adversarial'

    ### Trainer ###
    'relaxation_period': 3,  # epochs to wait where accuracy is dropping 
                            # below moving average before ending the run
                            # (-1 to disable it)
    
    'batch_size': 150,
    'epochs': 30,
    'base_lr': 5e-4,
    'weight_decay': 5e-4,

    ### Logging ###
    'print_logs': True,
    # 'print_logs': False,

    'weights_save_root': './weights/raw'
}

if True:
    # v2
    cfg['source_domain'] = 'v2'
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    v2_ckpt_path = cfg['weights_save_path']

    trainer.train(show_plot=True)

    # abs
    cfg['source_domain'] = 'abs'
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    abs_ckpt_path = cfg['weights_save_path']

    trainer.train(show_plot=True)
# Out:
# weights_save_path: ./weights/raw/pbupWxBU.pth
# Number of Common Labels = 10 | n_classes = 10
# Labels: ['yes', 'no', '0', '1', '2', '3', 'red', 'yellow', 'blue', 'green']
# V2: 	Train size = 2000	             | Val size = 500 | Total = 2500
# Abs: 	Train size = 2000	             | Val size = 500 | Total = 2500
# --------------------
# Epoch [1/30]	                         Avg Train Loss: 1.523498	                         Avg Eval Loss: 1.480506	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.15
# Epoch [2/30]	                         Avg Train Loss: 1.291000	                         Avg Eval Loss: 1.139941	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.20
# Epoch [3/30]	                         Avg Train Loss: 1.127416	                         Avg Eval Loss: 1.124356	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.29
# Epoch [4/30]	                         Avg Train Loss: 1.016908	                         Avg Eval Loss: 1.001815	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.32
# Epoch [5/30]	                         Avg Train Loss: 0.998334	                         Avg Eval Loss: 0.984939	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.34
# Epoch [6/30]	                         Avg Train Loss: 0.976429	                         Avg Eval Loss: 0.944142	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.37
# Epoch [7/30]	                         Avg Train Loss: 0.968391	                         Avg Eval Loss: 0.930204	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.37
# Epoch [8/30]	                         Avg Train Loss: 0.959174	                         Avg Eval Loss: 0.929549	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.36
# Epoch [9/30]	                         Avg Train Loss: 0.935431	                         Avg Eval Loss: 0.912222	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.38
# Epoch [10/30]	                         Avg Train Loss: 0.918032	                         Avg Eval Loss: 0.930837	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.39
# Epoch [11/30]	                         Avg Train Loss: 0.901404	                         Avg Eval Loss: 0.928885	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.40
# Epoch [12/30]	                         Avg Train Loss: 0.883713	                         Avg Eval Loss: 0.948579	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.40
# Epoch [13/30]	                         Avg Train Loss: 0.889317	                         Avg Eval Loss: 0.923901	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.41
# Epoch [14/30]	                         Avg Train Loss: 0.857848	                         Avg Eval Loss: 0.953120	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.41
# Epoch [15/30]	                         Avg Train Loss: 0.841418	                         Avg Eval Loss: 0.937771	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.41
# Epoch [16/30]	                         Avg Train Loss: 0.815829	                         Avg Eval Loss: 1.003910	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.41
# Epoch [17/30]	                         Avg Train Loss: 0.811308	                         Avg Eval Loss: 0.952612	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.41
# Epoch [18/30]	                         Avg Train Loss: 0.799935	                         Avg Eval Loss: 0.960675	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.44
# Epoch [19/30]	                         Avg Train Loss: 0.767426	                         Avg Eval Loss: 1.014138	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.43
# Epoch [20/30]	                         Avg Train Loss: 0.757320	                         Avg Eval Loss: 1.005172	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.44
# Epoch [21/30]	                         Avg Train Loss: 0.752709	                         Avg Eval Loss: 0.969122	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.44
# Epoch [22/30]	                         Avg Train Loss: 0.727479	                         Avg Eval Loss: 1.060204	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.43
# Epoch [23/30]	                         Avg Train Loss: 0.730914	                         Avg Eval Loss: 1.047567	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.44
# Epoch [24/30]	                         Avg Train Loss: 0.712876	                         Avg Eval Loss: 1.035605	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.44
# Epoch [25/30]	                         Avg Train Loss: 0.684931	                         Avg Eval Loss: 1.112693	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.45
# Epoch [26/30]	                         Avg Train Loss: 0.681502	                         Avg Eval Loss: 1.054984	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.45
# Epoch [27/30]	                         Avg Train Loss: 0.662010	                         Avg Eval Loss: 1.108096	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.45
# Epoch [28/30]	                         Avg Train Loss: 0.656495	                         Avg Eval Loss: 1.175865	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.45
# Epoch [29/30]	                         Avg Train Loss: 0.641663	                         Avg Eval Loss: 1.165971	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.47
# Epoch [30/30]	                         Avg Train Loss: 0.643103	                         Avg Eval Loss: 1.160605	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.45
# weights_save_path: ./weights/raw/Nqo8ZOGH.pth
# Number of Common Labels = 10 | n_classes = 10
# Labels: ['yes', 'no', '0', '1', '2', '3', 'red', 'yellow', 'blue', 'green']
# V2: 	Train size = 2000	             | Val size = 500 | Total = 2500
# Abs: 	Train size = 2000	             | Val size = 500 | Total = 2500
# --------------------
# Epoch [1/30]	                         Avg Train Loss: 1.515435	                         Avg Eval Loss: 1.394268	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.21
# Epoch [2/30]	                         Avg Train Loss: 1.334422	                         Avg Eval Loss: 1.186913	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.20
# Epoch [3/30]	                         Avg Train Loss: 1.173679	                         Avg Eval Loss: 1.113373	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.28
# Epoch [4/30]	                         Avg Train Loss: 1.055783	                         Avg Eval Loss: 1.042732	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.29
# Epoch [5/30]	                         Avg Train Loss: 1.023251	                         Avg Eval Loss: 1.002808	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.30
# Epoch [6/30]	                         Avg Train Loss: 0.997541	                         Avg Eval Loss: 0.994316	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.33
# Epoch [7/30]	                         Avg Train Loss: 0.984219	                         Avg Eval Loss: 0.980889	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.34
# Epoch [8/30]	                         Avg Train Loss: 0.966305	                         Avg Eval Loss: 0.938241	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.35
# Epoch [9/30]	                         Avg Train Loss: 0.948818	                         Avg Eval Loss: 0.930296	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.38
# Epoch [10/30]	                         Avg Train Loss: 0.928657	                         Avg Eval Loss: 0.927374	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.39
# Epoch [11/30]	                         Avg Train Loss: 0.919080	                         Avg Eval Loss: 0.920313	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.36
# Epoch [12/30]	                         Avg Train Loss: 0.910701	                         Avg Eval Loss: 0.965390	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.38
# Epoch [13/30]	                         Avg Train Loss: 0.902822	                         Avg Eval Loss: 0.917868	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.38
# Epoch [14/30]	                         Avg Train Loss: 0.879822	                         Avg Eval Loss: 0.935073	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.40
# Epoch [15/30]	                         Avg Train Loss: 0.858309	                         Avg Eval Loss: 0.939927	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.39
# Epoch [16/30]	                         Avg Train Loss: 0.842936	                         Avg Eval Loss: 0.937408	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.41
# Epoch [17/30]	                         Avg Train Loss: 0.821956	                         Avg Eval Loss: 0.933156	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.42
# Epoch [18/30]	                         Avg Train Loss: 0.802606	                         Avg Eval Loss: 0.966617	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.42
# Epoch [19/30]	                         Avg Train Loss: 0.787613	                         Avg Eval Loss: 1.035437	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.39
# Epoch [20/30]	                         Avg Train Loss: 0.777092	                         Avg Eval Loss: 1.057300	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.41
# Epoch [21/30]	                         Avg Train Loss: 0.751473	                         Avg Eval Loss: 1.048720	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.41
# Epoch [22/30]	                         Avg Train Loss: 0.728252	                         Avg Eval Loss: 1.023460	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.43
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 89
#      86 trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
#      87 abs_ckpt_path = cfg['weights_save_path']
# ---> 89 trainer.train(show_plot=True)
#
# File /workspace/trainer.py:617, in DA_Trainer.train(self, show_plot, optuna_trial, comet_expt)
#     612 self.train_dataloader = zip(
#     613     self.v2_train_dataloader, self.abs_train_dataloader
#     614 )
#     615 self.val_dataloader = zip(self.v2_val_dataloader, self.abs_val_dataloader)
# --> 617 label_loss, domain_loss, total_loss = self.train_epoch()
#     618 with torch.no_grad():
#     619     (
#     620         eval_loss,
#     621         v2_accuracy,
#    (...)
#     624         domain_accuracy,
#     625     ) = self.eval_epoch()
#
# File /workspace/trainer.py:520, in DA_Trainer.train_epoch(self)
#     513 for i, (
#     514         (v2_i_tokens, v2_q_tokens, v2_label),
#     515         (abs_i_tokens, abs_q_tokens, abs_label),
#     516 ) in enumerate(self.train_dataloader):
#     518     self.alpha = self.get_alpha(i, self.num_train_batches)
# --> 520     (label_loss, domain_loss, total_loss), _ = self.process_input(
#     521         v2_i_tokens,
#     522         v2_q_tokens,
#     523         v2_label,
#     524         abs_i_tokens,
#     525         abs_q_tokens,
#     526         abs_label,
#     527         self.alpha,
#     528     )
#     530     label_running_loss += label_loss.item()
#     531     domain_running_loss += domain_loss.item()
#
# File /workspace/trainer.py:472, in DA_Trainer.process_input(self, v2_i_tokens, v2_q_tokens, v2_label, abs_i_tokens, abs_q_tokens, abs_label, alpha)
#     469 abs_i_tokens = {key: value.cuda() for key, value in abs_i_tokens.items()}
#     470 abs_q_tokens = {key: value.cuda() for key, value in abs_q_tokens.items()}
# --> 472 v2_label_logits, v2_domain_logits = self.model(v2_i_tokens, v2_q_tokens, alpha)
#     473 abs_label_logits, abs_domain_logits = self.model(
#     474     abs_i_tokens, abs_q_tokens, alpha
#     475 )
#     477 v2_label = v2_label.cuda()
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /workspace/models/models.py:231, in VLModel_IS.forward(self, i_tokens, q_tokens, alpha)
#     230 def forward(self, i_tokens, q_tokens, alpha=None):
# --> 231     embedding = self.get_embedding(i_tokens, q_tokens)
#     232     embedding = embedding.squeeze(1)
#     234     label_logits = self.label_classifier(embedding)
#
# File /workspace/models/models.py:152, in VLModel.get_embedding(self, i_tokens, q_tokens)
#     150 with torch.no_grad():
#     151     i_embeddings = self.i_encoder(**i_tokens).last_hidden_state
# --> 152     q_embeddings = self.q_encoder(**q_tokens).last_hidden_state
#     154 for stack in range(self.num_stacked_attn):
#     155     # Cross Attention
#     156     i_attended, q_attended = self.cross_attn(
#     157         i_embeddings, q_embeddings, self.attn_q2i[stack], self.attn_i2q[stack]
#     158     )
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:1107, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1100         extended_attention_mask = _prepare_4d_causal_attention_mask_for_sdpa(
#    1101             attention_mask,
#    1102             input_shape,
#    1103             embedding_output,
#    1104             past_key_values_length,
#    1105         )
#    1106     else:
# -> 1107         extended_attention_mask = _prepare_4d_attention_mask_for_sdpa(
#    1108             attention_mask, embedding_output.dtype, tgt_len=seq_length
#    1109         )
#    1110 else:
#    1111     # We can provide a self-attention mask of dimensions [batch_size, from_seq_length, to_seq_length]
#    1112     # ourselves in which case we just need to make it broadcastable to all heads.
#    1113     extended_attention_mask = self.get_extended_attention_mask(attention_mask, input_shape)
#
# File /opt/conda/lib/python3.10/site-packages/transformers/modeling_attn_mask_utils.py:449, in _prepare_4d_attention_mask_for_sdpa(mask, dtype, tgt_len)
#     442 is_tracing = (
#     443     torch.jit.is_tracing()
#     444     or isinstance(mask, torch.fx.Proxy)
#     445     or (hasattr(torch, "_dynamo") and torch._dynamo.is_compiling())
#     446 )
#     448 # torch.jit.trace, symbolic_trace and torchdynamo with fullgraph=True are unable to capture data-dependent controlflows.
# --> 449 if not is_tracing and torch.all(mask == 1):
#     450     return None
#     451 else:
#
# KeyboardInterrupt:

# %%
v2_ckpt_path = './weights/raw/pbupWxBU.pth'

abs_ckpt_path = './weights/raw/Nqo8ZOGH.pth'

# %%
cfg['v2_ckpt'] = v2_ckpt_path
cfg['abs_ckpt'] = abs_ckpt_path

# %% [markdown]
# ## Evaluating

# %%
(v2_train_data, v2_val_data), (abs_train_data, abs_val_data), labels = data_processing_v2(cfg, vqa_v2, vqa_abs)
model = VLModel(cfg, return_embeddings=True).cuda()

def eval_domain_adaptation(eval_dataset, model_ckpt, evaluate_train=False):
    if eval_dataset == 'v2':
        train_data, val_data = v2_train_data, v2_val_data
    elif eval_dataset == 'abs':
        train_data, val_data = abs_train_data, abs_val_data

    train_dataset = VQADataset(cfg, train_data)
    val_dataset = VQADataset(cfg, val_data)

    train_dataloader = DataLoader(train_dataset, batch_size=cfg['batch_size'], shuffle=True)
    val_dataloader = DataLoader(val_dataset, batch_size=cfg['batch_size'], shuffle=True)

    if model_ckpt == 'v2':
        ckpt = cfg['v2_ckpt']
    elif model_ckpt == 'abs':
        ckpt = cfg['abs_ckpt']

    state_dict = torch.load(ckpt, weights_only=True)
    model.load_state_dict(state_dict, strict=False)

    dataloader = val_dataloader if not evaluate_train else train_dataloader

    model.eval()
    correct, total = 0, 0
    embeddings = None

    with torch.no_grad():
        for i_tokens, q_tokens, label in dataloader:
            i_tokens = {key: value.cuda() for key, value in i_tokens.items()}
            q_tokens = {key: value.cuda() for key, value in q_tokens.items()}
            label = label.cuda()
            
            logits, embedding = model(i_tokens, q_tokens)
            embeddings = np.concatenate((embeddings, embedding), axis=0) if embeddings is not None else embedding

            # Compute accuracy
            _, predicted_indices = torch.max(logits, dim=1)
            label_indices = torch.argmax(label, dim=1)
            is_correct = (predicted_indices == label_indices)

            total += label.shape[0]
            correct += is_correct.sum().item()

    accuracy = (correct / total)

    source = 'v2 ' if model_ckpt == 'v2' else 'abs'
    target = 'v2 ' if eval_dataset == 'v2' else 'abs'
    split = 'train set' if evaluate_train else 'val set  '
    print(f'{source} -> {target} | {split} \t accuracy = {accuracy*100:.2f}%')
    
    return embeddings

# %%
# v2 -> v2
v2_val_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='v2', evaluate_train=False)
v2_train_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='v2', evaluate_train=True)

# abs -> abs
abs_val_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='abs', evaluate_train=False)
abs_train_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='abs', evaluate_train=True)

# %%
# v2 -> abs
v2_abs_val_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='abs', evaluate_train=False)
v2_abs_train_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='abs', evaluate_train=True)

# abs -> v2
abs_v2_val_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='v2', evaluate_train=False)
abs_v2_train_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='v2', evaluate_train=True)

# %% [markdown]
# ## Visualizing embeddings

# %%
from sklearn.manifold import TSNE
import matplotlib.patches as mpatches

def plot_tsne(embeddings, plot_labels, perplexities, title=''):
    n_plots = len(perplexities)
    fig, axes = plt.subplots(1, n_plots, figsize=(6 * n_plots, 6))
    
    for idx, perplexity in enumerate(perplexities):
        tsne = TSNE(n_components=2, perplexity=perplexity, random_state=42)
        tsne_embeddings = tsne.fit_transform(embeddings)
        
        colors = {'vv': 'blue', 'aa': 'red', 'va': 'orange', 'av': 'violet'}
        ax = axes[idx]
        for i, plot_label in enumerate(plot_labels):
                
            ax.scatter(tsne_embeddings[i, 0], tsne_embeddings[i, 1], color=colors[plot_label])
            ax.text(tsne_embeddings[i, 0] + 0.1, tsne_embeddings[i, 1], '', fontsize=9)
        
        ax.set_title(f'Perplexity = {perplexity}')
    
    custom_legend = [mpatches.Patch(color=colors[label], label=label) for label in set(plot_labels)]
    fig.legend(handles=custom_legend)
    fig.suptitle(title, fontsize=16)

    plt.tight_layout()
    plt.show()

# %%
n_v2 = len(v2_val_embeddings)
n_abs = len(abs_val_embeddings)

# v2 -> v2
plot_tsne(v2_val_embeddings, ['vv'] * n_v2, perplexities=[2,4,8,16,32], title='v2->v2 (val set)')
plot_tsne(v2_train_embeddings, ['vv'] * n_v2, perplexities=[2,4,8,16,32], title='v2->v2 (train set)')

# abs -> abs
plot_tsne(abs_val_embeddings, ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='abs->abs (val set)')
plot_tsne(abs_train_embeddings, ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='abs->abs (train set)')

# combined plot
val_embeddings = np.concatenate((v2_val_embeddings, abs_val_embeddings), axis=0)
plot_tsne(val_embeddings, ['vv'] * n_v2 + ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='Same Domain (val set)')

train_embeddings = np.concatenate((v2_train_embeddings, abs_train_embeddings), axis=0)
plot_tsne(train_embeddings, ['vv'] * n_v2 + ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='Same Domain (train set)')

# %%
# v2 -> abs
plot_tsne(v2_abs_val_embeddings, ['va'] * n_abs, perplexities=[2,4,8,16,32], title='v2->abs (val set)')
plot_tsne(v2_abs_train_embeddings, ['va'] * n_abs, perplexities=[2,4,8,16,32], title='v2->abs (train set)')

# abs -> v2
plot_tsne(abs_v2_val_embeddings, ['av'] * n_v2, perplexities=[2,4,8,16,32], title='abs->v2 (val set)')
plot_tsne(abs_v2_train_embeddings, ['av'] * n_v2, perplexities=[2,4,8,16,32], title='abs->v2 (train set)')

# combined plot
val_embeddings = np.concatenate((v2_abs_val_embeddings, abs_v2_val_embeddings), axis=0)
plot_tsne(val_embeddings, ['va'] * n_abs + ['av'] * n_v2, perplexities=[2,4,8,16,32], title='Cross Domain (val set)')

train_embeddings = np.concatenate((v2_abs_train_embeddings, abs_v2_train_embeddings), axis=0)
plot_tsne(train_embeddings, ['va'] * n_abs + ['av'] * n_v2, perplexities=[2,4,8,16,32], title='Cross Domain (train set)')
