# %% [markdown]
# ## Domain Adversarial

# %%
import os
os.chdir('/workspace')

from trainer import *

cfg = {
    ### META ###
    'name': 'DANN',

    ### DataLoader ###
    'n_classes': 10,
    'labels': [
        'yes', 'no',
        '0', '1', '2', '3',  
        'red', 'yellow', 'blue', 'green', 
    ],
    'v2_samples_per_answer': 300,
    'abs_samples_per_answer': 300,

    'v2_samples_per_answer_train': 200,
    'v2_samples_per_answer_val': 50,

    'abs_samples_per_answer_train': 200,
    'abs_samples_per_answer_val': 50,

    'source_domain': 'abs',
    
    ### VLModel ###
    'image_encoder': 'facebook/dinov2-base',
    'text_encoder': 'bert-base-uncased',
    
    ## Embedder
    'num_attn_heads': 8,
    'fusion_mode': 'cat',
    'num_stacked_attn': 2, 
    
    'criss_cross__drop_p': 0.0,
    'post_concat__drop_p': 0.0, 
    'embed_attn__add_residual': False,
    'embed_attn__drop_p': 0.0,

    ## Label Classifier
    'label_classifier__use_bn': False,
    'label_classifier__drop_p': 0.0,
    'label_classifier__repeat_layers': [0, 0],

    ## Domain Classifier
    'domain_classifier__use_bn': True,
    'domain_classifier__drop_p': 0.5,
    'domain_classifier__repeat_layers': [2, 2], 

    ### Objective ###
    # loss fn
    'domain_adaptation_method': 'domain_adversarial',  # 'naive', 'importance_sampling', 'domain_adversarial'

    ### Trainer ###
    'relaxation_period': 3,  # epochs to wait where accuracy is dropping 
                            # below moving average before ending the run
                            # (-1 to disable it)
    
    'batch_size': 150,
    'epochs': 30,
    'base_lr': 0.0005,
    'weight_decay': 5e-4,

    ### Logging ###
    'print_logs': True,
    # 'print_logs': False,

    'weights_save_root': './weights/raw'
}

if True:
    # v2
    cfg['source_domain'] = 'v2'
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    v2_ckpt_path = cfg['weights_save_path']

    trainer.train(show_plot=True)

    # abs
    cfg['source_domain'] = 'abs'
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    abs_ckpt_path = cfg['weights_save_path']

    trainer.train(show_plot=True)
# Out:
# weights_save_path: ./weights/raw/cRNvY24X.pth
# Number of Common Labels = 10 | n_classes = 10
# Labels: ['yes', 'no', '0', '1', '2', '3', 'red', 'yellow', 'blue', 'green']
# V2: 	Train size = 2000	             | Val size = 500 | Total = 2500
# Abs: 	Train size = 2000	             | Val size = 500 | Total = 2500
# --------------------
# Epoch [1/30]	                         Avg Train Loss: 1.528084	                         Avg Eval Loss: 1.529280	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.12
# Epoch [2/30]	                         Avg Train Loss: 1.410208	                         Avg Eval Loss: 1.272096	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.23
# Epoch [3/30]	                         Avg Train Loss: 1.213922	                         Avg Eval Loss: 1.169529	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.20
# Epoch [4/30]	                         Avg Train Loss: 1.177965	                         Avg Eval Loss: 1.201026	                         Avg Domain Accuracy: 0.54	                         Avg Eval Accuracy: 0.20
# Epoch [5/30]	                         Avg Train Loss: 1.195096	                         Avg Eval Loss: 1.123693	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.20
# Epoch [6/30]	                         Avg Train Loss: 1.151308	                         Avg Eval Loss: 1.141962	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.20
# Epoch [7/30]	                         Avg Train Loss: 1.144137	                         Avg Eval Loss: 1.088221	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.22
# Epoch [8/30]	                         Avg Train Loss: 1.088068	                         Avg Eval Loss: 1.491961	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.15
# Epoch [9/30]	                         Avg Train Loss: 1.232875	                         Avg Eval Loss: 1.140610	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.23
# Epoch [10/30]	                         Avg Train Loss: 1.135793	                         Avg Eval Loss: 1.108298	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.25
# Epoch [11/30]	                         Avg Train Loss: 1.092607	                         Avg Eval Loss: 1.151568	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.27
# Epoch [12/30]	                         Avg Train Loss: 1.203851	                         Avg Eval Loss: 1.153661	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.20
# Epoch [13/30]	                         Avg Train Loss: 1.152072	                         Avg Eval Loss: 1.123061	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.23
# Epoch [14/30]	                         Avg Train Loss: 1.120091	                         Avg Eval Loss: 1.126891	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.25
# Epoch [15/30]	                         Avg Train Loss: 1.109785	                         Avg Eval Loss: 1.083807	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.26
# Epoch [16/30]	                         Avg Train Loss: 1.109068	                         Avg Eval Loss: 1.104236	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.27
# Epoch [17/30]	                         Avg Train Loss: 1.097785	                         Avg Eval Loss: 1.085690	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.29
# Epoch [18/30]	                         Avg Train Loss: 1.096006	                         Avg Eval Loss: 1.096941	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.29
# Epoch [19/30]	                         Avg Train Loss: 1.097560	                         Avg Eval Loss: 1.090945	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.27
# Epoch [20/30]	                         Avg Train Loss: 1.084988	                         Avg Eval Loss: 1.078383	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.31
# Epoch [21/30]	                         Avg Train Loss: 1.073827	                         Avg Eval Loss: 1.065117	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.31
# Epoch [22/30]	                         Avg Train Loss: 1.035856	                         Avg Eval Loss: 1.008354	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.31
# Epoch [23/30]	                         Avg Train Loss: 0.999592	                         Avg Eval Loss: 1.001226	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.32
# Epoch [24/30]	                         Avg Train Loss: 0.989143	                         Avg Eval Loss: 0.979337	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.34
# Epoch [25/30]	                         Avg Train Loss: 0.977154	                         Avg Eval Loss: 0.973146	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.35
# Epoch [26/30]	                         Avg Train Loss: 0.968136	                         Avg Eval Loss: 0.942738	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.33
# Epoch [27/30]	                         Avg Train Loss: 0.955814	                         Avg Eval Loss: 0.939450	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.36
# Epoch [28/30]	                         Avg Train Loss: 0.947573	                         Avg Eval Loss: 0.940205	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.38
# Epoch [29/30]	                         Avg Train Loss: 0.939450	                         Avg Eval Loss: 0.931615	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.37
# Epoch [30/30]	                         Avg Train Loss: 0.933001	                         Avg Eval Loss: 0.924264	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.36
# weights_save_path: ./weights/raw/na7LUdWD.pth
# Number of Common Labels = 10 | n_classes = 10
# Labels: ['yes', 'no', '0', '1', '2', '3', 'red', 'yellow', 'blue', 'green']
# V2: 	Train size = 2000	             | Val size = 500 | Total = 2500
# Abs: 	Train size = 2000	             | Val size = 500 | Total = 2500
# --------------------
# Epoch [1/30]	                         Avg Train Loss: 1.531749	                         Avg Eval Loss: 1.531354	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.12
# Epoch [2/30]	                         Avg Train Loss: 1.440301	                         Avg Eval Loss: 1.364817	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.22
# Epoch [3/30]	                         Avg Train Loss: 1.240322	                         Avg Eval Loss: 1.266712	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.22
# Epoch [4/30]	                         Avg Train Loss: 1.297629	                         Avg Eval Loss: 1.184336	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.20
# Epoch [5/30]	                         Avg Train Loss: 1.159302	                         Avg Eval Loss: 1.142357	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.25
# Epoch [6/30]	                         Avg Train Loss: 1.209811	                         Avg Eval Loss: 1.228676	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.20
# Epoch [7/30]	                         Avg Train Loss: 1.210422	                         Avg Eval Loss: 1.162558	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.20
# Epoch [8/30]	                         Avg Train Loss: 1.152137	                         Avg Eval Loss: 1.114262	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.20
# Epoch [9/30]	                         Avg Train Loss: 1.133572	                         Avg Eval Loss: 1.084931	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.21
# Epoch [10/30]	                         Avg Train Loss: 1.116232	                         Avg Eval Loss: 1.048133	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.28
# Epoch [11/30]	                         Avg Train Loss: 1.039208	                         Avg Eval Loss: 1.002779	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.29
# Epoch [12/30]	                         Avg Train Loss: 1.006789	                         Avg Eval Loss: 1.031832	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.29
# Epoch [13/30]	                         Avg Train Loss: 0.995664	                         Avg Eval Loss: 1.001713	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.33
# Epoch [14/30]	                         Avg Train Loss: 0.978684	                         Avg Eval Loss: 0.983551	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.34
# Epoch [15/30]	                         Avg Train Loss: 0.965245	                         Avg Eval Loss: 0.961373	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.35
# Epoch [16/30]	                         Avg Train Loss: 0.949581	                         Avg Eval Loss: 0.986400	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.36
# Epoch [17/30]	                         Avg Train Loss: 0.934985	                         Avg Eval Loss: 0.939995	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.36
# Epoch [18/30]	                         Avg Train Loss: 0.928511	                         Avg Eval Loss: 0.944333	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.36
# Epoch [19/30]	                         Avg Train Loss: 0.910393	                         Avg Eval Loss: 0.921145	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.37
# Epoch [20/30]	                         Avg Train Loss: 0.899199	                         Avg Eval Loss: 0.925738	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.38
# Epoch [21/30]	                         Avg Train Loss: 0.886999	                         Avg Eval Loss: 1.094933	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.35
# Epoch [22/30]	                         Avg Train Loss: 0.906258	                         Avg Eval Loss: 0.946259	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.37
# Epoch [23/30]	                         Avg Train Loss: 0.879881	                         Avg Eval Loss: 1.029360	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.36
# Epoch [24/30]	                         Avg Train Loss: 0.846768	                         Avg Eval Loss: 1.084849	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.38
# Epoch [25/30]	                         Avg Train Loss: 0.832818	                         Avg Eval Loss: 1.073865	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.36
# Epoch [26/30]	                         Avg Train Loss: 0.829834	                         Avg Eval Loss: 1.099045	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.37
# Epoch [27/30]	                         Avg Train Loss: 0.807763	                         Avg Eval Loss: 1.236648	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.38
# Epoch [28/30]	                         Avg Train Loss: 0.801035	                         Avg Eval Loss: 1.387691	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.37
# Epoch [29/30]	                         Avg Train Loss: 0.804544	                         Avg Eval Loss: 1.198117	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.37
# Epoch [30/30]	                         Avg Train Loss: 0.785240	                         Avg Eval Loss: 1.215600	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.37

# %%
# v2_ckpt_path = './weights/raw/name=DANN__n_classes=10__v2_samples_per_answer=300__abs_samples_per_answer=150__source_domain=v2__base_lr=0.001__domain_adaptation_method=domain_adversarial__.pth'

# abs_ckpt_path = './weights/raw/name=DANN__n_classes=10__v2_samples_per_answer=300__abs_samples_per_answer=150__source_domain=abs__base_lr=0.001__domain_adaptation_method=domain_adversarial__.pth'

# %%
cfg['v2_ckpt'] = v2_ckpt_path
cfg['abs_ckpt'] = abs_ckpt_path

# %% [markdown]
# ## Evaluating

# %%
(v2_train_data, v2_val_data), (abs_train_data, abs_val_data), labels = data_processing_v2(cfg, vqa_v2, vqa_abs)
model = VLModel(cfg, return_embeddings=True).cuda()

def eval_domain_adaptation(eval_dataset, model_ckpt, evaluate_train=False):
    if eval_dataset == 'v2':
        train_data, val_data = v2_train_data, v2_val_data
    elif eval_dataset == 'abs':
        train_data, val_data = abs_train_data, abs_val_data

    train_dataset = VQADataset(cfg, train_data)
    val_dataset = VQADataset(cfg, val_data)

    train_dataloader = DataLoader(train_dataset, batch_size=cfg['batch_size'], shuffle=True)
    val_dataloader = DataLoader(val_dataset, batch_size=cfg['batch_size'], shuffle=True)

    if model_ckpt == 'v2':
        ckpt = cfg['v2_ckpt']
    elif model_ckpt == 'abs':
        ckpt = cfg['abs_ckpt']

    state_dict = torch.load(ckpt, weights_only=True)
    model.load_state_dict(state_dict, strict=False)

    dataloader = val_dataloader if not evaluate_train else train_dataloader

    model.eval()
    correct, total = 0, 0
    embeddings = None

    with torch.no_grad():
        for i_tokens, q_tokens, label in dataloader:
            i_tokens = {key: value.cuda() for key, value in i_tokens.items()}
            q_tokens = {key: value.cuda() for key, value in q_tokens.items()}
            label = label.cuda()
            
            logits, embedding = model(i_tokens, q_tokens)
            embeddings = np.concatenate((embeddings, embedding), axis=0) if embeddings is not None else embedding

            # Compute accuracy
            _, predicted_indices = torch.max(logits, dim=1)
            label_indices = torch.argmax(label, dim=1)
            is_correct = (predicted_indices == label_indices)

            total += label.shape[0]
            correct += is_correct.sum().item()

    accuracy = (correct / total)

    source = 'v2 ' if model_ckpt == 'v2' else 'abs'
    target = 'v2 ' if eval_dataset == 'v2' else 'abs'
    split = 'train set' if evaluate_train else 'val set  '
    print(f'{source} -> {target} | {split} \t accuracy = {accuracy*100:.2f}%')
    
    return embeddings
# Out:
# Number of Common Labels = 10 | n_classes = 10
# Labels: ['yes', 'no', '0', '1', '2', '3', 'red', 'yellow', 'blue', 'green']
# V2: 	Train size = 2000	             | Val size = 500 | Total = 2500
# Abs: 	Train size = 2000	             | Val size = 500 | Total = 2500
# --------------------

# %%
# v2 -> v2
v2_val_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='v2', evaluate_train=False)
v2_train_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='v2', evaluate_train=True)

# abs -> abs
abs_val_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='abs', evaluate_train=False)
abs_train_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='abs', evaluate_train=True)
# Out:
# v2  -> v2  | val set   	 accuracy = 35.00%
# v2  -> v2  | train set 	 accuracy = 36.65%
# abs -> abs | val set   	 accuracy = 39.00%
# abs -> abs | train set 	 accuracy = 42.80%

# %%
# v2 -> abs
v2_abs_val_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='abs', evaluate_train=False)
v2_abs_train_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='abs', evaluate_train=True)

# abs -> v2
abs_v2_val_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='v2', evaluate_train=False)
abs_v2_train_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='v2', evaluate_train=True)
# Out:
# v2  -> abs | val set   	 accuracy = 42.00%
# v2  -> abs | train set 	 accuracy = 43.65%
# abs -> v2  | val set   	 accuracy = 33.20%
# abs -> v2  | train set 	 accuracy = 38.50%

# %% [markdown]
# ## Visualizing embeddings

# %%
from sklearn.manifold import TSNE
import matplotlib.patches as mpatches

def plot_tsne(embeddings, plot_labels, perplexities, title=''):
    n_plots = len(perplexities)
    fig, axes = plt.subplots(1, n_plots, figsize=(6 * n_plots, 6))
    
    for idx, perplexity in enumerate(perplexities):
        tsne = TSNE(n_components=2, perplexity=perplexity, random_state=42)
        tsne_embeddings = tsne.fit_transform(embeddings)
        
        colors = {'vv': 'blue', 'aa': 'red', 'va': 'orange', 'av': 'violet'}
        ax = axes[idx]
        for i, plot_label in enumerate(plot_labels):
                
            ax.scatter(tsne_embeddings[i, 0], tsne_embeddings[i, 1], color=colors[plot_label])
            ax.text(tsne_embeddings[i, 0] + 0.1, tsne_embeddings[i, 1], '', fontsize=9)
        
        ax.set_title(f'Perplexity = {perplexity}')
    
    custom_legend = [mpatches.Patch(color=colors[label], label=label) for label in set(plot_labels)]
    fig.legend(handles=custom_legend)
    fig.suptitle(title, fontsize=16)

    plt.tight_layout()
    plt.show()

# %%
n_v2 = len(v2_val_embeddings)
n_abs = len(abs_val_embeddings)

# v2 -> v2
plot_tsne(v2_val_embeddings, ['vv'] * n_v2, perplexities=[2,4,8,16,32], title='v2->v2 (val set)')
plot_tsne(v2_train_embeddings, ['vv'] * n_v2, perplexities=[2,4,8,16,32], title='v2->v2 (train set)')

# abs -> abs
plot_tsne(abs_val_embeddings, ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='abs->abs (val set)')
plot_tsne(abs_train_embeddings, ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='abs->abs (train set)')

# combined plot
val_embeddings = np.concatenate((v2_val_embeddings, abs_val_embeddings), axis=0)
plot_tsne(val_embeddings, ['vv'] * n_v2 + ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='Same Domain (val set)')

train_embeddings = np.concatenate((v2_train_embeddings, abs_train_embeddings), axis=0)
plot_tsne(train_embeddings, ['vv'] * n_v2 + ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='Same Domain (train set)')

# %%
# v2 -> abs
plot_tsne(v2_abs_val_embeddings, ['va'] * n_abs, perplexities=[2,4,8,16,32], title='v2->abs (val set)')
plot_tsne(v2_abs_train_embeddings, ['va'] * n_abs, perplexities=[2,4,8,16,32], title='v2->abs (train set)')

# abs -> v2
plot_tsne(abs_v2_val_embeddings, ['av'] * n_v2, perplexities=[2,4,8,16,32], title='abs->v2 (val set)')
plot_tsne(abs_v2_train_embeddings, ['av'] * n_v2, perplexities=[2,4,8,16,32], title='abs->v2 (train set)')

# combined plot
val_embeddings = np.concatenate((v2_abs_val_embeddings, abs_v2_val_embeddings), axis=0)
plot_tsne(val_embeddings, ['va'] * n_abs + ['av'] * n_v2, perplexities=[2,4,8,16,32], title='Cross Domain (val set)')

train_embeddings = np.concatenate((v2_abs_train_embeddings, abs_v2_train_embeddings), axis=0)
plot_tsne(train_embeddings, ['va'] * n_abs + ['av'] * n_v2, perplexities=[2,4,8,16,32], title='Cross Domain (train set)')
