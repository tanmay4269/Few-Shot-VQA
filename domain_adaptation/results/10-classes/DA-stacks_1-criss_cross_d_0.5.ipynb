# %% [markdown]
# ## Domain Adversarial

# %%
import os
os.chdir('/workspace')

from trainer import *

cfg = {
    ### META ###
    'name': 'DANN',

    ### DataLoader ###
    'n_classes': 10,
    'labels': [
        'yes', 'no',
        '0', '1', '2', '3',  
        'red', 'yellow', 'blue', 'green', 
    ],
    'v2_samples_per_answer': 300,
    'abs_samples_per_answer': 300,

    'v2_samples_per_answer_train': 200,
    'v2_samples_per_answer_val': 50,

    'abs_samples_per_answer_train': 200,
    'abs_samples_per_answer_val': 50,

    'source_domain': 'abs',
    
    ### VLModel ###
    'image_encoder': 'facebook/dinov2-base',
    'text_encoder': 'bert-base-uncased',
    
    ## Embedder
    'num_attn_heads': 8,
    'fusion_mode': 'cat',
    'num_stacked_attn': 1, 
    
    'criss_cross__drop_p': 0.5,
    'post_concat__drop_p': 0.0, 
    'embed_attn__add_residual': False,
    'embed_attn__drop_p': 0.0,

    ## Label Classifier
    'label_classifier__use_bn': False,
    'label_classifier__drop_p': 0.0,
    'label_classifier__repeat_layers': [0, 0],

    ## Domain Classifier
    'domain_classifier__use_bn': True,
    'domain_classifier__drop_p': 0.5,
    'domain_classifier__repeat_layers': [2, 2], 

    ### Objective ###
    # loss fn
    'domain_adaptation_method': 'domain_adversarial',  # 'naive', 'importance_sampling', 'domain_adversarial'

    ### Trainer ###
    'relaxation_period': 3,  # epochs to wait where accuracy is dropping 
                            # below moving average before ending the run
                            # (-1 to disable it)
    
    'batch_size': 150,
    'epochs': 30,
    'base_lr': 5e-4,
    'weight_decay': 5e-4,

    ### Logging ###
    'print_logs': True,
    # 'print_logs': False,

    'weights_save_root': './weights/raw'
}

if True:
    # v2
    cfg['source_domain'] = 'v2'
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    v2_ckpt_path = cfg['weights_save_path']

    trainer.train(show_plot=True)

    # abs
    cfg['source_domain'] = 'abs'
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    abs_ckpt_path = cfg['weights_save_path']

    trainer.train(show_plot=True)
# Out:
# weights_save_path: ./weights/raw/KULeWQLm.pth
# Number of Common Labels = 10 | n_classes = 10
# Labels: ['yes', 'no', '0', '1', '2', '3', 'red', 'yellow', 'blue', 'green']
# V2: 	Train size = 2000	             | Val size = 500 | Total = 2500
# Abs: 	Train size = 2000	             | Val size = 500 | Total = 2500
# --------------------
# Epoch [1/30]	                         Avg Train Loss: 1.508500	                         Avg Eval Loss: 1.479640	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.16
# Epoch [2/30]	                         Avg Train Loss: 1.232603	                         Avg Eval Loss: 1.082455	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.28
# Epoch [3/30]	                         Avg Train Loss: 1.069276	                         Avg Eval Loss: 1.000079	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.29
# Epoch [4/30]	                         Avg Train Loss: 1.020491	                         Avg Eval Loss: 0.990596	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.30
# Epoch [5/30]	                         Avg Train Loss: 1.000699	                         Avg Eval Loss: 1.012099	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.31
# Epoch [6/30]	                         Avg Train Loss: 0.991112	                         Avg Eval Loss: 0.964126	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.33
# Epoch [7/30]	                         Avg Train Loss: 0.971298	                         Avg Eval Loss: 0.928538	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.35
# Epoch [8/30]	                         Avg Train Loss: 0.952407	                         Avg Eval Loss: 0.922221	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.36
# Epoch [9/30]	                         Avg Train Loss: 0.945754	                         Avg Eval Loss: 0.935101	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.38
# Epoch [10/30]	                         Avg Train Loss: 0.931354	                         Avg Eval Loss: 0.954850	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.40
# Epoch [11/30]	                         Avg Train Loss: 0.925030	                         Avg Eval Loss: 0.945852	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.37
# Epoch [12/30]	                         Avg Train Loss: 0.913397	                         Avg Eval Loss: 0.911192	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.38
# Epoch [13/30]	                         Avg Train Loss: 0.893704	                         Avg Eval Loss: 0.930923	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.40
# Epoch [14/30]	                         Avg Train Loss: 0.877245	                         Avg Eval Loss: 0.915077	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.40
# Epoch [15/30]	                         Avg Train Loss: 0.865961	                         Avg Eval Loss: 0.960706	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.39
# Epoch [16/30]	                         Avg Train Loss: 0.833372	                         Avg Eval Loss: 0.922829	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.43
# Epoch [17/30]	                         Avg Train Loss: 0.804269	                         Avg Eval Loss: 0.972688	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.42
# Epoch [18/30]	                         Avg Train Loss: 0.782291	                         Avg Eval Loss: 0.949783	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.42
# Epoch [19/30]	                         Avg Train Loss: 0.760159	                         Avg Eval Loss: 0.997025	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.45
# Epoch [20/30]	                         Avg Train Loss: 0.764677	                         Avg Eval Loss: 0.926884	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.43
# Epoch [21/30]	                         Avg Train Loss: 0.739204	                         Avg Eval Loss: 0.970890	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.44
# Epoch [22/30]	                         Avg Train Loss: 0.718775	                         Avg Eval Loss: 1.047574	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.43
# Epoch [23/30]	                         Avg Train Loss: 0.704836	                         Avg Eval Loss: 1.007572	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.44
# Epoch [24/30]	                         Avg Train Loss: 0.696005	                         Avg Eval Loss: 1.075180	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.44
# Epoch [25/30]	                         Avg Train Loss: 0.698229	                         Avg Eval Loss: 1.080635	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.44
# Epoch [26/30]	                         Avg Train Loss: 0.685794	                         Avg Eval Loss: 1.077510	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.44
# Epoch [27/30]	                         Avg Train Loss: 0.675717	                         Avg Eval Loss: 1.131427	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.43
# Epoch [28/30]	                         Avg Train Loss: 0.661108	                         Avg Eval Loss: 1.157053	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.43
# Epoch [29/30]	                         Avg Train Loss: 0.657064	                         Avg Eval Loss: 1.130642	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.45
# Epoch [30/30]	                         Avg Train Loss: 0.652141	                         Avg Eval Loss: 1.208817	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.44
# weights_save_path: ./weights/raw/EFyHAfK1.pth
# Number of Common Labels = 10 | n_classes = 10
# Labels: ['yes', 'no', '0', '1', '2', '3', 'red', 'yellow', 'blue', 'green']
# V2: 	Train size = 2000	             | Val size = 500 | Total = 2500
# Abs: 	Train size = 2000	             | Val size = 500 | Total = 2500
# --------------------
# Epoch [1/30]	                         Avg Train Loss: 1.519840	                         Avg Eval Loss: 1.470972	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.17
# Epoch [2/30]	                         Avg Train Loss: 1.259514	                         Avg Eval Loss: 1.089043	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.27
# Epoch [3/30]	                         Avg Train Loss: 1.075538	                         Avg Eval Loss: 1.046078	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.29
# Epoch [4/30]	                         Avg Train Loss: 1.016594	                         Avg Eval Loss: 1.019867	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.32
# Epoch [5/30]	                         Avg Train Loss: 0.999604	                         Avg Eval Loss: 1.010272	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.33
# Epoch [6/30]	                         Avg Train Loss: 0.975465	                         Avg Eval Loss: 0.977168	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.35
# Epoch [7/30]	                         Avg Train Loss: 0.954921	                         Avg Eval Loss: 0.987471	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.36
# Epoch [8/30]	                         Avg Train Loss: 0.932356	                         Avg Eval Loss: 0.985034	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.37
# Epoch [9/30]	                         Avg Train Loss: 0.918886	                         Avg Eval Loss: 0.921355	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.41
# Epoch [10/30]	                         Avg Train Loss: 0.888953	                         Avg Eval Loss: 0.960324	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.40
# Epoch [11/30]	                         Avg Train Loss: 0.880412	                         Avg Eval Loss: 0.948083	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.41
# Epoch [12/30]	                         Avg Train Loss: 0.849726	                         Avg Eval Loss: 0.963795	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.42
# Epoch [13/30]	                         Avg Train Loss: 0.837847	                         Avg Eval Loss: 1.034253	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.39
# Epoch [14/30]	                         Avg Train Loss: 0.819971	                         Avg Eval Loss: 0.986889	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.40
# Epoch [15/30]	                         Avg Train Loss: 0.783141	                         Avg Eval Loss: 1.057303	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.39
# Epoch [16/30]	                         Avg Train Loss: 0.752419	                         Avg Eval Loss: 1.116075	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.42
# Epoch [17/30]	                         Avg Train Loss: 0.734789	                         Avg Eval Loss: 1.091023	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.41
# Epoch [18/30]	                         Avg Train Loss: 0.708767	                         Avg Eval Loss: 1.128110	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.43
# Epoch [19/30]	                         Avg Train Loss: 0.684897	                         Avg Eval Loss: 1.158769	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.40
# Epoch [20/30]	                         Avg Train Loss: 0.657037	                         Avg Eval Loss: 1.282583	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.40
# Epoch [21/30]	                         Avg Train Loss: 0.637110	                         Avg Eval Loss: 1.310747	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.42
# Epoch [22/30]	                         Avg Train Loss: 0.625277	                         Avg Eval Loss: 1.368362	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.43
# Epoch [23/30]	                         Avg Train Loss: 0.610460	                         Avg Eval Loss: 1.491012	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.42
# Epoch [24/30]	                         Avg Train Loss: 0.592489	                         Avg Eval Loss: 1.415128	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.43
# Epoch [25/30]	                         Avg Train Loss: 0.570621	                         Avg Eval Loss: 1.524842	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.42
# Epoch [26/30]	                         Avg Train Loss: 0.562822	                         Avg Eval Loss: 1.550202	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.41
# Epoch [27/30]	                         Avg Train Loss: 0.550341	                         Avg Eval Loss: 1.640711	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.42
# Epoch [28/30]	                         Avg Train Loss: 0.537609	                         Avg Eval Loss: 1.658887	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.40
# Epoch [29/30]	                         Avg Train Loss: 0.523479	                         Avg Eval Loss: 1.655782	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.41
# Epoch [30/30]	                         Avg Train Loss: 0.513599	                         Avg Eval Loss: 1.699170	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.40

# %%
# v2_ckpt_path = './weights/raw/name=DANN__n_classes=10__v2_samples_per_answer=300__abs_samples_per_answer=150__source_domain=v2__base_lr=0.001__domain_adaptation_method=domain_adversarial__.pth'

# abs_ckpt_path = './weights/raw/name=DANN__n_classes=10__v2_samples_per_answer=300__abs_samples_per_answer=150__source_domain=abs__base_lr=0.001__domain_adaptation_method=domain_adversarial__.pth'

# %%
cfg['v2_ckpt'] = v2_ckpt_path
cfg['abs_ckpt'] = abs_ckpt_path

# %% [markdown]
# ## Evaluating

# %%
(v2_train_data, v2_val_data), (abs_train_data, abs_val_data), labels = data_processing_v2(cfg, vqa_v2, vqa_abs)
model = VLModel(cfg, return_embeddings=True).cuda()

def eval_domain_adaptation(eval_dataset, model_ckpt, evaluate_train=False):
    if eval_dataset == 'v2':
        train_data, val_data = v2_train_data, v2_val_data
    elif eval_dataset == 'abs':
        train_data, val_data = abs_train_data, abs_val_data

    train_dataset = VQADataset(cfg, train_data)
    val_dataset = VQADataset(cfg, val_data)

    train_dataloader = DataLoader(train_dataset, batch_size=cfg['batch_size'], shuffle=True)
    val_dataloader = DataLoader(val_dataset, batch_size=cfg['batch_size'], shuffle=True)

    if model_ckpt == 'v2':
        ckpt = cfg['v2_ckpt']
    elif model_ckpt == 'abs':
        ckpt = cfg['abs_ckpt']

    state_dict = torch.load(ckpt, weights_only=True)
    model.load_state_dict(state_dict, strict=False)

    dataloader = val_dataloader if not evaluate_train else train_dataloader

    model.eval()
    correct, total = 0, 0
    embeddings = None

    with torch.no_grad():
        for i_tokens, q_tokens, label in dataloader:
            i_tokens = {key: value.cuda() for key, value in i_tokens.items()}
            q_tokens = {key: value.cuda() for key, value in q_tokens.items()}
            label = label.cuda()
            
            logits, embedding = model(i_tokens, q_tokens)
            embeddings = np.concatenate((embeddings, embedding), axis=0) if embeddings is not None else embedding

            # Compute accuracy
            _, predicted_indices = torch.max(logits, dim=1)
            label_indices = torch.argmax(label, dim=1)
            is_correct = (predicted_indices == label_indices)

            total += label.shape[0]
            correct += is_correct.sum().item()

    accuracy = (correct / total)

    source = 'v2 ' if model_ckpt == 'v2' else 'abs'
    target = 'v2 ' if eval_dataset == 'v2' else 'abs'
    split = 'train set' if evaluate_train else 'val set  '
    print(f'{source} -> {target} | {split} \t accuracy = {accuracy*100:.2f}%')
    
    return embeddings
# Out:
# Number of Common Labels = 10 | n_classes = 10
# Labels: ['yes', 'no', '0', '1', '2', '3', 'red', 'yellow', 'blue', 'green']
# V2: 	Train size = 2000	             | Val size = 500 | Total = 2500
# Abs: 	Train size = 2000	             | Val size = 500 | Total = 2500
# --------------------

# %%
# v2 -> v2
v2_val_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='v2', evaluate_train=False)
v2_train_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='v2', evaluate_train=True)

# abs -> abs
abs_val_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='abs', evaluate_train=False)
abs_train_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='abs', evaluate_train=True)
# Out:
# v2  -> v2  | val set   	 accuracy = 35.20%
# v2  -> v2  | train set 	 accuracy = 39.15%
# abs -> abs | val set   	 accuracy = 43.60%
# abs -> abs | train set 	 accuracy = 50.30%

# %%
# v2 -> abs
v2_abs_val_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='abs', evaluate_train=False)
v2_abs_train_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='abs', evaluate_train=True)

# abs -> v2
abs_v2_val_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='v2', evaluate_train=False)
abs_v2_train_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='v2', evaluate_train=True)
# Out:
# v2  -> abs | val set   	 accuracy = 43.80%
# v2  -> abs | train set 	 accuracy = 46.80%
# abs -> v2  | val set   	 accuracy = 33.80%
# abs -> v2  | train set 	 accuracy = 43.65%

# %% [markdown]
# ## Visualizing embeddings

# %%
from sklearn.manifold import TSNE
import matplotlib.patches as mpatches

def plot_tsne(embeddings, plot_labels, perplexities, title=''):
    n_plots = len(perplexities)
    fig, axes = plt.subplots(1, n_plots, figsize=(6 * n_plots, 6))
    
    for idx, perplexity in enumerate(perplexities):
        tsne = TSNE(n_components=2, perplexity=perplexity, random_state=42)
        tsne_embeddings = tsne.fit_transform(embeddings)
        
        colors = {'vv': 'blue', 'aa': 'red', 'va': 'orange', 'av': 'violet'}
        ax = axes[idx]
        for i, plot_label in enumerate(plot_labels):
                
            ax.scatter(tsne_embeddings[i, 0], tsne_embeddings[i, 1], color=colors[plot_label])
            ax.text(tsne_embeddings[i, 0] + 0.1, tsne_embeddings[i, 1], '', fontsize=9)
        
        ax.set_title(f'Perplexity = {perplexity}')
    
    custom_legend = [mpatches.Patch(color=colors[label], label=label) for label in set(plot_labels)]
    fig.legend(handles=custom_legend)
    fig.suptitle(title, fontsize=16)

    plt.tight_layout()
    plt.show()

# %%
n_v2 = len(v2_val_embeddings)
n_abs = len(abs_val_embeddings)

# v2 -> v2
plot_tsne(v2_val_embeddings, ['vv'] * n_v2, perplexities=[2,4,8,16,32], title='v2->v2 (val set)')
plot_tsne(v2_train_embeddings, ['vv'] * n_v2, perplexities=[2,4,8,16,32], title='v2->v2 (train set)')

# abs -> abs
plot_tsne(abs_val_embeddings, ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='abs->abs (val set)')
plot_tsne(abs_train_embeddings, ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='abs->abs (train set)')

# combined plot
val_embeddings = np.concatenate((v2_val_embeddings, abs_val_embeddings), axis=0)
plot_tsne(val_embeddings, ['vv'] * n_v2 + ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='Same Domain (val set)')

train_embeddings = np.concatenate((v2_train_embeddings, abs_train_embeddings), axis=0)
plot_tsne(train_embeddings, ['vv'] * n_v2 + ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='Same Domain (train set)')

# %%
# v2 -> abs
plot_tsne(v2_abs_val_embeddings, ['va'] * n_abs, perplexities=[2,4,8,16,32], title='v2->abs (val set)')
plot_tsne(v2_abs_train_embeddings, ['va'] * n_abs, perplexities=[2,4,8,16,32], title='v2->abs (train set)')

# abs -> v2
plot_tsne(abs_v2_val_embeddings, ['av'] * n_v2, perplexities=[2,4,8,16,32], title='abs->v2 (val set)')
plot_tsne(abs_v2_train_embeddings, ['av'] * n_v2, perplexities=[2,4,8,16,32], title='abs->v2 (train set)')

# combined plot
val_embeddings = np.concatenate((v2_abs_val_embeddings, abs_v2_val_embeddings), axis=0)
plot_tsne(val_embeddings, ['va'] * n_abs + ['av'] * n_v2, perplexities=[2,4,8,16,32], title='Cross Domain (val set)')

train_embeddings = np.concatenate((v2_abs_train_embeddings, abs_v2_train_embeddings), axis=0)
plot_tsne(train_embeddings, ['va'] * n_abs + ['av'] * n_v2, perplexities=[2,4,8,16,32], title='Cross Domain (train set)')
