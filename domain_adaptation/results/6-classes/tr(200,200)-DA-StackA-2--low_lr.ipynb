# %% [markdown]
# ## Domain Adversarial

# %%
import os
os.chdir('/workspace')

from trainer import *

cfg = {
    ### META ###
    'name': 'DANN',

    ### DataLoader ###
    'n_classes': 6,
    'labels': [
        'yes', 'no',
        '0', '1',  
        'red', 'yellow', 
    ],
    'v2_samples_per_answer': 300,
    'abs_samples_per_answer': 300,

    'v2_samples_per_answer_train': 200,
    'v2_samples_per_answer_val': 50,

    'abs_samples_per_answer_train': 200,
    'abs_samples_per_answer_val': 50,

    'source_domain': 'abs',
    
    ### VLModel ###
    'image_encoder': 'facebook/dinov2-base',
    'text_encoder': 'bert-base-uncased',
    
    ## Embedder
    'num_attn_heads': 8,
    'fusion_mode': 'cat',
    'num_stacked_attn': 2, 
    
    'criss_cross__drop_p': 0.0,
    'post_concat__drop_p': 0.0, 
    'embed_attn__add_residual': False,
    'embed_attn__drop_p': 0.0,

    ## Label Classifier
    'label_classifier__use_bn': False,
    'label_classifier__drop_p': 0.0,
    'label_classifier__repeat_layers': [0, 0],

    ## Domain Classifier
    'domain_classifier__use_bn': True,
    'domain_classifier__drop_p': 0.5,
    'domain_classifier__repeat_layers': [2, 2], 

    ### Objective ###
    # loss fn
    'domain_adaptation_method': 'domain_adversarial',  # 'naive', 'importance_sampling', 'domain_adversarial'

    ### Trainer ###
    'relaxation_period': 3,  # epochs to wait where accuracy is dropping 
                            # below moving average before ending the run
                            # (-1 to disable it)
    
    'batch_size': 150,
    'epochs': 30,
    'base_lr': 0.0005,
    'weight_decay': 5e-4,

    ### Logging ###
    'print_logs': True,
    # 'print_logs': False,

    'weights_save_root': './weights/raw'
}

if True:
    # v2
    cfg['source_domain'] = 'v2'
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    v2_ckpt_path = cfg['weights_save_path']

    trainer.train(show_plot=True)

    # abs
    cfg['source_domain'] = 'abs'
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    abs_ckpt_path = cfg['weights_save_path']

    trainer.train(show_plot=True)
# Out:
# weights_save_path: ./weights/raw/5njyVXJI.pth
# Number of Common Labels = 6 | n_classes = 6
# Labels: ['yes', 'no', '0', '1', 'red', 'yellow']
# V2: 	Train size = 1200	             | Val size = 300 | Total = 1500
# Abs: 	Train size = 1200	             | Val size = 300 | Total = 1500
# --------------------
# Epoch [1/30]	                         Avg Train Loss: 1.279599	                         Avg Eval Loss: 1.269064	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.17
# Epoch [2/30]	                         Avg Train Loss: 1.263114	                         Avg Eval Loss: 1.261037	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.19
# Epoch [3/30]	                         Avg Train Loss: 1.173602	                         Avg Eval Loss: 1.094168	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.34
# Epoch [4/30]	                         Avg Train Loss: 1.059039	                         Avg Eval Loss: 0.953165	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.34
# Epoch [5/30]	                         Avg Train Loss: 0.949434	                         Avg Eval Loss: 0.933060	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.36
# Epoch [6/30]	                         Avg Train Loss: 1.051163	                         Avg Eval Loss: 0.888581	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.45
# Epoch [7/30]	                         Avg Train Loss: 0.958569	                         Avg Eval Loss: 0.944335	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.34
# Epoch [8/30]	                         Avg Train Loss: 0.886946	                         Avg Eval Loss: 0.807118	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.47
# Epoch [9/30]	                         Avg Train Loss: 0.890238	                         Avg Eval Loss: 1.038645	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.34
# Epoch [10/30]	                         Avg Train Loss: 0.897764	                         Avg Eval Loss: 0.876576	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.43
# Epoch [11/30]	                         Avg Train Loss: 0.855560	                         Avg Eval Loss: 0.812244	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.45
# Epoch [12/30]	                         Avg Train Loss: 0.916633	                         Avg Eval Loss: 0.889893	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.44
# Epoch [13/30]	                         Avg Train Loss: 0.852841	                         Avg Eval Loss: 0.831410	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.47
# Epoch [14/30]	                         Avg Train Loss: 0.776935	                         Avg Eval Loss: 0.758941	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.48
# Epoch [15/30]	                         Avg Train Loss: 0.742579	                         Avg Eval Loss: 0.736314	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.50
# Epoch [16/30]	                         Avg Train Loss: 0.734888	                         Avg Eval Loss: 0.729756	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.52
# Epoch [17/30]	                         Avg Train Loss: 0.726868	                         Avg Eval Loss: 0.717691	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.50
# Epoch [18/30]	                         Avg Train Loss: 0.719299	                         Avg Eval Loss: 0.721827	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.53
# Epoch [19/30]	                         Avg Train Loss: 0.718723	                         Avg Eval Loss: 0.714187	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.53
# Epoch [20/30]	                         Avg Train Loss: 0.706797	                         Avg Eval Loss: 0.708292	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.54
# Epoch [21/30]	                         Avg Train Loss: 0.697430	                         Avg Eval Loss: 0.699640	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.56
# Epoch [22/30]	                         Avg Train Loss: 0.690977	                         Avg Eval Loss: 0.696996	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.55
# Epoch [23/30]	                         Avg Train Loss: 0.678487	                         Avg Eval Loss: 0.696309	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.56
# Epoch [24/30]	                         Avg Train Loss: 0.666893	                         Avg Eval Loss: 0.694229	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.57
# Epoch [25/30]	                         Avg Train Loss: 0.656314	                         Avg Eval Loss: 0.692048	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.57
# Epoch [26/30]	                         Avg Train Loss: 0.650025	                         Avg Eval Loss: 0.698691	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.57
# Epoch [27/30]	                         Avg Train Loss: 0.646644	                         Avg Eval Loss: 0.694897	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.59
# Epoch [28/30]	                         Avg Train Loss: 0.638830	                         Avg Eval Loss: 0.702203	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.58
# Epoch [29/30]	                         Avg Train Loss: 0.636517	                         Avg Eval Loss: 0.703272	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.57
# Epoch [30/30]	                         Avg Train Loss: 0.631632	                         Avg Eval Loss: 0.700690	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.57
# weights_save_path: ./weights/raw/TM5txSdR.pth
# Number of Common Labels = 6 | n_classes = 6
# Labels: ['yes', 'no', '0', '1', 'red', 'yellow']
# V2: 	Train size = 1200	             | Val size = 300 | Total = 1500
# Abs: 	Train size = 1200	             | Val size = 300 | Total = 1500
# --------------------
# Epoch [1/30]	                         Avg Train Loss: 1.276060	                         Avg Eval Loss: 1.272079	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.16
# Epoch [2/30]	                         Avg Train Loss: 1.268052	                         Avg Eval Loss: 1.262149	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.20
# Epoch [3/30]	                         Avg Train Loss: 1.169413	                         Avg Eval Loss: 1.136490	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.33
# Epoch [4/30]	                         Avg Train Loss: 1.082570	                         Avg Eval Loss: 1.000591	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.33
# Epoch [5/30]	                         Avg Train Loss: 0.955944	                         Avg Eval Loss: 0.956175	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.35
# Epoch [6/30]	                         Avg Train Loss: 0.919540	                         Avg Eval Loss: 0.901222	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.36
# Epoch [7/30]	                         Avg Train Loss: 0.942342	                         Avg Eval Loss: 0.931661	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.34
# Epoch [8/30]	                         Avg Train Loss: 0.909616	                         Avg Eval Loss: 0.880251	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.36
# Epoch [9/30]	                         Avg Train Loss: 0.867060	                         Avg Eval Loss: 0.840936	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.46
# Epoch [10/30]	                         Avg Train Loss: 0.841009	                         Avg Eval Loss: 0.796602	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.50
# Epoch [11/30]	                         Avg Train Loss: 0.777499	                         Avg Eval Loss: 0.747554	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.53
# Epoch [12/30]	                         Avg Train Loss: 0.743979	                         Avg Eval Loss: 0.725110	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.50
# Epoch [13/30]	                         Avg Train Loss: 0.721840	                         Avg Eval Loss: 0.726955	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.52
# Epoch [14/30]	                         Avg Train Loss: 0.712408	                         Avg Eval Loss: 0.708588	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.56
# Epoch [15/30]	                         Avg Train Loss: 0.697094	                         Avg Eval Loss: 0.722188	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.55
# Epoch [16/30]	                         Avg Train Loss: 0.696484	                         Avg Eval Loss: 0.695558	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.56
# Epoch [17/30]	                         Avg Train Loss: 0.677177	                         Avg Eval Loss: 0.723235	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.58
# Epoch [18/30]	                         Avg Train Loss: 0.666400	                         Avg Eval Loss: 0.697885	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.57
# Epoch [19/30]	                         Avg Train Loss: 0.650970	                         Avg Eval Loss: 0.693720	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.58
# Epoch [20/30]	                         Avg Train Loss: 0.639293	                         Avg Eval Loss: 0.696874	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.59
# Epoch [21/30]	                         Avg Train Loss: 0.624743	                         Avg Eval Loss: 0.721948	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.58
# Epoch [22/30]	                         Avg Train Loss: 0.613591	                         Avg Eval Loss: 0.727243	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.58
# Epoch [23/30]	                         Avg Train Loss: 0.604851	                         Avg Eval Loss: 0.733551	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.59
# Epoch [24/30]	                         Avg Train Loss: 0.599475	                         Avg Eval Loss: 0.752641	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.59
# Epoch [25/30]	                         Avg Train Loss: 0.602302	                         Avg Eval Loss: 0.749121	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.58
# Epoch [26/30]	                         Avg Train Loss: 0.594092	                         Avg Eval Loss: 0.758080	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.60
# Epoch [27/30]	                         Avg Train Loss: 0.593994	                         Avg Eval Loss: 0.752374	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.59
# Epoch [28/30]	                         Avg Train Loss: 0.591766	                         Avg Eval Loss: 0.784307	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.60
# Epoch [29/30]	                         Avg Train Loss: 0.589686	                         Avg Eval Loss: 0.755224	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.60
# Epoch [30/30]	                         Avg Train Loss: 0.587662	                         Avg Eval Loss: 0.773014	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.59

# %%
# v2_ckpt_path = './weights/raw/name=DANN__n_classes=10__v2_samples_per_answer=300__abs_samples_per_answer=150__source_domain=v2__base_lr=0.001__domain_adaptation_method=domain_adversarial__.pth'

# abs_ckpt_path = './weights/raw/name=DANN__n_classes=10__v2_samples_per_answer=300__abs_samples_per_answer=150__source_domain=abs__base_lr=0.001__domain_adaptation_method=domain_adversarial__.pth'

# %%
cfg['v2_ckpt'] = v2_ckpt_path
cfg['abs_ckpt'] = abs_ckpt_path

# %% [markdown]
# ## Evaluating

# %%
(v2_train_data, v2_val_data), (abs_train_data, abs_val_data), labels = data_processing_v2(cfg, vqa_v2, vqa_abs)
model = VLModel(cfg, return_embeddings=True).cuda()

def eval_domain_adaptation(eval_dataset, model_ckpt, evaluate_train=False):
    if eval_dataset == 'v2':
        train_data, val_data = v2_train_data, v2_val_data
    elif eval_dataset == 'abs':
        train_data, val_data = abs_train_data, abs_val_data

    train_dataset = VQADataset(cfg, train_data)
    val_dataset = VQADataset(cfg, val_data)

    train_dataloader = DataLoader(train_dataset, batch_size=cfg['batch_size'], shuffle=True)
    val_dataloader = DataLoader(val_dataset, batch_size=cfg['batch_size'], shuffle=True)

    if model_ckpt == 'v2':
        ckpt = cfg['v2_ckpt']
    elif model_ckpt == 'abs':
        ckpt = cfg['abs_ckpt']

    state_dict = torch.load(ckpt, weights_only=True)
    model.load_state_dict(state_dict, strict=False)

    dataloader = val_dataloader if not evaluate_train else train_dataloader

    model.eval()
    correct, total = 0, 0
    embeddings = None

    with torch.no_grad():
        for i_tokens, q_tokens, label in dataloader:
            i_tokens = {key: value.cuda() for key, value in i_tokens.items()}
            q_tokens = {key: value.cuda() for key, value in q_tokens.items()}
            label = label.cuda()
            
            logits, embedding = model(i_tokens, q_tokens)
            embeddings = np.concatenate((embeddings, embedding), axis=0) if embeddings is not None else embedding

            # Compute accuracy
            _, predicted_indices = torch.max(logits, dim=1)
            label_indices = torch.argmax(label, dim=1)
            is_correct = (predicted_indices == label_indices)

            total += label.shape[0]
            correct += is_correct.sum().item()

    accuracy = (correct / total)

    source = 'v2 ' if model_ckpt == 'v2' else 'abs'
    target = 'v2 ' if eval_dataset == 'v2' else 'abs'
    split = 'train set' if evaluate_train else 'val set  '
    print(f'{source} -> {target} | {split} \t accuracy = {accuracy*100:.2f}%')
    
    return embeddings
# Out:
# Number of Common Labels = 6 | n_classes = 6
# Labels: ['yes', 'no', '0', '1', 'red', 'yellow']
# V2: 	Train size = 1200	             | Val size = 300 | Total = 1500
# Abs: 	Train size = 1200	             | Val size = 300 | Total = 1500
# --------------------

# %%
# v2 -> v2
v2_val_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='v2', evaluate_train=False)
v2_train_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='v2', evaluate_train=True)

# abs -> abs
abs_val_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='abs', evaluate_train=False)
abs_train_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='abs', evaluate_train=True)
# Out:
# v2  -> v2  | val set   	 accuracy = 54.67%
# v2  -> v2  | train set 	 accuracy = 61.75%
# abs -> abs | val set   	 accuracy = 61.33%
# abs -> abs | train set 	 accuracy = 64.33%

# %%
# v2 -> abs
v2_abs_val_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='abs', evaluate_train=False)
v2_abs_train_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='abs', evaluate_train=True)

# abs -> v2
abs_v2_val_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='v2', evaluate_train=False)
abs_v2_train_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='v2', evaluate_train=True)
# Out:
# v2  -> abs | val set   	 accuracy = 60.33%
# v2  -> abs | train set 	 accuracy = 63.83%
# abs -> v2  | val set   	 accuracy = 53.67%
# abs -> v2  | train set 	 accuracy = 61.17%

# %% [markdown]
# ## Visualizing embeddings

# %%
from sklearn.manifold import TSNE
import matplotlib.patches as mpatches

def plot_tsne(embeddings, plot_labels, perplexities, title=''):
    n_plots = len(perplexities)
    fig, axes = plt.subplots(1, n_plots, figsize=(6 * n_plots, 6))
    
    for idx, perplexity in enumerate(perplexities):
        tsne = TSNE(n_components=2, perplexity=perplexity, random_state=42)
        tsne_embeddings = tsne.fit_transform(embeddings)
        
        colors = {'vv': 'blue', 'aa': 'red', 'va': 'orange', 'av': 'violet'}
        ax = axes[idx]
        for i, plot_label in enumerate(plot_labels):
                
            ax.scatter(tsne_embeddings[i, 0], tsne_embeddings[i, 1], color=colors[plot_label])
            ax.text(tsne_embeddings[i, 0] + 0.1, tsne_embeddings[i, 1], '', fontsize=9)
        
        ax.set_title(f'Perplexity = {perplexity}')
    
    custom_legend = [mpatches.Patch(color=colors[label], label=label) for label in set(plot_labels)]
    fig.legend(handles=custom_legend)
    fig.suptitle(title, fontsize=16)

    plt.tight_layout()
    plt.show()

# %%
n_v2 = len(v2_val_embeddings)
n_abs = len(abs_val_embeddings)

# v2 -> v2
plot_tsne(v2_val_embeddings, ['vv'] * n_v2, perplexities=[2,4,8,16,32], title='v2->v2 (val set)')
plot_tsne(v2_train_embeddings, ['vv'] * n_v2, perplexities=[2,4,8,16,32], title='v2->v2 (train set)')

# abs -> abs
plot_tsne(abs_val_embeddings, ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='abs->abs (val set)')
plot_tsne(abs_train_embeddings, ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='abs->abs (train set)')

# combined plot
val_embeddings = np.concatenate((v2_val_embeddings, abs_val_embeddings), axis=0)
plot_tsne(val_embeddings, ['vv'] * n_v2 + ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='Same Domain (val set)')

train_embeddings = np.concatenate((v2_train_embeddings, abs_train_embeddings), axis=0)
plot_tsne(train_embeddings, ['vv'] * n_v2 + ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='Same Domain (train set)')

# %%
# v2 -> abs
plot_tsne(v2_abs_val_embeddings, ['va'] * n_abs, perplexities=[2,4,8,16,32], title='v2->abs (val set)')
plot_tsne(v2_abs_train_embeddings, ['va'] * n_abs, perplexities=[2,4,8,16,32], title='v2->abs (train set)')

# abs -> v2
plot_tsne(abs_v2_val_embeddings, ['av'] * n_v2, perplexities=[2,4,8,16,32], title='abs->v2 (val set)')
plot_tsne(abs_v2_train_embeddings, ['av'] * n_v2, perplexities=[2,4,8,16,32], title='abs->v2 (train set)')

# combined plot
val_embeddings = np.concatenate((v2_abs_val_embeddings, abs_v2_val_embeddings), axis=0)
plot_tsne(val_embeddings, ['va'] * n_abs + ['av'] * n_v2, perplexities=[2,4,8,16,32], title='Cross Domain (val set)')

train_embeddings = np.concatenate((v2_abs_train_embeddings, abs_v2_train_embeddings), axis=0)
plot_tsne(train_embeddings, ['va'] * n_abs + ['av'] * n_v2, perplexities=[2,4,8,16,32], title='Cross Domain (train set)')
