# %% [markdown]
# ## Domain Adversarial

# %%
import os
os.chdir('/workspace')

from trainer import *

cfg = {
    ### META ###
    'name': 'DANN',

    ### DataLoader ###
    'n_classes': 6,
    'labels': [
        'yes', 'no',
        '0', '1',  
        'red', 'yellow', 
    ],
    'v2_samples_per_answer': 300,
    'abs_samples_per_answer': 300,

    'v2_samples_per_answer_train': 200,
    'v2_samples_per_answer_val': 50,

    'abs_samples_per_answer_train': 200,
    'abs_samples_per_answer_val': 50,

    'source_domain': 'abs',
    
    ### VLModel ###
    'image_encoder': 'facebook/dinov2-base',
    'text_encoder': 'bert-base-uncased',
    
    ## Embedder
    'num_attn_heads': 8,
    'fusion_mode': 'cat',
    'num_stacked_attn': 4, 
    
    'criss_cross__drop_p': 0.0,
    'post_concat__drop_p': 0.0, 
    'embed_attn__add_residual': False,
    'embed_attn__drop_p': 0.0,

    ## Label Classifier
    'label_classifier__use_bn': False,
    'label_classifier__drop_p': 0.0,
    'label_classifier__repeat_layers': [0, 0],

    ## Domain Classifier
    'domain_classifier__use_bn': True,
    'domain_classifier__drop_p': 0.5,
    'domain_classifier__repeat_layers': [2, 2], 

    ### Objective ###
    # loss fn
    'domain_adaptation_method': 'domain_adversarial',  # 'naive', 'importance_sampling', 'domain_adversarial'

    ### Trainer ###
    'relaxation_period': 3,  # epochs to wait where accuracy is dropping 
                            # below moving average before ending the run
                            # (-1 to disable it)
    
    'batch_size': 150,
    'epochs': 30,
    'base_lr': 0.001,
    'weight_decay': 5e-4,

    ### Logging ###
    'print_logs': True,
    # 'print_logs': False,

    'weights_save_root': './weights/raw'
}

if True:
    # v2
    cfg['source_domain'] = 'v2'
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    v2_ckpt_path = cfg['weights_save_path']

    trainer.train(show_plot=True)

    # abs
    cfg['source_domain'] = 'abs'
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    abs_ckpt_path = cfg['weights_save_path']

    trainer.train(show_plot=True)
# Out:
# weights_save_path: ./weights/raw/1uZjrGV1.pth
# Number of Common Labels = 6 | n_classes = 6
# Labels: ['yes', 'no', '0', '1', 'red', 'yellow']
# V2: 	Train size = 1200	             | Val size = 300 | Total = 1500
# Abs: 	Train size = 1200	             | Val size = 300 | Total = 1500
# --------------------
# Epoch [1/30]	                         Avg Train Loss: 1.277703	                         Avg Eval Loss: 1.272725	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.16
# Epoch [2/30]	                         Avg Train Loss: 1.270449	                         Avg Eval Loss: 1.281201	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.17
# Epoch [3/30]	                         Avg Train Loss: 1.264884	                         Avg Eval Loss: 1.273527	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.18
# Epoch [4/30]	                         Avg Train Loss: 1.262634	                         Avg Eval Loss: 1.262044	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.18
# Epoch [5/30]	                         Avg Train Loss: 1.269061	                         Avg Eval Loss: 1.282392	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.16
# Epoch [6/30]	                         Avg Train Loss: 1.260710	                         Avg Eval Loss: 1.247587	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.14
# Epoch [7/30]	                         Avg Train Loss: 1.262132	                         Avg Eval Loss: 1.275195	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.15
# Epoch [8/30]	                         Avg Train Loss: 1.316844	                         Avg Eval Loss: 1.247814	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.18
# Epoch [9/30]	                         Avg Train Loss: 1.249152	                         Avg Eval Loss: 1.243797	                         Avg Domain Accuracy: 0.54	                         Avg Eval Accuracy: 0.17
# Epoch [10/30]	                         Avg Train Loss: 1.255042	                         Avg Eval Loss: 1.257971	                         Avg Domain Accuracy: 0.46	                         Avg Eval Accuracy: 0.17
# Epoch [11/30]	                         Avg Train Loss: 1.278346	                         Avg Eval Loss: 1.246064	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.17
# Epoch [12/30]	                         Avg Train Loss: 1.307749	                         Avg Eval Loss: 1.256046	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.17
# Epoch [13/30]	                         Avg Train Loss: 1.855173	                         Avg Eval Loss: 1.416823	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.17
# Epoch [14/30]	                         Avg Train Loss: 1.330793	                         Avg Eval Loss: 1.446830	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.17
# Epoch [15/30]	                         Avg Train Loss: 11.085744	                         Avg Eval Loss: 21.621583	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.17
# Epoch [16/30]	                         Avg Train Loss: 11.440245	                         Avg Eval Loss: 3.237038	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.18
# Epoch [17/30]	                         Avg Train Loss: 25.338997	                         Avg Eval Loss: 37.128902	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.16
# Epoch [18/30]	                         Avg Train Loss: 619.672584	                         Avg Eval Loss: 461.766907	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.17
# Epoch [19/30]	                         Avg Train Loss: 601.225436	                         Avg Eval Loss: 247.693779	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.17
# Epoch [20/30]	                         Avg Train Loss: 52.727656	                         Avg Eval Loss: 2.042945	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.17
# Epoch [21/30]	                         Avg Train Loss: 1.254877	                         Avg Eval Loss: 1.245938	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.17
# Epoch [22/30]	                         Avg Train Loss: 1.245017	                         Avg Eval Loss: 1.246121	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.17
# Epoch [23/30]	                         Avg Train Loss: 1.243014	                         Avg Eval Loss: 1.245316	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.17
# Epoch [24/30]	                         Avg Train Loss: 1.282314	                         Avg Eval Loss: 1.245142	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.17
# Epoch [25/30]	                         Avg Train Loss: 1.244271	                         Avg Eval Loss: 1.246962	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.17
# Epoch [26/30]	                         Avg Train Loss: 1.244700	                         Avg Eval Loss: 1.244658	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.17
# Epoch [27/30]	                         Avg Train Loss: 1.244919	                         Avg Eval Loss: 1.243676	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.17
# Epoch [28/30]	                         Avg Train Loss: 1.244646	                         Avg Eval Loss: 1.246948	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.17
# Epoch [29/30]	                         Avg Train Loss: 1.245673	                         Avg Eval Loss: 1.245126	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.17
# Epoch [30/30]	                         Avg Train Loss: 1.246040	                         Avg Eval Loss: 1.246540	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.17
# weights_save_path: ./weights/raw/ODZKbNsf.pth
# Number of Common Labels = 6 | n_classes = 6
# Labels: ['yes', 'no', '0', '1', 'red', 'yellow']
# V2: 	Train size = 1200	             | Val size = 300 | Total = 1500
# Abs: 	Train size = 1200	             | Val size = 300 | Total = 1500
# --------------------
# Epoch [1/30]	                         Avg Train Loss: 1.275336	                         Avg Eval Loss: 1.273984	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.20
# Epoch [2/30]	                         Avg Train Loss: 1.273466	                         Avg Eval Loss: 1.270846	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.18
# Epoch [3/30]	                         Avg Train Loss: 1.292029	                         Avg Eval Loss: 1.268081	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.14
# Epoch [4/30]	                         Avg Train Loss: 1.294162	                         Avg Eval Loss: 1.285067	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.17
# Epoch [5/30]	                         Avg Train Loss: 1.273412	                         Avg Eval Loss: 1.258272	                         Avg Domain Accuracy: 0.54	                         Avg Eval Accuracy: 0.17
# Epoch [6/30]	                         Avg Train Loss: 1.266167	                         Avg Eval Loss: 1.253381	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.17
# Epoch [7/30]	                         Avg Train Loss: 1.254613	                         Avg Eval Loss: 1.244977	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.16
# Epoch [8/30]	                         Avg Train Loss: 1.270858	                         Avg Eval Loss: 1.251598	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.16
# Epoch [9/30]	                         Avg Train Loss: 1.251010	                         Avg Eval Loss: 1.256205	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.16
# Epoch [10/30]	                         Avg Train Loss: 1.251600	                         Avg Eval Loss: 1.258766	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.16
# Epoch [11/30]	                         Avg Train Loss: 1.252766	                         Avg Eval Loss: 1.248983	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.17
# Epoch [12/30]	                         Avg Train Loss: 1.243834	                         Avg Eval Loss: 1.250599	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.16
# Epoch [13/30]	                         Avg Train Loss: 1.248208	                         Avg Eval Loss: 1.246207	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.14
# Epoch [14/30]	                         Avg Train Loss: 1.245644	                         Avg Eval Loss: 1.244642	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.17
# Epoch [15/30]	                         Avg Train Loss: 1.242693	                         Avg Eval Loss: 1.240752	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.20
# Epoch [16/30]	                         Avg Train Loss: 1.185637	                         Avg Eval Loss: 1.094786	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.27
# Epoch [17/30]	                         Avg Train Loss: 1.015847	                         Avg Eval Loss: 1.006269	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.33
# Epoch [18/30]	                         Avg Train Loss: 0.975708	                         Avg Eval Loss: 0.957946	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.33
# Epoch [19/30]	                         Avg Train Loss: 0.946914	                         Avg Eval Loss: 0.944410	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.33
# Epoch [20/30]	                         Avg Train Loss: 0.943424	                         Avg Eval Loss: 0.941998	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.33
# Epoch [21/30]	                         Avg Train Loss: 0.936106	                         Avg Eval Loss: 0.941349	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.33
# Epoch [22/30]	                         Avg Train Loss: 0.931601	                         Avg Eval Loss: 0.942914	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.33
# Epoch [23/30]	                         Avg Train Loss: 0.929259	                         Avg Eval Loss: 0.937307	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.33
# Epoch [24/30]	                         Avg Train Loss: 0.928492	                         Avg Eval Loss: 0.929872	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.33
# Epoch [25/30]	                         Avg Train Loss: 0.912849	                         Avg Eval Loss: 0.914790	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.34
# Epoch [26/30]	                         Avg Train Loss: 0.897804	                         Avg Eval Loss: 0.904136	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.34
# Epoch [27/30]	                         Avg Train Loss: 0.887461	                         Avg Eval Loss: 0.905713	                         Avg Domain Accuracy: 0.45	                         Avg Eval Accuracy: 0.34
# Epoch [28/30]	                         Avg Train Loss: 0.882345	                         Avg Eval Loss: 0.892852	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.34
# Epoch [29/30]	                         Avg Train Loss: 0.874600	                         Avg Eval Loss: 0.886872	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.34
# Epoch [30/30]	                         Avg Train Loss: 0.870049	                         Avg Eval Loss: 0.886757	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.34

# %%
# v2_ckpt_path = './weights/raw/name=DANN__n_classes=10__v2_samples_per_answer=300__abs_samples_per_answer=150__source_domain=v2__base_lr=0.001__domain_adaptation_method=domain_adversarial__.pth'

# abs_ckpt_path = './weights/raw/name=DANN__n_classes=10__v2_samples_per_answer=300__abs_samples_per_answer=150__source_domain=abs__base_lr=0.001__domain_adaptation_method=domain_adversarial__.pth'

# %%
cfg['v2_ckpt'] = v2_ckpt_path
cfg['abs_ckpt'] = abs_ckpt_path

# %% [markdown]
# ## Evaluating

# %%
(v2_train_data, v2_val_data), (abs_train_data, abs_val_data), labels = data_processing_v2(cfg, vqa_v2, vqa_abs)
model = VLModel(cfg, return_embeddings=True).cuda()

def eval_domain_adaptation(eval_dataset, model_ckpt, evaluate_train=False):
    if eval_dataset == 'v2':
        train_data, val_data = v2_train_data, v2_val_data
    elif eval_dataset == 'abs':
        train_data, val_data = abs_train_data, abs_val_data

    train_dataset = VQADataset(cfg, train_data)
    val_dataset = VQADataset(cfg, val_data)

    train_dataloader = DataLoader(train_dataset, batch_size=cfg['batch_size'], shuffle=True)
    val_dataloader = DataLoader(val_dataset, batch_size=cfg['batch_size'], shuffle=True)

    if model_ckpt == 'v2':
        ckpt = cfg['v2_ckpt']
    elif model_ckpt == 'abs':
        ckpt = cfg['abs_ckpt']

    state_dict = torch.load(ckpt, weights_only=True)
    model.load_state_dict(state_dict, strict=False)

    dataloader = val_dataloader if not evaluate_train else train_dataloader

    model.eval()
    correct, total = 0, 0
    embeddings = None

    with torch.no_grad():
        for i_tokens, q_tokens, label in dataloader:
            i_tokens = {key: value.cuda() for key, value in i_tokens.items()}
            q_tokens = {key: value.cuda() for key, value in q_tokens.items()}
            label = label.cuda()
            
            logits, embedding = model(i_tokens, q_tokens)
            embeddings = np.concatenate((embeddings, embedding), axis=0) if embeddings is not None else embedding

            # Compute accuracy
            _, predicted_indices = torch.max(logits, dim=1)
            label_indices = torch.argmax(label, dim=1)
            is_correct = (predicted_indices == label_indices)

            total += label.shape[0]
            correct += is_correct.sum().item()

    accuracy = (correct / total)

    source = 'v2 ' if model_ckpt == 'v2' else 'abs'
    target = 'v2 ' if eval_dataset == 'v2' else 'abs'
    split = 'train set' if evaluate_train else 'val set  '
    print(f'{source} -> {target} | {split} \t accuracy = {accuracy*100:.2f}%')
    
    return embeddings
# Out:
# Number of Common Labels = 6 | n_classes = 6
# Labels: ['yes', 'no', '0', '1', 'red', 'yellow']
# V2: 	Train size = 1200	             | Val size = 300 | Total = 1500
# Abs: 	Train size = 1200	             | Val size = 300 | Total = 1500
# --------------------

# %%
# v2 -> v2
v2_val_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='v2', evaluate_train=False)
v2_train_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='v2', evaluate_train=True)

# abs -> abs
abs_val_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='abs', evaluate_train=False)
abs_train_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='abs', evaluate_train=True)
# Out:
# v2  -> v2  | val set   	 accuracy = 16.67%
# v2  -> v2  | train set 	 accuracy = 16.67%
# abs -> abs | val set   	 accuracy = 34.33%
# abs -> abs | train set 	 accuracy = 34.08%

# %%
# v2 -> abs
v2_abs_val_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='abs', evaluate_train=False)
v2_abs_train_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='abs', evaluate_train=True)

# abs -> v2
abs_v2_val_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='v2', evaluate_train=False)
abs_v2_train_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='v2', evaluate_train=True)
# Out:
# v2  -> abs | val set   	 accuracy = 16.67%
# v2  -> abs | train set 	 accuracy = 16.67%
# abs -> v2  | val set   	 accuracy = 32.33%
# abs -> v2  | train set 	 accuracy = 34.75%

# %% [markdown]
# ## Visualizing embeddings

# %%
from sklearn.manifold import TSNE
import matplotlib.patches as mpatches

def plot_tsne(embeddings, plot_labels, perplexities, title=''):
    n_plots = len(perplexities)
    fig, axes = plt.subplots(1, n_plots, figsize=(6 * n_plots, 6))
    
    for idx, perplexity in enumerate(perplexities):
        tsne = TSNE(n_components=2, perplexity=perplexity, random_state=42)
        tsne_embeddings = tsne.fit_transform(embeddings)
        
        colors = {'vv': 'blue', 'aa': 'red', 'va': 'orange', 'av': 'violet'}
        ax = axes[idx]
        for i, plot_label in enumerate(plot_labels):
                
            ax.scatter(tsne_embeddings[i, 0], tsne_embeddings[i, 1], color=colors[plot_label])
            ax.text(tsne_embeddings[i, 0] + 0.1, tsne_embeddings[i, 1], '', fontsize=9)
        
        ax.set_title(f'Perplexity = {perplexity}')
    
    custom_legend = [mpatches.Patch(color=colors[label], label=label) for label in set(plot_labels)]
    fig.legend(handles=custom_legend)
    fig.suptitle(title, fontsize=16)

    plt.tight_layout()
    plt.show()

# %%
n_v2 = len(v2_val_embeddings)
n_abs = len(abs_val_embeddings)

# v2 -> v2
plot_tsne(v2_val_embeddings, ['vv'] * n_v2, perplexities=[2,4,8,16,32], title='v2->v2 (val set)')
plot_tsne(v2_train_embeddings, ['vv'] * n_v2, perplexities=[2,4,8,16,32], title='v2->v2 (train set)')

# abs -> abs
plot_tsne(abs_val_embeddings, ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='abs->abs (val set)')
plot_tsne(abs_train_embeddings, ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='abs->abs (train set)')

# combined plot
val_embeddings = np.concatenate((v2_val_embeddings, abs_val_embeddings), axis=0)
plot_tsne(val_embeddings, ['vv'] * n_v2 + ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='Same Domain (val set)')

train_embeddings = np.concatenate((v2_train_embeddings, abs_train_embeddings), axis=0)
plot_tsne(train_embeddings, ['vv'] * n_v2 + ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='Same Domain (train set)')

# %%
# v2 -> abs
plot_tsne(v2_abs_val_embeddings, ['va'] * n_abs, perplexities=[2,4,8,16,32], title='v2->abs (val set)')
plot_tsne(v2_abs_train_embeddings, ['va'] * n_abs, perplexities=[2,4,8,16,32], title='v2->abs (train set)')

# abs -> v2
plot_tsne(abs_v2_val_embeddings, ['av'] * n_v2, perplexities=[2,4,8,16,32], title='abs->v2 (val set)')
plot_tsne(abs_v2_train_embeddings, ['av'] * n_v2, perplexities=[2,4,8,16,32], title='abs->v2 (train set)')

# combined plot
val_embeddings = np.concatenate((v2_abs_val_embeddings, abs_v2_val_embeddings), axis=0)
plot_tsne(val_embeddings, ['va'] * n_abs + ['av'] * n_v2, perplexities=[2,4,8,16,32], title='Cross Domain (val set)')

train_embeddings = np.concatenate((v2_abs_train_embeddings, abs_v2_train_embeddings), axis=0)
plot_tsne(train_embeddings, ['va'] * n_abs + ['av'] * n_v2, perplexities=[2,4,8,16,32], title='Cross Domain (train set)')
