# %% [markdown]
# ## Domain Adversarial

# %%
import os
os.chdir('/workspace')

from trainer import *

cfg = {
    ### META ###
    'name': 'DANN',

    ### DataLoader ###
    'n_classes': 6,
    'labels': [
        'yes', 'no',
        '0', '1',  
        'red', 'yellow', 
    ],
    'v2_samples_per_answer': 300,
    'abs_samples_per_answer': 300,

    'v2_samples_per_answer_train': 200,
    'v2_samples_per_answer_val': 50,

    'abs_samples_per_answer_train': 200,
    'abs_samples_per_answer_val': 50,

    'source_domain': 'abs',
    
    ### VLModel ###
    'image_encoder': 'facebook/dinov2-base',
    'text_encoder': 'bert-base-uncased',
    
    ## Embedder
    'num_attn_heads': 8,
    'fusion_mode': 'cat',
    'num_stacked_attn': 1, 
    
    'criss_cross__drop_p': 0.0,
    'post_concat__drop_p': 0.0, 
    'embed_attn__add_residual': False,
    'embed_attn__drop_p': 0.0,

    ## Label Classifier
    'label_classifier__use_bn': False,
    'label_classifier__drop_p': 0.0,
    'label_classifier__repeat_layers': [0, 0],

    ## Domain Classifier
    'domain_classifier__use_bn': True,
    'domain_classifier__drop_p': 0.5,
    'domain_classifier__repeat_layers': [2, 2], 

    ### Objective ###
    # loss fn
    'domain_adaptation_method': 'domain_adversarial',  # 'naive', 'importance_sampling', 'domain_adversarial'

    ### Trainer ###
    'relaxation_period': 3,  # epochs to wait where accuracy is dropping 
                            # below moving average before ending the run
                            # (-1 to disable it)
    
    'batch_size': 150,
    'epochs': 30,
    'base_lr': 0.001,
    'weight_decay': 5e-4,

    ### Logging ###
    'print_logs': True,
    # 'print_logs': False,

    'weights_save_root': './weights/raw'
}

if True:
    # v2
    cfg['source_domain'] = 'v2'
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    v2_ckpt_path = cfg['weights_save_path']

    trainer.train(show_plot=True)

    # abs
    cfg['source_domain'] = 'abs'
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    abs_ckpt_path = cfg['weights_save_path']

    trainer.train(show_plot=True)
# Out:
# weights_save_path: ./weights/raw/0zzdX1JK.pth
# Number of Common Labels = 6 | n_classes = 6
# Labels: ['yes', 'no', '0', '1', 'red', 'yellow']
# V2: 	Train size = 1200	             | Val size = 300 | Total = 1500
# Abs: 	Train size = 1200	             | Val size = 300 | Total = 1500
# --------------------
# Epoch [1/30]	                         Avg Train Loss: 1.262950	                         Avg Eval Loss: 1.284299	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.17
# Epoch [2/30]	                         Avg Train Loss: 1.211469	                         Avg Eval Loss: 1.042862	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.44
# Epoch [3/30]	                         Avg Train Loss: 0.996866	                         Avg Eval Loss: 0.760307	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.51
# Epoch [4/30]	                         Avg Train Loss: 0.766881	                         Avg Eval Loss: 0.752566	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.50
# Epoch [5/30]	                         Avg Train Loss: 0.738785	                         Avg Eval Loss: 0.726776	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.49
# Epoch [6/30]	                         Avg Train Loss: 0.709480	                         Avg Eval Loss: 0.717152	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.51
# Epoch [7/30]	                         Avg Train Loss: 0.691520	                         Avg Eval Loss: 0.726991	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.48
# Epoch [8/30]	                         Avg Train Loss: 0.686106	                         Avg Eval Loss: 0.732432	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.53
# Epoch [9/30]	                         Avg Train Loss: 0.667809	                         Avg Eval Loss: 0.752813	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.51
# Epoch [10/30]	                         Avg Train Loss: 0.626540	                         Avg Eval Loss: 0.774369	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.53
# Epoch [11/30]	                         Avg Train Loss: 0.600187	                         Avg Eval Loss: 0.797851	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.54
# Epoch [12/30]	                         Avg Train Loss: 0.584119	                         Avg Eval Loss: 0.836029	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.54
# Epoch [13/30]	                         Avg Train Loss: 0.560000	                         Avg Eval Loss: 0.817647	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.54
# Epoch [14/30]	                         Avg Train Loss: 0.542541	                         Avg Eval Loss: 0.981652	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.53
# Epoch [15/30]	                         Avg Train Loss: 0.505324	                         Avg Eval Loss: 1.011946	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.53
# Epoch [16/30]	                         Avg Train Loss: 0.492606	                         Avg Eval Loss: 0.992435	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.54
# Epoch [17/30]	                         Avg Train Loss: 0.460176	                         Avg Eval Loss: 1.082700	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.56
# Epoch [18/30]	                         Avg Train Loss: 0.445215	                         Avg Eval Loss: 1.147294	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.54
# Epoch [19/30]	                         Avg Train Loss: 0.439015	                         Avg Eval Loss: 1.211010	                         Avg Domain Accuracy: 0.45	                         Avg Eval Accuracy: 0.53
# Epoch [20/30]	                         Avg Train Loss: 0.436761	                         Avg Eval Loss: 1.151328	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.52
# Epoch [21/30]	                         Avg Train Loss: 0.431455	                         Avg Eval Loss: 1.263989	                         Avg Domain Accuracy: 0.45	                         Avg Eval Accuracy: 0.53
# Epoch [22/30]	                         Avg Train Loss: 0.430592	                         Avg Eval Loss: 1.245851	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.54
# Epoch [23/30]	                         Avg Train Loss: 0.420105	                         Avg Eval Loss: 1.245145	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.53
# Epoch [24/30]	                         Avg Train Loss: 0.410235	                         Avg Eval Loss: 1.207602	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.52
# Epoch [25/30]	                         Avg Train Loss: 0.406577	                         Avg Eval Loss: 1.362306	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.51
# Epoch [26/30]	                         Avg Train Loss: 0.398861	                         Avg Eval Loss: 1.383203	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.53
# Epoch [27/30]	                         Avg Train Loss: 0.392899	                         Avg Eval Loss: 1.383046	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.52
# Epoch [28/30]	                         Avg Train Loss: 0.388523	                         Avg Eval Loss: 1.458258	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.52
# Epoch [29/30]	                         Avg Train Loss: 0.383869	                         Avg Eval Loss: 1.494407	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.52
# Epoch [30/30]	                         Avg Train Loss: 0.378977	                         Avg Eval Loss: 1.512027	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.53
# weights_save_path: ./weights/raw/8EjknlNT.pth
# Number of Common Labels = 6 | n_classes = 6
# Labels: ['yes', 'no', '0', '1', 'red', 'yellow']
# V2: 	Train size = 1200	             | Val size = 300 | Total = 1500
# Abs: 	Train size = 1200	             | Val size = 300 | Total = 1500
# --------------------
# Epoch [1/30]	                         Avg Train Loss: 1.273259	                         Avg Eval Loss: 1.221083	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.40
# Epoch [2/30]	                         Avg Train Loss: 1.196827	                         Avg Eval Loss: 1.027091	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.43
# Epoch [3/30]	                         Avg Train Loss: 0.940616	                         Avg Eval Loss: 0.785139	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.49
# Epoch [4/30]	                         Avg Train Loss: 0.769579	                         Avg Eval Loss: 0.738141	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.48
# Epoch [5/30]	                         Avg Train Loss: 0.735262	                         Avg Eval Loss: 0.731503	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.51
# Epoch [6/30]	                         Avg Train Loss: 0.725138	                         Avg Eval Loss: 0.728486	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.50
# Epoch [7/30]	                         Avg Train Loss: 0.718234	                         Avg Eval Loss: 0.717751	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.50
# Epoch [8/30]	                         Avg Train Loss: 0.713127	                         Avg Eval Loss: 0.718507	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.51
# Epoch [9/30]	                         Avg Train Loss: 0.707700	                         Avg Eval Loss: 0.709942	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.52
# Epoch [10/30]	                         Avg Train Loss: 0.699213	                         Avg Eval Loss: 0.708223	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.52
# Epoch [11/30]	                         Avg Train Loss: 0.693891	                         Avg Eval Loss: 0.707912	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.53
# Epoch [12/30]	                         Avg Train Loss: 0.683879	                         Avg Eval Loss: 0.714297	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.52
# Epoch [13/30]	                         Avg Train Loss: 0.669921	                         Avg Eval Loss: 0.738066	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.52
# Epoch [14/30]	                         Avg Train Loss: 0.656387	                         Avg Eval Loss: 0.728428	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.53
# Epoch [15/30]	                         Avg Train Loss: 0.629298	                         Avg Eval Loss: 0.732694	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.54
# Epoch [16/30]	                         Avg Train Loss: 0.600604	                         Avg Eval Loss: 0.773393	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.56
# Epoch [17/30]	                         Avg Train Loss: 0.567204	                         Avg Eval Loss: 0.791130	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.55
# Epoch [18/30]	                         Avg Train Loss: 0.544452	                         Avg Eval Loss: 0.879937	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.55
# Epoch [19/30]	                         Avg Train Loss: 0.518807	                         Avg Eval Loss: 0.964923	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.58
# Epoch [20/30]	                         Avg Train Loss: 0.503294	                         Avg Eval Loss: 0.953815	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.57
# Epoch [21/30]	                         Avg Train Loss: 0.479682	                         Avg Eval Loss: 1.013884	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.54
# Epoch [22/30]	                         Avg Train Loss: 0.461873	                         Avg Eval Loss: 1.091819	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.54
# Epoch [23/30]	                         Avg Train Loss: 0.469550	                         Avg Eval Loss: 1.028391	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.54
# Epoch [24/30]	                         Avg Train Loss: 0.453536	                         Avg Eval Loss: 1.005076	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.55
# Epoch [25/30]	                         Avg Train Loss: 0.438859	                         Avg Eval Loss: 1.116935	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.53
# Epoch [26/30]	                         Avg Train Loss: 0.419666	                         Avg Eval Loss: 1.199293	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.53
# Epoch [27/30]	                         Avg Train Loss: 0.414061	                         Avg Eval Loss: 1.249068	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.55
# Epoch [28/30]	                         Avg Train Loss: 0.409136	                         Avg Eval Loss: 1.261422	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.53
# Epoch [29/30]	                         Avg Train Loss: 0.405441	                         Avg Eval Loss: 1.237509	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.54
# Epoch [30/30]	                         Avg Train Loss: 0.394694	                         Avg Eval Loss: 1.246240	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.54

# %%
# v2_ckpt_path = './weights/raw/name=DANN__n_classes=10__v2_samples_per_answer=300__abs_samples_per_answer=150__source_domain=v2__base_lr=0.001__domain_adaptation_method=domain_adversarial__.pth'

# abs_ckpt_path = './weights/raw/name=DANN__n_classes=10__v2_samples_per_answer=300__abs_samples_per_answer=150__source_domain=abs__base_lr=0.001__domain_adaptation_method=domain_adversarial__.pth'

# %%
cfg['v2_ckpt'] = v2_ckpt_path
cfg['abs_ckpt'] = abs_ckpt_path

# %% [markdown]
# ## Evaluating

# %%
(v2_train_data, v2_val_data), (abs_train_data, abs_val_data), labels = data_processing_v2(cfg, vqa_v2, vqa_abs)
model = VLModel(cfg, return_embeddings=True).cuda()

def eval_domain_adaptation(eval_dataset, model_ckpt, evaluate_train=False):
    if eval_dataset == 'v2':
        train_data, val_data = v2_train_data, v2_val_data
    elif eval_dataset == 'abs':
        train_data, val_data = abs_train_data, abs_val_data

    train_dataset = VQADataset(cfg, train_data)
    val_dataset = VQADataset(cfg, val_data)

    train_dataloader = DataLoader(train_dataset, batch_size=cfg['batch_size'], shuffle=True)
    val_dataloader = DataLoader(val_dataset, batch_size=cfg['batch_size'], shuffle=True)

    if model_ckpt == 'v2':
        ckpt = cfg['v2_ckpt']
    elif model_ckpt == 'abs':
        ckpt = cfg['abs_ckpt']

    state_dict = torch.load(ckpt, weights_only=True)
    model.load_state_dict(state_dict, strict=False)

    dataloader = val_dataloader if not evaluate_train else train_dataloader

    model.eval()
    correct, total = 0, 0
    embeddings = None

    with torch.no_grad():
        for i_tokens, q_tokens, label in dataloader:
            i_tokens = {key: value.cuda() for key, value in i_tokens.items()}
            q_tokens = {key: value.cuda() for key, value in q_tokens.items()}
            label = label.cuda()
            
            logits, embedding = model(i_tokens, q_tokens)
            embeddings = np.concatenate((embeddings, embedding), axis=0) if embeddings is not None else embedding

            # Compute accuracy
            _, predicted_indices = torch.max(logits, dim=1)
            label_indices = torch.argmax(label, dim=1)
            is_correct = (predicted_indices == label_indices)

            total += label.shape[0]
            correct += is_correct.sum().item()

    accuracy = (correct / total)

    source = 'v2 ' if model_ckpt == 'v2' else 'abs'
    target = 'v2 ' if eval_dataset == 'v2' else 'abs'
    split = 'train set' if evaluate_train else 'val set  '
    print(f'{source} -> {target} | {split} \t accuracy = {accuracy*100:.2f}%')
    
    return embeddings
# Out:
# Number of Common Labels = 6 | n_classes = 6
# Labels: ['yes', 'no', '0', '1', 'red', 'yellow']
# V2: 	Train size = 1200	             | Val size = 300 | Total = 1500
# Abs: 	Train size = 1200	             | Val size = 300 | Total = 1500
# --------------------

# %%
# v2 -> v2
v2_val_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='v2', evaluate_train=False)
v2_train_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='v2', evaluate_train=True)

# abs -> abs
abs_val_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='abs', evaluate_train=False)
abs_train_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='abs', evaluate_train=True)
# Out:
# v2  -> v2  | val set   	 accuracy = 50.67%
# v2  -> v2  | train set 	 accuracy = 58.67%
# abs -> abs | val set   	 accuracy = 56.67%
# abs -> abs | train set 	 accuracy = 59.50%

# %%
# v2 -> abs
v2_abs_val_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='abs', evaluate_train=False)
v2_abs_train_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='abs', evaluate_train=True)

# abs -> v2
abs_v2_val_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='v2', evaluate_train=False)
abs_v2_train_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='v2', evaluate_train=True)
# Out:
# v2  -> abs | val set   	 accuracy = 50.00%
# v2  -> abs | train set 	 accuracy = 57.08%
# abs -> v2  | val set   	 accuracy = 48.33%
# abs -> v2  | train set 	 accuracy = 58.00%

# %% [markdown]
# ## Visualizing embeddings

# %%
from sklearn.manifold import TSNE
import matplotlib.patches as mpatches

def plot_tsne(embeddings, plot_labels, perplexities, title=''):
    n_plots = len(perplexities)
    fig, axes = plt.subplots(1, n_plots, figsize=(6 * n_plots, 6))
    
    for idx, perplexity in enumerate(perplexities):
        tsne = TSNE(n_components=2, perplexity=perplexity, random_state=42)
        tsne_embeddings = tsne.fit_transform(embeddings)
        
        colors = {'vv': 'blue', 'aa': 'red', 'va': 'orange', 'av': 'violet'}
        ax = axes[idx]
        for i, plot_label in enumerate(plot_labels):
                
            ax.scatter(tsne_embeddings[i, 0], tsne_embeddings[i, 1], color=colors[plot_label])
            ax.text(tsne_embeddings[i, 0] + 0.1, tsne_embeddings[i, 1], '', fontsize=9)
        
        ax.set_title(f'Perplexity = {perplexity}')
    
    custom_legend = [mpatches.Patch(color=colors[label], label=label) for label in set(plot_labels)]
    fig.legend(handles=custom_legend)
    fig.suptitle(title, fontsize=16)

    plt.tight_layout()
    plt.show()

# %%
n_v2 = len(v2_val_embeddings)
n_abs = len(abs_val_embeddings)

# v2 -> v2
plot_tsne(v2_val_embeddings, ['vv'] * n_v2, perplexities=[2,4,8,16,32], title='v2->v2 (val set)')
plot_tsne(v2_train_embeddings, ['vv'] * n_v2, perplexities=[2,4,8,16,32], title='v2->v2 (train set)')

# abs -> abs
plot_tsne(abs_val_embeddings, ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='abs->abs (val set)')
plot_tsne(abs_train_embeddings, ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='abs->abs (train set)')

# combined plot
val_embeddings = np.concatenate((v2_val_embeddings, abs_val_embeddings), axis=0)
plot_tsne(val_embeddings, ['vv'] * n_v2 + ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='Same Domain (val set)')

train_embeddings = np.concatenate((v2_train_embeddings, abs_train_embeddings), axis=0)
plot_tsne(train_embeddings, ['vv'] * n_v2 + ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='Same Domain (train set)')

# %%
# v2 -> abs
plot_tsne(v2_abs_val_embeddings, ['va'] * n_abs, perplexities=[2,4,8,16,32], title='v2->abs (val set)')
plot_tsne(v2_abs_train_embeddings, ['va'] * n_abs, perplexities=[2,4,8,16,32], title='v2->abs (train set)')

# abs -> v2
plot_tsne(abs_v2_val_embeddings, ['av'] * n_v2, perplexities=[2,4,8,16,32], title='abs->v2 (val set)')
plot_tsne(abs_v2_train_embeddings, ['av'] * n_v2, perplexities=[2,4,8,16,32], title='abs->v2 (train set)')

# combined plot
val_embeddings = np.concatenate((v2_abs_val_embeddings, abs_v2_val_embeddings), axis=0)
plot_tsne(val_embeddings, ['va'] * n_abs + ['av'] * n_v2, perplexities=[2,4,8,16,32], title='Cross Domain (val set)')

train_embeddings = np.concatenate((v2_abs_train_embeddings, abs_v2_train_embeddings), axis=0)
plot_tsne(train_embeddings, ['va'] * n_abs + ['av'] * n_v2, perplexities=[2,4,8,16,32], title='Cross Domain (train set)')
