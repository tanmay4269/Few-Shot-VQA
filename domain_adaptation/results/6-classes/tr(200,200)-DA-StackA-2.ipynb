# %% [markdown]
# ## Domain Adversarial

# %%
import os
os.chdir('/workspace')

from trainer import *

cfg = {
    ### META ###
    'name': 'DANN',

    ### DataLoader ###
    'n_classes': 6,
    'labels': [
        'yes', 'no',
        '0', '1',  
        'red', 'yellow', 
    ],
    'v2_samples_per_answer': 300,
    'abs_samples_per_answer': 300,

    'v2_samples_per_answer_train': 200,
    'v2_samples_per_answer_val': 50,

    'abs_samples_per_answer_train': 200,
    'abs_samples_per_answer_val': 50,

    'source_domain': 'abs',
    
    ### VLModel ###
    'image_encoder': 'facebook/dinov2-base',
    'text_encoder': 'bert-base-uncased',
    
    ## Embedder
    'num_attn_heads': 8,
    'fusion_mode': 'cat',
    'num_stacked_attn': 2, 
    
    'criss_cross__drop_p': 0.0,
    'post_concat__drop_p': 0.0, 
    'embed_attn__add_residual': False,
    'embed_attn__drop_p': 0.0,

    ## Label Classifier
    'label_classifier__use_bn': False,
    'label_classifier__drop_p': 0.0,
    'label_classifier__repeat_layers': [0, 0],

    ## Domain Classifier
    'domain_classifier__use_bn': True,
    'domain_classifier__drop_p': 0.5,
    'domain_classifier__repeat_layers': [2, 2], 

    ### Objective ###
    # loss fn
    'domain_adaptation_method': 'domain_adversarial',  # 'naive', 'importance_sampling', 'domain_adversarial'

    ### Trainer ###
    'relaxation_period': 3,  # epochs to wait where accuracy is dropping 
                            # below moving average before ending the run
                            # (-1 to disable it)
    
    'batch_size': 150,
    'epochs': 30,
    'base_lr': 0.001,
    'weight_decay': 5e-4,

    ### Logging ###
    'print_logs': True,
    # 'print_logs': False,

    'weights_save_root': './weights/raw'
}

if True:
    # v2
    cfg['source_domain'] = 'v2'
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    v2_ckpt_path = cfg['weights_save_path']

    trainer.train(show_plot=True)

    # abs
    cfg['source_domain'] = 'abs'
    trainer = DA_Trainer(cfg, vqa_v2, vqa_abs)
    abs_ckpt_path = cfg['weights_save_path']

    trainer.train(show_plot=True)
# Out:
# weights_save_path: ./weights/raw/TU5hxa72.pth
# Number of Common Labels = 6 | n_classes = 6
# Labels: ['yes', 'no', '0', '1', 'red', 'yellow']
# V2: 	Train size = 1200	             | Val size = 300 | Total = 1500
# Abs: 	Train size = 1200	             | Val size = 300 | Total = 1500
# --------------------
# Epoch [1/30]	                         Avg Train Loss: 1.277547	                         Avg Eval Loss: 1.264291	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.20
# Epoch [2/30]	                         Avg Train Loss: 1.341705	                         Avg Eval Loss: 1.251106	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.18
# Epoch [3/30]	                         Avg Train Loss: 1.352615	                         Avg Eval Loss: 1.167289	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.21
# Epoch [4/30]	                         Avg Train Loss: 1.129132	                         Avg Eval Loss: 1.028133	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.33
# Epoch [5/30]	                         Avg Train Loss: 0.960972	                         Avg Eval Loss: 0.917538	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.33
# Epoch [6/30]	                         Avg Train Loss: 0.921093	                         Avg Eval Loss: 0.893468	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.33
# Epoch [7/30]	                         Avg Train Loss: 0.872208	                         Avg Eval Loss: 0.774620	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.47
# Epoch [8/30]	                         Avg Train Loss: 0.771297	                         Avg Eval Loss: 0.823932	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.48
# Epoch [9/30]	                         Avg Train Loss: 0.758426	                         Avg Eval Loss: 0.724428	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.49
# Epoch [10/30]	                         Avg Train Loss: 2.023439	                         Avg Eval Loss: 1.130615	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.37
# Epoch [11/30]	                         Avg Train Loss: 1.031283	                         Avg Eval Loss: 0.935981	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.37
# Epoch [12/30]	                         Avg Train Loss: 0.967019	                         Avg Eval Loss: 0.816241	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.48
# Epoch [13/30]	                         Avg Train Loss: 1.023361	                         Avg Eval Loss: 0.920807	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.36
# Epoch [14/30]	                         Avg Train Loss: 0.889521	                         Avg Eval Loss: 0.812060	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.48
# Epoch [15/30]	                         Avg Train Loss: 1.533060	                         Avg Eval Loss: 1.294758	                         Avg Domain Accuracy: 0.54	                         Avg Eval Accuracy: 0.34
# Epoch [16/30]	                         Avg Train Loss: 1.263602	                         Avg Eval Loss: 1.170256	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.32
# Epoch [17/30]	                         Avg Train Loss: 1.012181	                         Avg Eval Loss: 0.953037	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.36
# Epoch [18/30]	                         Avg Train Loss: 0.912675	                         Avg Eval Loss: 0.916061	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.39
# Epoch [19/30]	                         Avg Train Loss: 0.879140	                         Avg Eval Loss: 0.804661	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.45
# Epoch [20/30]	                         Avg Train Loss: 0.768219	                         Avg Eval Loss: 0.756335	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.50
# Epoch [21/30]	                         Avg Train Loss: 0.751543	                         Avg Eval Loss: 0.731893	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.50
# Epoch [22/30]	                         Avg Train Loss: 0.737711	                         Avg Eval Loss: 0.735941	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.49
# Epoch [23/30]	                         Avg Train Loss: 0.725200	                         Avg Eval Loss: 0.716687	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.50
# Epoch [24/30]	                         Avg Train Loss: 0.719819	                         Avg Eval Loss: 0.724366	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.48
# Epoch [25/30]	                         Avg Train Loss: 0.711665	                         Avg Eval Loss: 0.724247	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.50
# Epoch [26/30]	                         Avg Train Loss: 0.709727	                         Avg Eval Loss: 0.720555	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.50
# Epoch [27/30]	                         Avg Train Loss: 0.707613	                         Avg Eval Loss: 0.722285	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.51
# Epoch [28/30]	                         Avg Train Loss: 0.706032	                         Avg Eval Loss: 0.718236	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.51
# Epoch [29/30]	                         Avg Train Loss: 0.699162	                         Avg Eval Loss: 0.712659	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.51
# Epoch [30/30]	                         Avg Train Loss: 0.693981	                         Avg Eval Loss: 0.713866	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.51
# weights_save_path: ./weights/raw/CTIfskhq.pth
# Number of Common Labels = 6 | n_classes = 6
# Labels: ['yes', 'no', '0', '1', 'red', 'yellow']
# V2: 	Train size = 1200	             | Val size = 300 | Total = 1500
# Abs: 	Train size = 1200	             | Val size = 300 | Total = 1500
# --------------------
# Epoch [1/30]	                         Avg Train Loss: 1.278727	                         Avg Eval Loss: 1.256200	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.17
# Epoch [2/30]	                         Avg Train Loss: 1.313214	                         Avg Eval Loss: 1.042565	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.33
# Epoch [3/30]	                         Avg Train Loss: 1.132940	                         Avg Eval Loss: 1.008408	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.33
# Epoch [4/30]	                         Avg Train Loss: 0.977609	                         Avg Eval Loss: 0.931302	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.33
# Epoch [5/30]	                         Avg Train Loss: 0.938011	                         Avg Eval Loss: 1.027973	                         Avg Domain Accuracy: 0.53	                         Avg Eval Accuracy: 0.29
# Epoch [6/30]	                         Avg Train Loss: 1.571775	                         Avg Eval Loss: 1.145239	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.25
# Epoch [7/30]	                         Avg Train Loss: 1.035809	                         Avg Eval Loss: 0.936467	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.33
# Epoch [8/30]	                         Avg Train Loss: 1.132889	                         Avg Eval Loss: 1.328296	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.13
# Epoch [9/30]	                         Avg Train Loss: 1.140022	                         Avg Eval Loss: 0.950314	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.33
# Epoch [10/30]	                         Avg Train Loss: 0.925343	                         Avg Eval Loss: 0.857323	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.45
# Epoch [11/30]	                         Avg Train Loss: 1.023416	                         Avg Eval Loss: 1.094783	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.31
# Epoch [12/30]	                         Avg Train Loss: 1.138809	                         Avg Eval Loss: 1.161401	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.34
# Epoch [13/30]	                         Avg Train Loss: 1.006821	                         Avg Eval Loss: 0.925752	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.34
# Epoch [14/30]	                         Avg Train Loss: 0.920158	                         Avg Eval Loss: 2.369929	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.35
# Epoch [15/30]	                         Avg Train Loss: 11.194531	                         Avg Eval Loss: 1.256754	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.19
# Epoch [16/30]	                         Avg Train Loss: 1.251964	                         Avg Eval Loss: 1.205002	                         Avg Domain Accuracy: 0.50	                         Avg Eval Accuracy: 0.18
# Epoch [17/30]	                         Avg Train Loss: 1.144440	                         Avg Eval Loss: 0.985481	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.34
# Epoch [18/30]	                         Avg Train Loss: 0.967256	                         Avg Eval Loss: 0.926094	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.35
# Epoch [19/30]	                         Avg Train Loss: 0.896535	                         Avg Eval Loss: 0.814226	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.46
# Epoch [20/30]	                         Avg Train Loss: 0.796123	                         Avg Eval Loss: 1.725972	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.34
# Epoch [21/30]	                         Avg Train Loss: 1.101373	                         Avg Eval Loss: 0.916434	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.35
# Epoch [22/30]	                         Avg Train Loss: 0.898046	                         Avg Eval Loss: 0.867823	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.46
# Epoch [23/30]	                         Avg Train Loss: 0.835601	                         Avg Eval Loss: 0.814524	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.49
# Epoch [24/30]	                         Avg Train Loss: 0.802349	                         Avg Eval Loss: 0.772985	                         Avg Domain Accuracy: 0.48	                         Avg Eval Accuracy: 0.49
# Epoch [25/30]	                         Avg Train Loss: 0.755938	                         Avg Eval Loss: 0.746502	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.48
# Epoch [26/30]	                         Avg Train Loss: 0.734383	                         Avg Eval Loss: 0.735495	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.47
# Epoch [27/30]	                         Avg Train Loss: 0.722748	                         Avg Eval Loss: 0.731613	                         Avg Domain Accuracy: 0.52	                         Avg Eval Accuracy: 0.49
# Epoch [28/30]	                         Avg Train Loss: 0.721832	                         Avg Eval Loss: 0.728541	                         Avg Domain Accuracy: 0.49	                         Avg Eval Accuracy: 0.50
# Epoch [29/30]	                         Avg Train Loss: 0.714260	                         Avg Eval Loss: 0.724684	                         Avg Domain Accuracy: 0.47	                         Avg Eval Accuracy: 0.51
# Epoch [30/30]	                         Avg Train Loss: 0.708405	                         Avg Eval Loss: 0.718099	                         Avg Domain Accuracy: 0.51	                         Avg Eval Accuracy: 0.52

# %%
# v2_ckpt_path = './weights/raw/name=DANN__n_classes=10__v2_samples_per_answer=300__abs_samples_per_answer=150__source_domain=v2__base_lr=0.001__domain_adaptation_method=domain_adversarial__.pth'

# abs_ckpt_path = './weights/raw/name=DANN__n_classes=10__v2_samples_per_answer=300__abs_samples_per_answer=150__source_domain=abs__base_lr=0.001__domain_adaptation_method=domain_adversarial__.pth'

# %%
cfg['v2_ckpt'] = v2_ckpt_path
cfg['abs_ckpt'] = abs_ckpt_path

# %% [markdown]
# ## Evaluating

# %%
(v2_train_data, v2_val_data), (abs_train_data, abs_val_data), labels = data_processing_v2(cfg, vqa_v2, vqa_abs)
model = VLModel(cfg, return_embeddings=True).cuda()

def eval_domain_adaptation(eval_dataset, model_ckpt, evaluate_train=False):
    if eval_dataset == 'v2':
        train_data, val_data = v2_train_data, v2_val_data
    elif eval_dataset == 'abs':
        train_data, val_data = abs_train_data, abs_val_data

    train_dataset = VQADataset(cfg, train_data)
    val_dataset = VQADataset(cfg, val_data)

    train_dataloader = DataLoader(train_dataset, batch_size=cfg['batch_size'], shuffle=True)
    val_dataloader = DataLoader(val_dataset, batch_size=cfg['batch_size'], shuffle=True)

    if model_ckpt == 'v2':
        ckpt = cfg['v2_ckpt']
    elif model_ckpt == 'abs':
        ckpt = cfg['abs_ckpt']

    state_dict = torch.load(ckpt, weights_only=True)
    model.load_state_dict(state_dict, strict=False)

    dataloader = val_dataloader if not evaluate_train else train_dataloader

    model.eval()
    correct, total = 0, 0
    embeddings = None

    with torch.no_grad():
        for i_tokens, q_tokens, label in dataloader:
            i_tokens = {key: value.cuda() for key, value in i_tokens.items()}
            q_tokens = {key: value.cuda() for key, value in q_tokens.items()}
            label = label.cuda()
            
            logits, embedding = model(i_tokens, q_tokens)
            embeddings = np.concatenate((embeddings, embedding), axis=0) if embeddings is not None else embedding

            # Compute accuracy
            _, predicted_indices = torch.max(logits, dim=1)
            label_indices = torch.argmax(label, dim=1)
            is_correct = (predicted_indices == label_indices)

            total += label.shape[0]
            correct += is_correct.sum().item()

    accuracy = (correct / total)

    source = 'v2 ' if model_ckpt == 'v2' else 'abs'
    target = 'v2 ' if eval_dataset == 'v2' else 'abs'
    split = 'train set' if evaluate_train else 'val set  '
    print(f'{source} -> {target} | {split} \t accuracy = {accuracy*100:.2f}%')
    
    return embeddings
# Out:
# Number of Common Labels = 6 | n_classes = 6
# Labels: ['yes', 'no', '0', '1', 'red', 'yellow']
# V2: 	Train size = 1200	             | Val size = 300 | Total = 1500
# Abs: 	Train size = 1200	             | Val size = 300 | Total = 1500
# --------------------

# %%
# v2 -> v2
v2_val_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='v2', evaluate_train=False)
v2_train_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='v2', evaluate_train=True)

# abs -> abs
abs_val_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='abs', evaluate_train=False)
abs_train_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='abs', evaluate_train=True)
# Out:
# v2  -> v2  | val set   	 accuracy = 50.33%
# v2  -> v2  | train set 	 accuracy = 55.17%
# abs -> abs | val set   	 accuracy = 54.67%
# abs -> abs | train set 	 accuracy = 54.25%

# %%
# v2 -> abs
v2_abs_val_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='abs', evaluate_train=False)
v2_abs_train_embeddings = eval_domain_adaptation(model_ckpt='v2', eval_dataset='abs', evaluate_train=True)

# abs -> v2
abs_v2_val_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='v2', evaluate_train=False)
abs_v2_train_embeddings = eval_domain_adaptation(model_ckpt='abs', eval_dataset='v2', evaluate_train=True)
# Out:
# v2  -> abs | val set   	 accuracy = 52.00%
# v2  -> abs | train set 	 accuracy = 55.25%
# abs -> v2  | val set   	 accuracy = 50.33%
# abs -> v2  | train set 	 accuracy = 53.25%

# %% [markdown]
# ## Visualizing embeddings

# %%
from sklearn.manifold import TSNE
import matplotlib.patches as mpatches

def plot_tsne(embeddings, plot_labels, perplexities, title=''):
    n_plots = len(perplexities)
    fig, axes = plt.subplots(1, n_plots, figsize=(6 * n_plots, 6))
    
    for idx, perplexity in enumerate(perplexities):
        tsne = TSNE(n_components=2, perplexity=perplexity, random_state=42)
        tsne_embeddings = tsne.fit_transform(embeddings)
        
        colors = {'vv': 'blue', 'aa': 'red', 'va': 'orange', 'av': 'violet'}
        ax = axes[idx]
        for i, plot_label in enumerate(plot_labels):
                
            ax.scatter(tsne_embeddings[i, 0], tsne_embeddings[i, 1], color=colors[plot_label])
            ax.text(tsne_embeddings[i, 0] + 0.1, tsne_embeddings[i, 1], '', fontsize=9)
        
        ax.set_title(f'Perplexity = {perplexity}')
    
    custom_legend = [mpatches.Patch(color=colors[label], label=label) for label in set(plot_labels)]
    fig.legend(handles=custom_legend)
    fig.suptitle(title, fontsize=16)

    plt.tight_layout()
    plt.show()

# %%
n_v2 = len(v2_val_embeddings)
n_abs = len(abs_val_embeddings)

# v2 -> v2
plot_tsne(v2_val_embeddings, ['vv'] * n_v2, perplexities=[2,4,8,16,32], title='v2->v2 (val set)')
plot_tsne(v2_train_embeddings, ['vv'] * n_v2, perplexities=[2,4,8,16,32], title='v2->v2 (train set)')

# abs -> abs
plot_tsne(abs_val_embeddings, ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='abs->abs (val set)')
plot_tsne(abs_train_embeddings, ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='abs->abs (train set)')

# combined plot
val_embeddings = np.concatenate((v2_val_embeddings, abs_val_embeddings), axis=0)
plot_tsne(val_embeddings, ['vv'] * n_v2 + ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='Same Domain (val set)')

train_embeddings = np.concatenate((v2_train_embeddings, abs_train_embeddings), axis=0)
plot_tsne(train_embeddings, ['vv'] * n_v2 + ['aa'] * n_abs, perplexities=[2,4,8,16,32], title='Same Domain (train set)')

# %%
# v2 -> abs
plot_tsne(v2_abs_val_embeddings, ['va'] * n_abs, perplexities=[2,4,8,16,32], title='v2->abs (val set)')
plot_tsne(v2_abs_train_embeddings, ['va'] * n_abs, perplexities=[2,4,8,16,32], title='v2->abs (train set)')

# abs -> v2
plot_tsne(abs_v2_val_embeddings, ['av'] * n_v2, perplexities=[2,4,8,16,32], title='abs->v2 (val set)')
plot_tsne(abs_v2_train_embeddings, ['av'] * n_v2, perplexities=[2,4,8,16,32], title='abs->v2 (train set)')

# combined plot
val_embeddings = np.concatenate((v2_abs_val_embeddings, abs_v2_val_embeddings), axis=0)
plot_tsne(val_embeddings, ['va'] * n_abs + ['av'] * n_v2, perplexities=[2,4,8,16,32], title='Cross Domain (val set)')

train_embeddings = np.concatenate((v2_abs_train_embeddings, abs_v2_train_embeddings), axis=0)
plot_tsne(train_embeddings, ['va'] * n_abs + ['av'] * n_v2, perplexities=[2,4,8,16,32], title='Cross Domain (train set)')
