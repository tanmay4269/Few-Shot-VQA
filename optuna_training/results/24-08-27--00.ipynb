# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [1]</a>'.</span>

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
import os
os.chdir('/workspace/')

from optuna_training.trainer import OptunaTrainer

trainer = OptunaTrainer(n_trials=100, n_jobs=5)
trainer.run()
# Out:
# [I 2024-08-27 19:17:44,773] A new study created in memory with name: no-name-f99b2cbc-cdbf-4317-bdc8-b7b8ef649da1
# Sampler is TPESampler
# [W 2024-08-27 19:18:00,712] Trial 0 failed with parameters: {'v2_samples_per_answer': 4, 'abs_samples_per_answer': 5, 'source_domain': 'abs', 'label_classifier__use_bn': False, 'label_classifier__drop_p': 0.0, 'label_classifier__repeat_layers': 1, 'domain_classifier__use_bn': False, 'domain_classifier__drop_p': 0.5, 'domain_classifier__repeat_layers': 0, 'base_lr': 0.00034734588110031845, 'weight_decay': 9.467176307777435e-05} because of the following error: AttributeError("'NoneType' object has no attribute 'to'").
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/optuna/study/_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
#   File "/workspace/optuna_training/trainer.py", line 150, in objective
#     trainer = self.init_trainer(trial)
#   File "/workspace/optuna_training/trainer.py", line 143, in init_trainer
#     trainer = DA_Trainer(self.cfg, self.vqa_v2, self.vqa_abs)
#   File "/workspace/trainer.py", line 238, in __init__
#     super().__init__(cfg, vqa_v2, vqa_abs)
#   File "/workspace/trainer.py", line 41, in __init__
#     self.model = self.init_model()
#   File "/workspace/trainer.py", line 244, in init_model
#     return VLModel_IS(self.cfg).cuda()
#   File "/workspace/models/models.py", line 218, in __init__
#     super().__init__(cfg, embed_dim, return_embeddings)
#   File "/workspace/models/models.py", line 25, in __init__
#     self.i_encoder = AutoModel.from_pretrained(cfg["image_encoder"])
#   File "/opt/conda/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py", line 564, in from_pretrained
#     return model_class.from_pretrained(
#   File "/opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py", line 3832, in from_pretrained
#     model = cls(config, *model_args, **model_kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/transformers/models/dinov2/modeling_dinov2.py", line 584, in __init__
#     self.post_init()
#   File "/opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py", line 1406, in post_init
#     self.init_weights()
#   File "/opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py", line 2321, in init_weights
#     self.apply(self._initialize_weights)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 894, in apply
#     module.apply(fn)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 894, in apply
#     module.apply(fn)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 894, in apply
#     module.apply(fn)
#   [Previous line repeated 2 more times]
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 895, in apply
#     fn(self)
#   File "/opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py", line 1819, in _initialize_weights
#     self._init_weights(module)
#   File "/opt/conda/lib/python3.10/site-packages/transformers/models/dinov2/modeling_dinov2.py", line 489, in _init_weights
#     ).to(module.weight.dtype)
# AttributeError: 'NoneType' object has no attribute 'to'
# [W 2024-08-27 19:18:00,715] Trial 0 failed with value None.
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Using '/workspace/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# COMET WARNING: api_key was given, but is ignored in OfflineExperiment(); remember to set when you upload
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Uploads:
# COMET INFO:     filename    : 1
# COMET INFO:     notebook    : 1
# COMET INFO:     source_code : 1
# COMET INFO:
# COMET WARNING: Experiment Name is generated at upload time for Offline Experiments unless set explicitly with Experiment.set_name
# COMET INFO: Starting saving the offline archive
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Uploads:
# COMET INFO:     filename    : 1
# COMET INFO:     notebook    : 2
# COMET INFO:     source_code : 2
# COMET INFO:
# COMET WARNING: Experiment Name is generated at upload time for Offline Experiments unless set explicitly with Experiment.set_name
# COMET INFO: Starting saving the offline archive
# COMET WARNING: Failed to properly clean the experiment, reason: FileNotFoundError(2, 'No such file or directory')
# COMET INFO: To upload this offline experiment, run:
#     comet upload /workspace/.cometml-runs/7570200c0c8b4418acc42275bfa0abdc.zip
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Using '/workspace/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Using '/workspace/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Uploads:
# COMET INFO:     filename    : 1
# COMET INFO:     notebook    : 1
# COMET INFO:     source_code : 1
# COMET INFO:
# COMET WARNING: Experiment Name is generated at upload time for Offline Experiments unless set explicitly with Experiment.set_name
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload /workspace/.cometml-runs/7634cf65e19b45949db11e6d0494281d.zip
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Using '/workspace/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# [I 2024-08-27 20:02:16,192] Trial 2 finished with value: 1.0210061371326447 and parameters: {'v2_samples_per_answer': 4, 'abs_samples_per_answer': 4, 'source_domain': 'v2', 'label_classifier__use_bn': True, 'label_classifier__drop_p': 0.25, 'label_classifier__repeat_layers': 1, 'domain_classifier__use_bn': True, 'domain_classifier__drop_p': 0.5, 'domain_classifier__repeat_layers': 1, 'base_lr': 0.00011027722850666564, 'weight_decay': 7.767978303631771e-05}. Best is trial 2 with value: 1.0210061371326447.
# [I 2024-08-27 20:02:16,295] Trial 3 finished with value: 1.022161826491356 and parameters: {'v2_samples_per_answer': 5, 'abs_samples_per_answer': 5, 'source_domain': 'abs', 'label_classifier__use_bn': False, 'label_classifier__drop_p': 0.0, 'label_classifier__repeat_layers': 0, 'domain_classifier__use_bn': True, 'domain_classifier__drop_p': 0.5, 'domain_classifier__repeat_layers': 1, 'base_lr': 0.0004118224440869831, 'weight_decay': 9.601593452834172e-05}. Best is trial 2 with value: 1.0210061371326447.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : 7Gt5Hk20
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     Accuracy/Domain [30]    : (0.432, 0.69)
# COMET INFO:     Accuracy/abs_label [30] : (0.098, 0.34)
# COMET INFO:     Accuracy/avg_label [30] : (0.101, 0.325)
# COMET INFO:     Accuracy/v2_label [30]  : (0.1, 0.322)
# COMET INFO:     Loss/Eval [30]          : (1.0110086798667908, 1.4997677505016327)
# COMET INFO:     Loss/Train_domain [30]  : (0.6765811613627842, 0.7018339037895203)
# COMET INFO:     Loss/Train_label [30]   : (1.3019009828567505, 2.3027700015476773)
# COMET INFO:     Loss/Train_total [30]   : (0.9971963763237, 1.4981320244925362)
# COMET INFO:     loss [84]               : (0.989015519618988, 1.4992578029632568)
# COMET INFO:   Others:
# COMET INFO:     Name               : 7Gt5Hk20
# COMET INFO:     offline_experiment : True
# COMET INFO:   Parameters:
# COMET INFO:     abs_samples_per_answer           : 300
# COMET INFO:     abs_samples_per_answer_train     : 100
# COMET INFO:     abs_samples_per_answer_val       : 50
# COMET INFO:     base_lr                          : 4.820994680809146e-05
# COMET INFO:     batch_size                       : 150
# COMET INFO:     criss_cross__drop_p              : 0.0
# COMET INFO:     domain_adaptation_method         : domain_adversarial
# COMET INFO:     domain_classifier__drop_p        : 0.25
# COMET INFO:     domain_classifier__repeat_layers : [2, 2]
# COMET INFO:     domain_classifier__use_bn        : False
# COMET INFO:     domain_classifier_lr             : 4.820994680809146e-05
# COMET INFO:     embed_attn__add_residual         : False
# COMET INFO:     embed_attn__drop_p               : 0.0
# COMET INFO:     embedder_lr                      : 4.820994680809146e-05
# COMET INFO:     epochs                           : 30
# COMET INFO:     fusion_mode                      : cat
# COMET INFO:     image_encoder                    : facebook/dinov2-base
# COMET INFO:     label_classifier__drop_p         : 0.25
# COMET INFO:     label_classifier__repeat_layers  : [1, 1]
# COMET INFO:     label_classifier__use_bn         : False
# COMET INFO:     label_classifier_lr              : 4.820994680809146e-05
# COMET INFO:     max_q_len                        : 23
# COMET INFO:     n_classes                        : 10
# COMET INFO:     name                             : DANN
# COMET INFO:     num_attn_heads                   : 8
# COMET INFO:     num_stacked_attn                 : 1
# COMET INFO:     post_concat__drop_p              : 0.0
# COMET INFO:     print_logs                       : False
# COMET INFO:     relaxation_period                : -1
# COMET INFO:     show_plot                        : True
# COMET INFO:     source_domain                    : v2
# COMET INFO:     text_encoder                     : bert-base-uncased
# COMET INFO:     title                            : 7Gt5Hk20
# COMET INFO:     v2_samples_per_answer            : 300
# COMET INFO:     v2_samples_per_answer_train      : 100
# COMET INFO:     v2_samples_per_answer_val        : 50
# COMET INFO:     weight_decay                     : 2.610259113591845e-05
# COMET INFO:     weights_save_path                : ./weights/raw/7Gt5Hk20.pth
# COMET INFO:     weights_save_root                : ./weights/raw
# COMET INFO:   Uploads:
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     git-patch (uncompressed)     : 1 (4.14 KB)
# COMET INFO:     installed packages           : 1
# COMET INFO:     model-element                : 2 (883.23 MB)
# COMET INFO:     notebook                     : 1
# COMET INFO:     os packages                  : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : 7Gt5Hk20
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     Accuracy/Domain [30]    : (0.412, 0.792)
# COMET INFO:     Accuracy/abs_label [30] : (0.098, 0.312)
# COMET INFO:     Accuracy/avg_label [30] : (0.097, 0.308)
# COMET INFO:     Accuracy/v2_label [30]  : (0.096, 0.328)
# COMET INFO:     Loss/Eval [30]          : (1.0431030690670013, 1.500760942697525)
# COMET INFO:     Loss/Train_domain [30]  : (0.6522990550313678, 0.7298482060432434)
# COMET INFO:     Loss/Train_label [30]   : (1.389114260673523, 2.303399085998535)
# COMET INFO:     Loss/Train_total [30]   : (1.0389785426003593, 1.4984087262834822)
# COMET INFO:   Others:
# COMET INFO:     Name               : 7Gt5Hk20
# COMET INFO:     offline_experiment : True
# COMET INFO:   Parameters:
# COMET INFO:     abs_samples_per_answer           : 300
# COMET INFO:     abs_samples_per_answer_train     : 100
# COMET INFO:     abs_samples_per_answer_val       : 50
# COMET INFO:     base_lr                          : 4.820994680809146e-05
# COMET INFO:     batch_size                       : 150
# COMET INFO:     criss_cross__drop_p              : 0.0
# COMET INFO:     domain_adaptation_method         : domain_adversarial
# COMET INFO:     domain_classifier__drop_p        : 0.25
# COMET INFO:     domain_classifier__repeat_layers : [2, 2]
# COMET INFO:     domain_classifier__use_bn        : False
# COMET INFO:     domain_classifier_lr             : 4.820994680809146e-05
# COMET INFO:     embed_attn__add_residual         : False
# COMET INFO:     embed_attn__drop_p               : 0.0
# COMET INFO:     embedder_lr                      : 4.820994680809146e-05
# COMET INFO:     epochs                           : 30
# COMET INFO:     fusion_mode                      : cat
# COMET INFO:     image_encoder                    : facebook/dinov2-base
# COMET INFO:     label_classifier__drop_p         : 0.25
# COMET INFO:     label_classifier__repeat_layers  : [1, 1]
# COMET INFO:     label_classifier__use_bn         : False
# COMET INFO:     label_classifier_lr              : 4.820994680809146e-05
# COMET INFO:     max_q_len                        : 23
# COMET INFO:     n_classes                        : 10
# COMET INFO:     name                             : DANN
# COMET INFO:     num_attn_heads                   : 8
# COMET INFO:     num_stacked_attn                 : 1
# COMET INFO:     post_concat__drop_p              : 0.0
# COMET INFO:     print_logs                       : False
# COMET INFO:     relaxation_period                : -1
# COMET INFO:     show_plot                        : True
# COMET INFO:     source_domain                    : v2
# COMET INFO:     text_encoder                     : bert-base-uncased
# COMET INFO:     title                            : 7Gt5Hk20
# COMET INFO:     v2_samples_per_answer            : 300
# COMET INFO:     v2_samples_per_answer_train      : 100
# COMET INFO:     v2_samples_per_answer_val        : 50
# COMET INFO:     weight_decay                     : 2.610259113591845e-05
# COMET INFO:     weights_save_path                : ./weights/raw/7Gt5Hk20.pth
# COMET INFO:     weights_save_root                : ./weights/raw
# COMET INFO:   Uploads:
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     git-patch (uncompressed)     : 1 (4.14 KB)
# COMET INFO:     installed packages           : 1
# COMET INFO:     model-element                : 2 (883.23 MB)
# COMET INFO:     notebook                     : 1
# COMET INFO:     os packages                  : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET INFO: Still saving offline stats to messages file before program termination (may take up to 120 seconds)
# COMET INFO: Starting saving the offline archive
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload /workspace/.cometml-runs/1dedf67201014a4fb713ae9019282f15.zip
# [I 2024-08-27 20:02:20,513] Trial 1 finished with value: 1.0184873938560486 and parameters: {'v2_samples_per_answer': 4, 'abs_samples_per_answer': 5, 'source_domain': 'abs', 'label_classifier__use_bn': False, 'label_classifier__drop_p': 0.25, 'label_classifier__repeat_layers': 0, 'domain_classifier__use_bn': True, 'domain_classifier__drop_p': 0.25, 'domain_classifier__repeat_layers': 0, 'base_lr': 5.645829982641053e-05, 'weight_decay': 3.206357869327777e-05}. Best is trial 1 with value: 1.0184873938560486.
# COMET INFO: To upload this offline experiment, run:
#     comet upload /workspace/.cometml-runs/0ad8221352d9460c8a6fb941c1043742.zip
# [I 2024-08-27 20:02:20,666] Trial 4 finished with value: 1.0513834059238434 and parameters: {'v2_samples_per_answer': 2, 'abs_samples_per_answer': 2, 'source_domain': 'v2', 'label_classifier__use_bn': False, 'label_classifier__drop_p': 0.25, 'label_classifier__repeat_layers': 1, 'domain_classifier__use_bn': False, 'domain_classifier__drop_p': 0.25, 'domain_classifier__repeat_layers': 2, 'base_lr': 4.820994680809146e-05, 'weight_decay': 2.610259113591845e-05}. Best is trial 1 with value: 1.0184873938560486.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 7
#       4 from optuna_training.trainer import OptunaTrainer
#       6 trainer = OptunaTrainer(n_trials=100, n_jobs=5)
# ----> 7 trainer.run()
#
# File /workspace/optuna_training/trainer.py:174, in OptunaTrainer.run(self)
#     171 study = optuna.create_study(direction="minimize")
#     172 print(f"Sampler is {study.sampler.__class__.__name__}")
# --> 174 study.optimize(self.objective, n_trials=self.optuna_cfg['n_trials'], n_jobs=self.optuna_cfg['n_jobs'])
#     176 pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
#     177 complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])
#
# File /opt/conda/lib/python3.10/site-packages/optuna/study/study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File /opt/conda/lib/python3.10/site-packages/optuna/study/_optimize.py:99, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      97                     # Raise if exception occurred in executing the completed futures.
#      98                     for f in completed:
# ---> 99                         f.result()
#     101                 futures.add(
#     102                     executor.submit(
#     103                         _optimize_sequential,
#    (...)
#     114                     )
#     115                 )
#     116 finally:
#
# File /opt/conda/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/conda/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File /opt/conda/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File /opt/conda/lib/python3.10/site-packages/optuna/study/_optimize.py:159, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     156         break
#     158 try:
# --> 159     frozen_trial = _run_trial(study, func, catch)
#     160 finally:
#     161     # The following line mitigates memory problems that can be occurred in some
#     162     # environments (e.g., services that use computing containers such as GitHub Actions).
#     163     # Please refer to the following PR for further details:
#     164     # https://github.com/optuna/optuna/pull/325.
#     165     if gc_after_trial:
#
# File /opt/conda/lib/python3.10/site-packages/optuna/study/_optimize.py:247, in _run_trial(study, func, catch)
#     240         assert False, "Should not reach."
#     242 if (
#     243     frozen_trial.state == TrialState.FAIL
#     244     and func_err is not None
#     245     and not isinstance(func_err, catch)
#     246 ):
# --> 247     raise func_err
#     248 return frozen_trial
#
# File /opt/conda/lib/python3.10/site-packages/optuna/study/_optimize.py:196, in _run_trial(study, func, catch)
#     194 with get_heartbeat_thread(trial._trial_id, study._storage):
#     195     try:
# --> 196         value_or_values = func(trial)
#     197     except exceptions.TrialPruned as e:
#     198         # TODO(mamu): Handle multi-objective cases.
#     199         state = TrialState.PRUNED
#
# File /workspace/optuna_training/trainer.py:150, in OptunaTrainer.objective(self, trial)
#     149 def objective(self, trial):
# --> 150     trainer = self.init_trainer(trial)
#     152     if self.optuna_cfg['comet_logging']:
#     153         config = trainer.cfg
#
# File /workspace/optuna_training/trainer.py:143, in OptunaTrainer.init_trainer(self, trial)
#     140     l = self.cfg[k]
#     141     self.cfg[k] = [l, l]
# --> 143 trainer = DA_Trainer(self.cfg, self.vqa_v2, self.vqa_abs)
#     145 trial.params['n_classes'] = self.cfg['n_classes']  # Coz it could update in data_processing_v2
#     147 return trainer
#
# File /workspace/trainer.py:238, in DA_Trainer.__init__(self, cfg, vqa_v2, vqa_abs)
#     235 cfg["label_classifier_lr"] = cfg["base_lr"]
#     236 cfg["domain_classifier_lr"] = cfg["base_lr"]
# --> 238 super().__init__(cfg, vqa_v2, vqa_abs)
#     240 self.criterion_label = nn.CrossEntropyLoss(reduction="none")
#     241 self.criterion_domain = nn.BCEWithLogitsLoss()
#
# File /workspace/trainer.py:41, in Trainer.__init__(self, cfg, vqa_v2, vqa_abs)
#      38 self.source_domain = cfg["source_domain"]
#      40 self.init_dataloader()
# ---> 41 self.model = self.init_model()
#      43 self.criterion = nn.CrossEntropyLoss()
#      44 self.optimizer = self.init_optimizer()
#
# File /workspace/trainer.py:244, in DA_Trainer.init_model(self)
#     243 def init_model(self):
# --> 244     return VLModel_IS(self.cfg).cuda()
#
# File /workspace/models/models.py:218, in VLModel_IS.__init__(self, cfg, embed_dim, return_embeddings)
#     217 def __init__(self, cfg, embed_dim=768, return_embeddings=False):
# --> 218     super().__init__(cfg, embed_dim, return_embeddings)
#     220     self.grad_reversal = cfg['domain_adaptation_method'] == 'domain_adversarial'
#     222     self.domain_classifier = self.init_ffn(
#     223         cfg["domain_classifier__use_bn"],
#     224         cfg["domain_classifier__drop_p"],
#    (...)
#     227         repeat_layers=cfg['domain_classifier__repeat_layers'],
#     228     )
#
# File /workspace/models/models.py:25, in VLModel.__init__(self, cfg, embed_dim, return_embeddings)
#      22     if "transformers" in logger.name.lower():
#      23         logger.setLevel(logging.ERROR)
# ---> 25 self.i_encoder = AutoModel.from_pretrained(cfg["image_encoder"])
#      26 self.q_encoder = BertModel.from_pretrained(cfg["text_encoder"])
#      28 self.num_stacked_attn = cfg["num_stacked_attn"]
#
# File /opt/conda/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:564, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562 elif type(config) in cls._model_mapping.keys():
#     563     model_class = _get_model_class(config, cls._model_mapping)
# --> 564     return model_class.from_pretrained(
#     565         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     566     )
#     567 raise ValueError(
#     568     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     569     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     570 )
#
# File /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:3832, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3826 config = cls._autoset_attn_implementation(
#    3827     config, use_flash_attention_2=use_flash_attention_2, torch_dtype=torch_dtype, device_map=device_map
#    3828 )
#    3830 with ContextManagers(init_contexts):
#    3831     # Let's make sure we don't run the init function of buffer modules
# -> 3832     model = cls(config, *model_args, **model_kwargs)
#    3834 # make sure we use the model's config since the __init__ call might have copied it
#    3835 config = model.config
#
# File /opt/conda/lib/python3.10/site-packages/transformers/models/dinov2/modeling_dinov2.py:584, in Dinov2Model.__init__(self, config)
#     581 self.layernorm = nn.LayerNorm(config.hidden_size, eps=config.layer_norm_eps)
#     583 # Initialize weights and apply final processing
# --> 584 self.post_init()
#
# File /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:1406, in PreTrainedModel.post_init(self)
#    1401 def post_init(self):
#    1402     """
#    1403     A method executed at the end of each Transformer model initialization, to execute code that needs the model's
#    1404     modules properly initialized (such as weight initialization).
#    1405     """
# -> 1406     self.init_weights()
#    1407     self._backward_compatibility_gradient_checkpointing()
#
# File /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:2321, in PreTrainedModel.init_weights(self)
#    2317     self.prune_heads(self.config.pruned_heads)
#    2319 if _init_weights:
#    2320     # Initialize weights
# -> 2321     self.apply(self._initialize_weights)
#    2323     # Tie weights should be skipped when not initializing all weights
#    2324     # since from_pretrained(...) calls tie weights anyways
#    2325     self.tie_weights()
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:894, in Module.apply(self, fn)
#     858 r"""Apply ``fn`` recursively to every submodule (as returned by ``.children()``) as well as self.
#     859
#     860 Typical use includes initializing the parameters of a model
#    (...)
#     891
#     892 """
#     893 for module in self.children():
# --> 894     module.apply(fn)
#     895 fn(self)
#     896 return self
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:894, in Module.apply(self, fn)
#     858 r"""Apply ``fn`` recursively to every submodule (as returned by ``.children()``) as well as self.
#     859
#     860 Typical use includes initializing the parameters of a model
#    (...)
#     891
#     892 """
#     893 for module in self.children():
# --> 894     module.apply(fn)
#     895 fn(self)
#     896 return self
#
#     [... skipping similar frames: Module.apply at line 894 (2 times)]
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:894, in Module.apply(self, fn)
#     858 r"""Apply ``fn`` recursively to every submodule (as returned by ``.children()``) as well as self.
#     859
#     860 Typical use includes initializing the parameters of a model
#    (...)
#     891
#     892 """
#     893 for module in self.children():
# --> 894     module.apply(fn)
#     895 fn(self)
#     896 return self
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:895, in Module.apply(self, fn)
#     893 for module in self.children():
#     894     module.apply(fn)
# --> 895 fn(self)
#     896 return self
#
# File /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:1819, in PreTrainedModel._initialize_weights(self, module)
#    1817 if getattr(module, "_is_hf_initialized", False):
#    1818     return
# -> 1819 self._init_weights(module)
#    1820 module._is_hf_initialized = True
#
# File /opt/conda/lib/python3.10/site-packages/transformers/models/dinov2/modeling_dinov2.py:489, in Dinov2PreTrainedModel._init_weights(self, module)
#     483 """Initialize the weights"""
#     484 if isinstance(module, (nn.Linear, nn.Conv2d)):
#     485     # Upcast the input in `fp32` and cast it back to desired `dtype` to avoid
#     486     # `trunc_normal_cpu` not implemented in `half` issues
#     487     module.weight.data = nn.init.trunc_normal_(
#     488         module.weight.data.to(torch.float32), mean=0.0, std=self.config.initializer_range
# --> 489     ).to(module.weight.dtype)
#     490     if module.bias is not None:
#     491         module.bias.data.zero_()
#
# AttributeError: 'NoneType' object has no attribute 'to'
